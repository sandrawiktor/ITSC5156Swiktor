# %% [markdown]
# ### Sentiment Analysis
# + PAPER: https://journalofbigdata.springeropen.com/articles/10.1186/s40537-015-0015-2
# + POS TAGS: https://stackoverflow.com/questions/15388831/what-are-all-possible-pos-tags-of-nltk
# + Hash function: https://stackoverflow.com/questions/16008670/how-to-hash-a-string-into-8-digits
# + NOTES: To do the negative sentiment analysis, you need to erase all punctuation and capitalization from the DF
# + Bag of Words vectorizer: https://www.mygreatlearning.com/blog/bag-of-words/

# %% [markdown]
# # Preprocessing
# ---

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import nltk
from nltk.tokenize import word_tokenize
from collections import Counter


nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
df = pd.read_json('/content/reviews_Musical_Instruments_5.json', lines=True)

#df = pd.read_csv('/content/reviews_Musical_Instruments_5.csv')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
df = df[['reviewText', 'overall']]

# %%
df['reviewText'] = df['reviewText'].str.lower()

# %%
df
# Out:
#                                               reviewText  overall
# 0      not much to write about here, but it does exac...        5
# 1      the product does exactly as it should and is q...        5
# 2      the primary job of this device is to block the...        5
# 3      nice windscreen protects my mxl mic and preven...        5
# 4      this pop filter is great. it looks and perform...        5
# ...                                                  ...      ...
# 10256            great, just as expected.  thank to all.        5
# 10257  i've been thinking about trying the nanoweb st...        5
# 10258  i have tried coated strings in the past ( incl...        4
# 10259  well, made by elixir and developed with taylor...        4
# 10260  these strings are really quite good, but i wou...        4
#
# [10261 rows x 2 columns]

# %%
df['reviewText'] = df['reviewText'].str.replace(r'[^\w\s]+', '')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ### Divide dataset by star

# %%
df_5 = df[df['overall'] == 5]
df_4 = df[df['overall'] == 4]
df_3 = df[df['overall'] == 3]
df_2 = df[df['overall'] == 2]
df_1 = df[df['overall'] == 1]

# %% [markdown]
# ### Analyze dataset
# - We notice there is an issue of an imbalanced dataset. We will need to consider this later.

# %%
df_5.shape
# Out:
# (6938, 2)

# %%
df_4.shape
# Out:
# (2084, 2)

# %%
df_3.shape
# Out:
# (772, 2)

# %%
df_2.shape
# Out:
# (250, 2)

# %%
df_1.shape
# Out:
# (217, 2)

# %%
df_array = []
df_array.append(df_1)
df_array.append(df_2)
df_array.append(df_3)
df_array.append(df_4)
df_array.append(df_5)

# %% [markdown]
# ## Methods
#
#
# ---

# %%
def tokenizer_(df):
  # holds all tokenized reviews
  reviews_tok = []
  # holds all tags of review
 
  tokenizer = nltk.RegexpTokenizer(r"\w+")

  # tokenize
  for i in df['reviewText']:  
    
    reviews_tok.append(tokenizer.tokenize(i))
      

  return reviews_tok

# %%
def POS_tagger(reviews_tok):
  
  tag = []
  # parts of speech tagging
  for i in reviews_tok:
    val = nltk.pos_tag(i)
    for j in val:
      # not sure what caused this error, but for some reason, some values of j did not return a tuple
      if len(j) == 2:
          tag.append(j)
  return tag

# %%
def filt(tag):
  # filter tags with no emotional meaning (only take verb, adverb, adjective)
  filtered_tag = []
  filt_list_pos = ['JJ','JJR','JJS','RB','RBR','RBS','VB','VBD','VBG','VBN','VBP','VBZ','WRB']
  temp = []
  for i in tag:
    if i[1] in filt_list_pos:
      filtered_tag.append(i)

  return filtered_tag

# %%
def tokens_prep(df):
  tokens_5 = word_tokens(df_5)
  tokens_5

# %%
def word_tokens(df):
  tagged = tokenizer_(df)
  tag = POS_tagger(tagged)
  filtered = filt(tag)
  return filtered

# %%
from collections import Counter
def most_common_tokens(tokens, df):
  tokens=word_tokens(df)
  Count = Counter(tokens)
  # take 25% of the top words
  most_occur = Count.most_common(int(len(df)*0.25))
  print(most_occur)
  common = []
  common_plus = []

  for i in most_occur:
    common.append(i[0][0])
    common_plus.append(i)
  return common, common_plus

# %%
# vectorizes a dataframe
def vectorizer(common, df):
  full_vec = []
  for j in df["reviewText"]:
   
    test_vec = []


    for i in common:
      #print(i)
      if i[0] in j:
        test_vec.append(1)
      else:
        test_vec.append(0)
    # hash the 1s and 0s vector    
    full_vec.append(hash(str(test_vec))%1000000)

  return full_vec

# %% [markdown]
# ## Creating Token Vectors
#
# ---
# There has to be a better way to do this part without making separate variables for each category. I know there is. But I'm on a deadline here so this is what we're doing.

# %%
tokens_arr = []
bow = []
# Output filtered tokens in each category
tokens_1 = word_tokens(df_1)
tokens1, tokens1_plus = most_common_tokens(tokens_1, df_1)
print(len(tokens1))

tokens_2 = word_tokens(df_2)
tokens2, tokens2_plus = most_common_tokens(tokens_2, df_2)
print(len(tokens2))


tokens_3 = word_tokens(df_3)
tokens3, tokens3_plus = most_common_tokens(tokens_3, df_3)
print(len(tokens3))


tokens_4 = word_tokens(df_4)
tokens4, tokens4_plus = most_common_tokens(tokens_4, df_4)
print(len(tokens4))


tokens_5 = word_tokens(df_5)
tokens5, tokens5_plus = most_common_tokens(tokens_5, df_5)
print(len(tokens5))



tokens_arr.append(tokens1)
tokens_arr.append(tokens2)
tokens_arr.append(tokens3)
tokens_arr.append(tokens4)
tokens_arr.append(tokens5)
# Out:
# [(('is', 'VBZ'), 311), (('not', 'RB'), 199), (('was', 'VBD'), 167), (('have', 'VBP'), 142), (('i', 'JJ'), 129), (('are', 'VBP'), 103), (('just', 'RB'), 97), (('be', 'VB'), 81), (('so', 'RB'), 78), (('very', 'RB'), 66), (('when', 'WRB'), 60), (('get', 'VB'), 57), (('really', 'RB'), 55), (('had', 'VBD'), 55), (('has', 'VBZ'), 54), (('good', 'JJ'), 53), (('even', 'RB'), 51), (('too', 'RB'), 49), (('other', 'JJ'), 48), (('got', 'VBD'), 47), (('back', 'RB'), 45), (('only', 'RB'), 45), (('have', 'VB'), 43), (('buy', 'VB'), 43), (('i', 'VBP'), 42), (('then', 'RB'), 41), (('i', 'RB'), 39), (('cheap', 'JJ'), 37), (('use', 'VB'), 37), (('i', 'VB'), 36), (('few', 'JJ'), 35), (('did', 'VBD'), 34), (('bought', 'VBD'), 34), (('well', 'RB'), 33), (('were', 'VBD'), 32), (('more', 'JJR'), 31), (('am', 'VBP'), 31), (('work', 'VB'), 30), (('also', 'RB'), 30), (('now', 'RB'), 29), (('does', 'VBZ'), 28), (('same', 'JJ'), 28), (('used', 'VBN'), 27), (('great', 'JJ'), 27), (('do', 'VBP'), 27), (('bad', 'JJ'), 26), (('going', 'VBG'), 26), (('new', 'JJ'), 26), (('how', 'WRB'), 25), (('want', 'VBP'), 24), (('again', 'RB'), 24), (('dont', 'VBP'), 23), (('been', 'VBN'), 22), (('never', 'RB'), 22)]
# 54
# [(('is', 'VBZ'), 423), (('not', 'RB'), 255), (('was', 'VBD'), 172), (('are', 'VBP'), 159), (('i', 'JJ'), 152), (('have', 'VBP'), 148), (('be', 'VB'), 119), (('just', 'RB'), 118), (('very', 'RB'), 97), (('so', 'RB'), 86), (('get', 'VB'), 86), (('good', 'JJ'), 78), (('have', 'VB'), 69), (('great', 'JJ'), 69), (('when', 'WRB'), 67), (('other', 'JJ'), 66), (('had', 'VBD'), 64), (('really', 'RB'), 57), (('too', 'RB'), 57), (('has', 'VBZ'), 56), (('better', 'JJR'), 54), (('i', 'VBP'), 53), (('well', 'RB'), 52), (('use', 'VB'), 50), (('does', 'VBZ'), 49), (('only', 'RB'), 48), (('even', 'RB'), 47), (('bought', 'VBD'), 46), (('were', 'VBD'), 45), (('more', 'JJR'), 45), (('more', 'RBR'), 45), (('much', 'JJ'), 44), (('also', 'RB'), 44), (('cheap', 'JJ'), 42), (('same', 'JJ'), 40), (('dont', 'VBP'), 40), (('then', 'RB'), 38), (('used', 'VBN'), 37), (('got', 'VBD'), 37), (('i', 'RB'), 36), (('want', 'VBP'), 36), (('did', 'VBD'), 36), (('i', 'VB'), 35), (('do', 'VB'), 34), (('big', 'JJ'), 34), (('now', 'RB'), 33), (('as', 'RB'), 32), (('do', 'VBP'), 32), (('first', 'JJ'), 32), (('new', 'JJ'), 31), (('still', 'RB'), 30), (('ive', 'JJ'), 30), (('hard', 'JJ'), 30), (('however', 'RB'), 30), (('work', 'VB'), 30), (('where', 'WRB'), 28), (('high', 'JJ'), 28), (('enough', 'RB'), 27), (('little', 'JJ'), 27), (('using', 'VBG'), 26), (('am', 'VBP'), 26), (('works', 'VBZ'), 25)]
# 62
# [(('is', 'VBZ'), 1354), (('not', 'RB'), 727), (('are', 'VBP'), 509), (('i', 'JJ'), 482), (('have', 'VBP'), 462), (('be', 'VB'), 441), (('just', 'RB'), 381), (('was', 'VBD'), 376), (('good', 'JJ'), 325), (('so', 'RB'), 293), (('very', 'RB'), 280), (('when', 'WRB'), 257), (('other', 'JJ'), 213), (('get', 'VB'), 213), (('really', 'RB'), 211), (('has', 'VBZ'), 193), (('well', 'RB'), 192), (('have', 'VB'), 180), (('does', 'VBZ'), 179), (('little', 'JJ'), 178), (('had', 'VBD'), 175), (('use', 'VB'), 173), (('more', 'RBR'), 168), (('great', 'JJ'), 167), (('i', 'VBP'), 161), (('only', 'RB'), 154), (('more', 'JJR'), 153), (('too', 'RB'), 146), (('better', 'JJR'), 138), (('using', 'VBG'), 135), (('also', 'RB'), 134), (('even', 'RB'), 125), (('dont', 'VBP'), 121), (('works', 'VBZ'), 118), (('as', 'RB'), 118), (('much', 'JJ'), 109), (('much', 'RB'), 108), (('still', 'RB'), 104), (('bought', 'VBD'), 99), (('then', 'RB'), 99), (('nice', 'JJ'), 98), (('used', 'VBN'), 97), (('do', 'VBP'), 97), (('i', 'RB'), 95), (('got', 'VBD'), 95), (('ive', 'JJ'), 94), (('i', 'VB'), 91), (('do', 'VB'), 91), (('want', 'VBP'), 91), (('use', 'VBP'), 88), (('how', 'WRB'), 88), (('think', 'VBP'), 87), (('been', 'VBN'), 85), (('small', 'JJ'), 82), (('cheap', 'JJ'), 82), (('am', 'VBP'), 81), (('now', 'RB'), 80), (('playing', 'VBG'), 78), (('same', 'JJ'), 77), (('easy', 'JJ'), 75), (('makes', 'VBZ'), 73), (('work', 'VB'), 72), (('make', 'VB'), 72), (('far', 'RB'), 71), (('probably', 'RB'), 71), (('did', 'VBD'), 71), (('however', 'RB'), 71), (('enough', 'RB'), 71), (('few', 'JJ'), 69), (('back', 'RB'), 68), (('get', 'VBP'), 67), (('were', 'VBD'), 66), (('pretty', 'RB'), 65), (('sure', 'JJ'), 65), (('buy', 'VB'), 65), (('first', 'JJ'), 64), (('getting', 'VBG'), 63), (('made', 'VBN'), 63), (('bad', 'JJ'), 62), (('acoustic', 'JJ'), 62), (('looking', 'VBG'), 61), (('different', 'JJ'), 60), (('most', 'JJS'), 60), (('where', 'WRB'), 60), (('go', 'VB'), 60), (('need', 'VBP'), 60), (('new', 'JJ'), 59), (('know', 'VBP'), 58), (('last', 'JJ'), 58), (('going', 'VBG'), 58), (('seems', 'VBZ'), 58), (('high', 'JJ'), 56), (('fine', 'JJ'), 55), (('keep', 'VB'), 55), (('say', 'VB'), 54), (('play', 'VB'), 54), (('being', 'VBG'), 53), (('give', 'VB'), 53), (('hard', 'JJ'), 53), (('found', 'VBD'), 51), (('better', 'RBR'), 51), (('low', 'JJ'), 51), (('never', 'RB'), 50), (('tried', 'VBD'), 50), (('sounds', 'VBZ'), 49), (('electric', 'JJ'), 49), (('mic', 'JJ'), 48), (('many', 'JJ'), 47), (('best', 'JJS'), 46), (('easily', 'RB'), 46), (('ok', 'JJ'), 46), (('big', 'JJ'), 45), (('quite', 'RB'), 44), (('said', 'VBD'), 44), (('try', 'VB'), 43), (('hold', 'VB'), 43), (('long', 'JJ'), 43), (('cant', 'VBP'), 43), (('having', 'VBG'), 42), (('actually', 'RB'), 42), (('almost', 'RB'), 41), (('old', 'JJ'), 40), (('im', 'JJ'), 40), (('maybe', 'RB'), 39), (('decent', 'JJ'), 39), (('recommend', 'VB'), 39), (('see', 'VB'), 39), (('definitely', 'RB'), 39), (('least', 'JJS'), 39), (('find', 'VB'), 39), (('once', 'RB'), 38), (('less', 'JJR'), 38), (('again', 'RB'), 38), (('thin', 'JJ'), 38), (('take', 'VB'), 38), (('i', 'VBZ'), 36), (('able', 'JJ'), 36), (('seem', 'VBP'), 36), (('pedal', 'JJ'), 35), (('large', 'JJ'), 35), (('expensive', 'JJ'), 34), (('gets', 'VBZ'), 34), (('love', 'VBP'), 34), (('there', 'RB'), 33), (('doesnt', 'VBZ'), 33), (('always', 'RB'), 33), (('extra', 'JJ'), 32), (('prefer', 'VBP'), 32), (('overall', 'JJ'), 32), (('ordered', 'VBD'), 32), (('heavy', 'JJ'), 32), (('here', 'RB'), 32), (('only', 'JJ'), 32), (('thought', 'VBD'), 31), (('put', 'VB'), 31), (('go', 'VBP'), 31), (('tuning', 'VBG'), 31), (('done', 'VBN'), 31), (('right', 'JJ'), 30), (('play', 'VBP'), 30), (('fit', 'VB'), 30), (('why', 'WRB'), 30), (('solid', 'JJ'), 30), (('higher', 'JJR'), 30), (('feel', 'VB'), 30), (('used', 'VBD'), 30), (('short', 'JJ'), 30), (('didnt', 'VBP'), 29), (('comes', 'VBZ'), 29), (('dont', 'JJ'), 29), (('rather', 'RB'), 29), (('looks', 'VBZ'), 29), (('wanted', 'VBD'), 29), (('quickly', 'RB'), 29), ...
# 193
# [(('is', 'VBZ'), 3356), (('not', 'RB'), 1436), (('are', 'VBP'), 1277), (('have', 'VBP'), 1221), (('i', 'JJ'), 1114), (('be', 'VB'), 1054), (('good', 'JJ'), 996), (('was', 'VBD'), 796), (('just', 'RB'), 782), (('very', 'RB'), 729), (('so', 'RB'), 703), (('well', 'RB'), 690), (('great', 'JJ'), 674), (('when', 'WRB'), 598), (('little', 'JJ'), 539), (('has', 'VBZ'), 521), (('other', 'JJ'), 508), (('get', 'VB'), 486), (('really', 'RB'), 439), (('i', 'VBP'), 434), (('had', 'VBD'), 415), (('works', 'VBZ'), 408), (('more', 'RBR'), 403), (('does', 'VBZ'), 402), (('also', 'RB'), 386), (('nice', 'JJ'), 373), (('use', 'VB'), 369), (('have', 'VB'), 364), (('more', 'JJR'), 358), (('only', 'RB'), 341), (('using', 'VBG'), 325), (('too', 'RB'), 317), (('as', 'RB'), 316), (('do', 'VBP'), 278), (('used', 'VBN'), 276), (('even', 'RB'), 270), (('still', 'RB'), 267), (('dont', 'VBP'), 266), (('been', 'VBN'), 254), (('ive', 'JJ'), 249), (('easy', 'JJ'), 246), (('bought', 'VBD'), 243), (('am', 'VBP'), 242), (('much', 'JJ'), 239), (('use', 'VBP'), 237), (('i', 'RB'), 229), (('i', 'VB'), 225), (('want', 'VBP'), 223), (('then', 'RB'), 217), (('better', 'JJR'), 215), (('got', 'VBD'), 214), (('now', 'RB'), 212), (('how', 'WRB'), 203), (('small', 'JJ'), 200), (('think', 'VBP'), 196), (('do', 'VB'), 196), (('few', 'JJ'), 194), (('playing', 'VBG'), 194), (('same', 'JJ'), 192), (('seems', 'VBZ'), 189), (('much', 'RB'), 187), (('were', 'VBD'), 187), (('new', 'JJ'), 186), (('need', 'VBP'), 183), (('acoustic', 'JJ'), 183), (('fine', 'JJ'), 181), (('cheap', 'JJ'), 174), (('make', 'VB'), 172), (('mic', 'JJ'), 169), (('last', 'JJ'), 168), (('only', 'JJ'), 167), (('however', 'RB'), 163), (('enough', 'RB'), 162), (('pretty', 'RB'), 158), (('different', 'JJ'), 157), (('made', 'VBN'), 156), (('best', 'JJS'), 155), (('first', 'JJ'), 153), (('far', 'RB'), 152), (('sure', 'JJ'), 151), (('did', 'VBD'), 151), (('quite', 'RB'), 149), (('makes', 'VBZ'), 149), (('buy', 'VB'), 148), (('big', 'JJ'), 145), (('sounds', 'VBZ'), 143), (('looking', 'VBG'), 141), (('probably', 'RB'), 141), (('high', 'JJ'), 139), (('solid', 'JJ'), 139), (('going', 'VBG'), 138), (('most', 'JJS'), 134), (('keep', 'VB'), 133), (('where', 'WRB'), 131), (('many', 'JJ'), 130), (('play', 'VB'), 127), (('again', 'RB'), 126), (('never', 'RB'), 125), (('get', 'VBP'), 122), (('go', 'VB'), 122), (('low', 'JJ'), 120), (('electric', 'JJ'), 120), (('better', 'RBR'), 118), (('back', 'RB'), 117), (('give', 'VB'), 117), (('being', 'VBG'), 116), (('hard', 'JJ'), 115), (('actually', 'RB'), 114), (('see', 'VB'), 113), (('heavy', 'JJ'), 113), (('almost', 'RB'), 113), (('know', 'VBP'), 110), (('easily', 'RB'), 110), (('found', 'VBD'), 110), (('came', 'VBD'), 110), (('find', 'VB'), 110), (('always', 'RB'), 109), (('bad', 'JJ'), 109), (('say', 'VB'), 109), (('hold', 'VB'), 108), (('having', 'VBG'), 108), (('i', 'VBZ'), 105), (('used', 'VBD'), 105), (('comes', 'VBZ'), 105), (('getting', 'VBG'), 104), (('take', 'VB'), 104), (('long', 'JJ'), 103), (('right', 'JJ'), 103), (('cant', 'VBP'), 103), (('work', 'VB'), 102), (('less', 'JJR'), 102), (('try', 'VB'), 102), (('here', 'RB'), 102), (('looks', 'VBZ'), 101), (('expensive', 'JJ'), 101), (('yet', 'RB'), 97), (('recommend', 'VB'), 97), (('old', 'JJ'), 97), (('once', 'RB'), 95), (('extra', 'JJ'), 95), (('light', 'JJ'), 93), (('tuning', 'VBG'), 93), (('im', 'JJ'), 92), (('several', 'JJ'), 92), (('doesnt', 'VBZ'), 92), (('happy', 'JJ'), 91), (('string', 'VBG'), 91), (('clean', 'JJ'), 90), (('there', 'RB'), 90), (('recording', 'VBG'), 89), (('perfect', 'JJ'), 88), (('said', 'VBD'), 88), (('usb', 'JJ'), 87), (('especially', 'RB'), 85), (('why', 'WRB'), 82), (('put', 'VB'), 82), (('pedal', 'JJ'), 82), (('sound', 'JJ'), 81), (('seem', 'VBP'), 81), (('work', 'VBP'), 81), (('find', 'VBP'), 80), (('built', 'VBN'), 80), (('needed', 'VBD'), 79), (('gets', 'VBZ'), 79), (('slightly', 'RB'), 79), (('inexpensive', 'JJ'), 78), (('definitely', 'RB'), 76), (('long', 'RB'), 76), (('instead', 'RB'), 75 ...
# 521
# [(('is', 'VBZ'), 9127), (('are', 'VBP'), 3739), (('have', 'VBP'), 3589), (('not', 'RB'), 3117), (('great', 'JJ'), 3042), (('i', 'JJ'), 3011), (('very', 'RB'), 2621), (('was', 'VBD'), 2507), (('be', 'VB'), 2343), (('just', 'RB'), 2325), (('good', 'JJ'), 2199), (('so', 'RB'), 2023), (('well', 'RB'), 1956), (('when', 'WRB'), 1673), (('has', 'VBZ'), 1539), (('really', 'RB'), 1465), (('i', 'VBP'), 1329), (('other', 'JJ'), 1313), (('little', 'JJ'), 1168), (('also', 'RB'), 1120), (('get', 'VB'), 1116), (('had', 'VBD'), 1102), (('nice', 'JJ'), 1065), (('use', 'VB'), 1055), (('more', 'JJR'), 991), (('works', 'VBZ'), 989), (('easy', 'JJ'), 957), (('more', 'RBR'), 949), (('does', 'VBZ'), 947), (('ive', 'JJ'), 925), (('using', 'VBG'), 922), (('have', 'VB'), 896), (('too', 'RB'), 848), (('bought', 'VBD'), 847), (('as', 'RB'), 834), (('used', 'VBN'), 833), (('even', 'RB'), 793), (('been', 'VBN'), 791), (('am', 'VBP'), 789), (('use', 'VBP'), 776), (('now', 'RB'), 744), (('do', 'VBP'), 705), (('acoustic', 'JJ'), 700), (('only', 'RB'), 694), (('much', 'JJ'), 689), (('got', 'VBD'), 661), (('playing', 'VBG'), 657), (('i', 'RB'), 657), (('best', 'JJS'), 652), (('still', 'RB'), 646), (('i', 'VB'), 644), (('dont', 'VBP'), 643), (('how', 'WRB'), 607), (('then', 'RB'), 595), (('buy', 'VB'), 587), (('small', 'JJ'), 584), (('want', 'VBP'), 584), (('better', 'JJR'), 580), (('new', 'JJ'), 551), (('do', 'VB'), 546), (('many', 'JJ'), 543), (('different', 'JJ'), 539), (('much', 'RB'), 534), (('last', 'JJ'), 528), (('few', 'JJ'), 523), (('sounds', 'VBZ'), 511), (('need', 'VBP'), 501), (('same', 'JJ'), 486), (('looking', 'VBG'), 486), (('made', 'VBN'), 481), (('were', 'VBD'), 480), (('always', 'RB'), 479), (('makes', 'VBZ'), 471), (('play', 'VB'), 467), (('never', 'RB'), 466), (('love', 'VBP'), 457), (('go', 'VB'), 440), (('did', 'VBD'), 439), (('far', 'RB'), 438), (('perfect', 'JJ'), 434), (('first', 'JJ'), 422), (('make', 'VB'), 421), (('enough', 'RB'), 413), (('mic', 'JJ'), 410), (('electric', 'JJ'), 410), (('high', 'JJ'), 393), (('think', 'VBP'), 392), (('get', 'VBP'), 386), (('long', 'JJ'), 385), (('say', 'VB'), 379), (('i', 'VBZ'), 376), (('recommend', 'VB'), 375), (('solid', 'JJ'), 375), (('highly', 'RB'), 374), (('going', 'VBG'), 370), (('back', 'RB'), 369), (('right', 'JJ'), 366), (('where', 'WRB'), 364), (('easily', 'RB'), 363), (('keep', 'VB'), 359), (('sure', 'JJ'), 353), (('being', 'VBG'), 351), (('cheap', 'JJ'), 350), (('low', 'JJ'), 350), (('most', 'JJS'), 344), (('ever', 'RB'), 335), (('know', 'VBP'), 329), (('seems', 'VBZ'), 328), (('heavy', 'JJ'), 327), (('better', 'RBR'), 324), (('clean', 'JJ'), 323), (('cant', 'VBP'), 322), (('happy', 'JJ'), 319), (('old', 'JJ'), 317), (('looks', 'VBZ'), 315), (('see', 'VB'), 308), (('actually', 'RB'), 307), (('comes', 'VBZ'), 302), (('expensive', 'JJ'), 301), (('play', 'VBP'), 301), (('excellent', 'JJ'), 300), (('pretty', 'RB'), 299), (('came', 'VBD'), 294), (('having', 'VBG'), 292), (('again', 'RB'), 287), (('big', 'JJ'), 287), (('several', 'JJ'), 285), (('hard', 'JJ'), 285), (('find', 'VB'), 284), (('perfectly', 'RB'), 284), (('quite', 'RB'), 283), (('take', 'VB'), 280), (('probably', 'RB'), 279), (('light', 'JJ'), 272), (('built', 'VBN'), 271), (('only', 'JJ'), 271), (('hold', 'VB'), 270), (('used', 'VBD'), 269), (('im', 'JJ'), 269), (('put', 'VB'), 268), (('getting', 'VBG'), 267), (('simple', 'JJ'), 266), (('there', 'RB'), 266), (('give', 'VB'), 263), (('tuning', 'VBG'), 261), (('fine', 'JJ'), 256), (('definitely', 'RB'), 256), (('own', 'JJ'), 250), (('here', 'RB'), 246), (('almost', 'RB'), 245), (('try', 'VB'), 244), (('work', 'VB'), 243), (('recording', 'VBG'), 242), (('wanted', 'VBD'), 242), (('yet', 'RB'), 242), (('extra', 'JJ'), 240), (('found', 'VBD'), 238), (('sturdy', 'JJ'), 237), (('needed', 'VBD'), 235), (('sound', 'JJ'), 231), (('able', 'JJ'), 230), (('once', 'RB'), 230), (('said', 'VBD'), 229), (('pedal', 'JJ'), 228), (('less', 'JJR'), 228), (('tried', 'VBD'), 226), (('string', 'VBG'), 225 ...
# 1734

# %%
len(tokens_arr)
# Out:
# 5

# %%
# flatten bag of words
common= sum(tokens_arr, [])
common

# %%
bow_1 = vectorizer(common, df_1)

# %%
len(bow_1)
# Out:
# 217

# %%
arr_1=[]
for i in range(len(bow_1)):
  arr_1.append(1)

# %%
bow_2 = vectorizer(common, df_2)

# %%
arr_2=[]
for i in range(len(bow_2)):
  arr_2.append(2)

# %%
bow_3 = vectorizer(common, df_3)

# %%
arr_3=[]
for i in range(len(bow_3)):
  arr_3.append(3)

# %%
bow_4 = vectorizer(common, df_4)

# %%
arr_4=[]
for i in range(len(bow_4)):
  arr_4.append(4)

# %%
bow_5 = vectorizer(common, df_5)

# %%
arr_5=[]
for i in range(len(bow_5)):
  arr_5.append(5)

# %%
data={'Reviews':df_1['reviewText'],
      'Token_Vector': bow_1,
      'Rating':arr_1}
df1_dataset = pd.DataFrame(data)
df1_dataset.head()
# Out:
#                                                Reviews  Token_Vector  Rating
# 52   it hums crackles and i think im having problem...        413234       1
# 89   im a procheapo and i hated this thing theyre n...        346160       1
# 223  received it in time standard blister packaging...         20636       1
# 224  these things are terrible one wouldnt fit in m...        346160       1
# 408  this is a cheap piece of junk that does what i...        369805       1

# %%
data={'Reviews':df_2['reviewText'],
      'Token_Vector': bow_2,
      'Rating':arr_2}
df2_dataset = pd.DataFrame(data)
df2_dataset.head()
# Out:
#                                                Reviews  Token_Vector  Rating
# 15   i bought this to use with my keyboard i wasnt ...         20636       2
# 50   i didnt expect this cable to be so thin its ea...        987913       2
# 98   i bought this for my canon vixia hf g10 video ...        563117       2
# 144  i got 3 of these to plug xlr cables into the 1...        609355       2
# 286  the handle and spring strength make this uncom...         35838       2

# %%
data={'Reviews':df_3['reviewText'],
      'Token_Vector': bow_3,
      'Rating':arr_3}
df3_dataset = pd.DataFrame(data)
df3_dataset.head()
# Out:
#                                               Reviews  Token_Vector  Rating
# 7   i now use this cable to run from the output of...        602996       3
# 12  if you are not use to using a large sustaining...        731413       3
# 59  works for practice  its a guitar instrument ca...        936646       3
# 71  unbalanced guitar cable is notoriously noisy e...         81221       3
# 74  its a cable no frills tangles pretty easy and ...         20636       3

# %%
len(common)
# Out:
# 2564

# %%
data={'Reviews':df_4['reviewText'],
      'Token_Vector': bow_4,
      'Rating':arr_4}
df4_dataset = pd.DataFrame(data)
df4_dataset.head()
# Out:
#                                               Reviews  Token_Vector  Rating
# 11  i got it to have it if i needed it i have foun...        789251       4
# 16  this fender cable is the perfect length for me...         75053       4
# 20  this is a cool looking cheap cable which works...         20636       4
# 22  very good cable well made and it looks great w...         20636       4
# 25  cant go wrong great quality on a budget price ...         43320       4

# %%
data={'Reviews':df_5['reviewText'],
      'Token_Vector': bow_5,
      'Rating':arr_5}
df5_dataset = pd.DataFrame(data)
df5_dataset.head()
# Out:
#                                              Reviews  Token_Vector  Rating
# 0  not much to write about here but it does exact...        388518       5
# 1  the product does exactly as it should and is q...        369805       5
# 2  the primary job of this device is to block the...        369805       5
# 3  nice windscreen protects my mxl mic and preven...        413234       5
# 4  this pop filter is great it looks and performs...        367907       5

# %%
df_dataset = []

# %%
df_dataset = df1_dataset.append(df2_dataset)

# %%
df_dataset = df_dataset.append(df3_dataset)

# %%
df_dataset = df_dataset.append(df4_dataset)

# %%
df_dataset = df_dataset.append(df5_dataset)

# %%
df_dataset
# Out:
#                                                  Reviews  Token_Vector  Rating
# 52     it hums crackles and i think im having problem...        413234       1
# 89     im a procheapo and i hated this thing theyre n...        346160       1
# 223    received it in time standard blister packaging...         20636       1
# 224    these things are terrible one wouldnt fit in m...        346160       1
# 408    this is a cheap piece of junk that does what i...        369805       1
# ...                                                  ...           ...     ...
# 10251  true to phosphor bronze these strings have a m...        563117       5
# 10252  ive used elixirs for about five years now this...        563117       5
# 10254  i really like these strings  while they are no...        413234       5
# 10256               great just as expected  thank to all        667333       5
# 10257  ive been thinking about trying the nanoweb str...        369805       5
#
# [10261 rows x 3 columns]

# %%
df_dataset.to_csv('music_dataset.csv')

# %% [markdown]
# ## NEGATION PHRASES

# %%
negation_list = ['no', 'not', 'none', 'nobody', 'nothing', 'neither', 'nowhere', 'never', 'hardly', 'scarcely', 'barely', 'doesnt', 'isnt', 'wasnt', 'shouldnt', 'wouldnt', 'couldnt', 'wont', 'cant', 'dont']
def neg_tokens(df):
  t = word_tokens(df)
  df_neg_tokens = []
  for i in range(0,len(t)-1):
    if t[i][0] in negation_list:
      df_neg_tokens.append((t[i][0],t[i+1][0]))
      
  return df_neg_tokens

# %%
df1_neg = neg_tokens(df_1)
df2_neg = neg_tokens(df_2)
df3_neg = neg_tokens(df_3)
df4_neg = neg_tokens(df_4)
df5_neg = neg_tokens(df_5)

# %%
def most_common_tokens_neg(tokens, df):
  #tokens=word_tokens(df)
  Count = Counter(tokens)
  # take 25% of the top words
  most_occur = Count.most_common(int(len(df)*0.25))
  print(most_occur)
  common = []
  common_plus = []

  for i in most_occur:
    common.append(i[0])
    common_plus.append(i)
  return common, most_occur

# %%
df1_MC, x1 = most_common_tokens_neg(df1_neg, df_1)
# Out:
# [(('not', 'work'), 9), (('not', 'use'), 8), (('not', 'buy'), 8), (('not', 'even'), 8), (('not', 'only'), 6), (('not', 'going'), 5), (('not', 'very'), 5), (('not', 'sure'), 4), (('not', 'be'), 4), (('not', 'recommend'), 4), (('not', 'i'), 4), (('never', 'seen'), 3), (('not', 'good'), 3), (('never', 'buy'), 3), (('dont', 'know'), 3), (('doesnt', 'seem'), 3), (('not', 'have'), 3), (('doesnt', 'have'), 3), (('never', 'had'), 3), (('not', 'as'), 3), (('not', 'really'), 3), (('dont', 'recommend'), 2), (('not', 'hold'), 2), (('cant', 'have'), 2), (('not', 'get'), 2), (('not', 'find'), 2), (('not', 'do'), 2), (('cant', 'get'), 2), (('not', 'fit'), 2), (('not', 'working'), 2), (('cant', 'believe'), 2), (('not', 'where'), 2), (('not', 'how'), 2), (('not', 'just'), 2), (('dont', 'even'), 2), (('not', 'maybe'), 2), (('never', 'heard'), 2), (('not', 'display'), 2), (('cant', 'is'), 2), (('not', 'appear'), 2), (('not', 'afford'), 2), (('never', 'again'), 2), (('no', 'longer'), 2), (('never', 'did'), 2), (('not', 'durable'), 2), (('dont', 'need'), 2), (('dont', 'see'), 2), (('doesnt', 'workbuy'), 1), (('barely', 'more'), 1), (('not', 'twenty'), 1), (('not', 'schaller1'), 1), (('wasnt', 'forced'), 1), (('not', 'come'), 1), (('doesnt', 'very'), 1)]

# %%
df2_MC, x2 = most_common_tokens_neg(df2_neg, df_2)
# Out:
# [(('not', 'recommend'), 8), (('not', 'good'), 8), (('not', 'be'), 8), (('not', 'have'), 8), (('not', 'sure'), 7), (('not', 'very'), 7), (('not', 'so'), 7), (('not', 'great'), 6), (('not', 'work'), 5), (('not', 'fit'), 5), (('not', 'enough'), 5), (('not', 'is'), 5), (('not', 'get'), 4), (('not', 'i'), 3), (('not', 'only'), 3), (('not', 'much'), 3), (('dont', 'sound'), 3), (('not', 'put'), 3), (('not', 'hold'), 3), (('not', 'happy'), 3), (('wouldnt', 'recommend'), 3), (('not', 'just'), 3), (('not', 'use'), 3), (('dont', 'really'), 3), (('not', 'going'), 3), (('not', 'even'), 3), (('doesnt', 'as'), 2), (('dont', 'particularly'), 2), (('not', 'thats'), 2), (('doesnt', 'need'), 2), (('dont', 'play'), 2), (('doesnt', 'really'), 2), (('not', 'buy'), 2), (('not', 'sound'), 2), (('dont', 'not'), 2), (('dont', 'buy'), 2), (('dont', 'get'), 2), (('doesnt', 'fit'), 2), (('not', 'too'), 2), (('not', 'break'), 2), (('wouldnt', 'be'), 2), (('not', 'catch'), 2), (('dont', 'have'), 2), (('not', 'bad'), 2), (('not', 'comfortable'), 2), (('not', 'using'), 2), (('never', 'used'), 2), (('doesnt', 'come'), 2), (('never', 'buy'), 2), (('dont', 'bend'), 2), (('not', 'impressed'), 2), (('not', 'worth'), 2), (('cant', 'expect'), 2), (('never', 'had'), 2), (('not', 'extra'), 2), (('isnt', 'very'), 2), (('dont', 'so'), 2), (('never', 'felt'), 2), (('wasnt', 'really'), 1), (('nowhere', 'closein'), 1), (('not', 'long'), 1), (('wasnt', 'have'), 1)]

# %%
df3_MC, x3 = most_common_tokens_neg(df3_neg, df_3)
# Out:
# [(('not', 'sure'), 26), (('not', 'bad'), 21), (('not', 'have'), 18), (('not', 'as'), 16), (('not', 'be'), 15), (('dont', 'have'), 14), (('not', 'really'), 14), (('not', 'very'), 14), (('not', 'great'), 13), (('not', 'much'), 13), (('dont', 'know'), 12), (('not', 'so'), 11), (('not', 'recommend'), 9), (('not', 'fit'), 9), (('not', 'use'), 9), (('dont', 'think'), 8), (('never', 'had'), 8), (('not', 'good'), 8), (('not', 'get'), 8), (('not', 'is'), 8), (('not', 'i'), 8), (('dont', 'need'), 8), (('not', 'too'), 7), (('not', 'big'), 7), (('not', 'buy'), 7), (('not', 'are'), 7), (('not', 'work'), 7), (('wouldnt', 'recommend'), 7), (('cant', 'get'), 7), (('not', 'even'), 6), (('not', 'same'), 6), (('dont', 'get'), 6), (('dont', 'expect'), 6), (('not', 'enough'), 6), (('not', 'going'), 6), (('not', 'high'), 5), (('dont', 'really'), 5), (('cant', 'go'), 5), (('cant', 'really'), 5), (('dont', 'feel'), 5), (('not', 'come'), 5), (('not', 'greatest'), 5), (('dont', 'use'), 5), (('dont', 'seem'), 5), (('doesnt', 'seem'), 5), (('not', 'quite'), 4), (('not', 'seem'), 4), (('cant', 'say'), 4), (('not', 'not'), 4), (('not', 'was'), 4), (('not', 'want'), 4), (('not', 'easy'), 4), (('not', 'expensive'), 4), (('not', 'sound'), 4), (('wouldnt', 'be'), 4), (('dont', 'is'), 4), (('doesnt', 'have'), 4), (('not', 'comfortable'), 4), (('wasnt', 'expecting'), 4), (('never', 'use'), 4), (('not', 'nice'), 4), (('not', 'using'), 3), (('not', 'best'), 3), (('dont', 'see'), 3), (('not', 'more'), 3), (('not', 'stay'), 3), (('doesnt', 'is'), 3), (('not', 'been'), 3), (('couldnt', 'get'), 3), (('never', 'really'), 3), (('doesnt', 'i'), 3), (('dont', 'last'), 3), (('cant', 'be'), 3), (('dont', 'much'), 3), (('doesnt', 'as'), 3), (('not', 'super'), 3), (('not', 'make'), 3), (('not', 'other'), 3), (('isnt', 'bad'), 3), (('not', 'mention'), 3), (('no', 'longer'), 3), (('not', 'useful'), 3), (('not', 'most'), 3), (('doesnt', 'add'), 3), (('not', 'say'), 3), (('wasnt', 'looking'), 3), (('dont', 'buy'), 3), (('dont', 'sound'), 3), (('dont', 'do'), 3), (('dont', 'want'), 3), (('not', 'im'), 3), (('cant', 'afford'), 3), (('not', 'cheap'), 3), (('not', 'worth'), 3), (('shouldnt', 'have'), 3), (('not', 'getting'), 3), (('not', 'used'), 3), (('not', 'mic'), 3), (('dont', 'mind'), 3), (('not', 'stiff'), 3), (('dont', 'just'), 3), (('not', 'incredibly'), 3), (('not', 'only'), 3), (('not', 'give'), 2), (('not', 'do'), 2), (('dont', 'own'), 2), (('couldnt', 'even'), 2), (('not', 'up'), 2), (('not', 'noisy'), 2), (('not', 'ill'), 2), (('not', 'top'), 2), (('not', 'just'), 2), (('not', 'found'), 2), (('dont', 'take'), 2), (('not', 'like'), 2), (('not', 'actually'), 2), (('not', 'appear'), 2), (('not', 'spend'), 2), (('not', 'well'), 2), (('wasnt', 'impressed'), 2), (('not', 'when'), 2), (('not', 'thought'), 2), (('never', 'know'), 2), (('not', 'cost'), 2), (('not', 'always'), 2), (('doesnt', 'really'), 2), (('not', 'strong'), 2), (('cant', 'play'), 2), (('not', 'put'), 2), (('not', 'play'), 2), (('never', 'have'), 2), (('wont', 'get'), 2), (('not', 'especially'), 2), (('doesnt', 'sound'), 2), (('nowhere', 'near'), 2), (('wont', 'be'), 2), (('not', 'exactly'), 2), (('not', 'ive'), 2), (('not', 'keep'), 2), (('not', 'huge'), 2), (('dont', 'adjust'), 2), (('not', 'heavy'), 2), (('dont', 'bother'), 2), (('isnt', 'best'), 2), (('dont', 'i'), 2), (('doesnt', 'mean'), 2), (('doesnt', 'appear'), 2), (('not', 'realize'), 2), (('dont', 'are'), 2), (('dont', 'even'), 2), (('not', 'expected'), 2), (('barely', 'fits'), 2), (('not', 'professional'), 2), (('not', 'need'), 2), (('wont', 'notice'), 2), (('dont', 'am'), 2), (('not', 'specific'), 2), (('not', 'ideal'), 2), (('dont', 'too'), 2), (('wasnt', 'even'), 2), (('wouldnt', 'just'), 2), (('wouldnt', 'buy'), 2), (('not', 'acoustic'), 2), (('couldnt', 'tell'), 2), (('not', 'stop'), 2), (('wont', 'find'), 2), (('not', 'respond'), 2), (('not', 'feel'), 2), (('isnt', 'much'), 2), (('not', 'pedal'), 2), (('doesnt', 'pick'), 2), (('not', 'made'), 2 ...

# %%
df4_MC, x4 = most_common_tokens_neg(df4_neg, df_4)
# Out:
# [(('not', 'have'), 47), (('not', 'sure'), 44), (('not', 'be'), 41), (('dont', 'have'), 37), (('not', 'so'), 33), (('not', 'as'), 30), (('not', 'too'), 29), (('not', 'bad'), 27), (('not', 'much'), 24), (('not', 'very'), 24), (('dont', 'think'), 23), (('dont', 'know'), 23), (('not', 'quite'), 22), (('not', 'best'), 20), (('not', 'really'), 20), (('not', 'is'), 19), (('wont', 'be'), 19), (('not', 'big'), 19), (('not', 'going'), 18), (('never', 'had'), 17), (('dont', 'want'), 17), (('not', 'work'), 16), (('not', 'only'), 16), (('not', 'use'), 16), (('not', 'great'), 16), (('dont', 'need'), 15), (('not', 'i'), 14), (('cant', 'go'), 13), (('not', 'even'), 12), (('cant', 'really'), 12), (('not', 'had'), 12), (('dont', 'expect'), 11), (('doesnt', 'have'), 11), (('not', 'want'), 11), (('dont', 'really'), 10), (('not', 'good'), 10), (('cant', 'beat'), 10), (('no', 'longer'), 10), (('not', 'fit'), 10), (('not', 'being'), 10), (('not', 'get'), 9), (('not', 'hard'), 9), (('dont', 'is'), 9), (('cant', 'be'), 9), (('dont', 'use'), 9), (('not', 'sound'), 8), (('not', 'go'), 8), (('not', 'just'), 7), (('not', 'was'), 7), (('never', 'been'), 7), (('doesnt', 'get'), 7), (('not', 'do'), 7), (('dont', 'i'), 7), (('never', 'have'), 7), (('dont', 'be'), 7), (('not', 'easy'), 7), (('not', 'huge'), 7), (('wont', 'get'), 7), (('dont', 'get'), 6), (('doesnt', 'sound'), 6), (('never', 'used'), 6), (('dont', 'find'), 6), (('not', 'mention'), 6), (('not', 'buy'), 6), (('dont', 'even'), 6), (('not', 'many'), 6), (('isnt', 'bad'), 6), (('never', 'really'), 6), (('not', 'easily'), 6), (('cant', 'get'), 6), (('not', 'same'), 6), (('cant', 'say'), 6), (('not', 'am'), 6), (('not', 'having'), 6), (('not', 'enough'), 6), (('not', 'last'), 5), (('not', 'exactly'), 5), (('not', 'seem'), 5), (('not', 'think'), 5), (('not', 'fitting'), 5), (('not', 'find'), 5), (('dont', 'feel'), 5), (('shouldnt', 'have'), 5), (('isnt', 'really'), 5), (('not', 'cheap'), 5), (('doesnt', 'as'), 5), (('not', 'scratch'), 5), (('not', 'are'), 5), (('cant', 'see'), 5), (('never', 'heard'), 5), (('isnt', 'best'), 5), (('cant', 'make'), 5), (('not', 'high'), 5), (('cant', 'expect'), 5), (('not', 'expensive'), 5), (('wasnt', 'sure'), 5), (('never', 'use'), 5), (('not', 'stay'), 5), (('not', 'professional'), 5), (('dont', 'seem'), 4), (('not', 'ive'), 4), (('isnt', 'much'), 4), (('not', 'give'), 4), (('doesnt', 'much'), 4), (('doesnt', 'take'), 4), (('dont', 'when'), 4), (('not', 'does'), 4), (('not', 'playing'), 4), (('not', 'make'), 4), (('not', 'true'), 4), (('doesnt', 'seem'), 4), (('not', 'careful'), 4), (('not', 'heavy'), 4), (('not', 'using'), 4), (('not', 'perfect'), 4), (('not', 'worried'), 4), (('dont', 'much'), 4), (('not', 'change'), 4), (('not', 'pro'), 4), (('not', 'looking'), 4), (('not', 'put'), 4), (('not', 'always'), 4), (('dont', 'see'), 4), (('dont', 'put'), 4), (('not', 'used'), 4), (('wont', 'make'), 4), (('not', 'included'), 4), (('not', 'nearly'), 4), (('not', 'try'), 4), (('not', 'most'), 4), (('not', 'likely'), 4), (('not', 'completely'), 4), (('not', 'greatest'), 3), (('not', 'reach'), 3), (('dont', 'only'), 3), (('not', 'little'), 3), (('not', 'has'), 3), (('not', 'overly'), 3), (('couldnt', 'find'), 3), (('not', 'take'), 3), (('cant', 'play'), 3), (('couldnt', 'be'), 3), (('doesnt', 'make'), 3), (('not', 'warm'), 3), (('dont', 'more'), 3), (('wont', 'find'), 3), (('not', 'damage'), 3), (('wouldnt', 'recommend'), 3), (('shouldnt', 'be'), 3), (('doesnt', 'i'), 3), (('not', 'first'), 3), (('doesnt', 'great'), 3), (('not', 'found'), 3), (('isnt', 'too'), 3), (('wouldnt', 'call'), 3), (('never', 'get'), 3), (('not', 'terrible'), 3), (('wont', 'i'), 3), (('not', 'attach'), 3), (('not', 'expecting'), 3), (('not', 'why'), 3), (('cant', 'do'), 3), (('doesnt', 'is'), 3), (('not', 'leave'), 3), (('dont', 'are'), 3), (('doesnt', 'fit'), 3), (('not', 'nice'), 3), (('doesnt', 'just'), 3), (('not', 'come'), 3), (('isnt', 'also'), 3), (('not', 'say'), 3), (('not', 'properly'), 3),  ...

# %%
df5_MC, x5 = most_common_tokens_neg(df5_neg, df_5)
# Out:
# [(('not', 'be'), 120), (('not', 'have'), 117), (('dont', 'have'), 107), (('cant', 'go'), 87), (('not', 'sure'), 79), (('not', 'much'), 76), (('not', 'only'), 74), (('not', 'too'), 70), (('wont', 'be'), 63), (('never', 'had'), 58), (('dont', 'know'), 49), (('not', 'going'), 48), (('not', 'so'), 41), (('not', 'use'), 39), (('dont', 'need'), 37), (('dont', 'think'), 37), (('dont', 'really'), 37), (('dont', 'want'), 36), (('cant', 'beat'), 36), (('not', 'really'), 35), (('not', 'get'), 32), (('not', 'as'), 30), (('not', 'are'), 30), (('dont', 'get'), 29), (('not', 'i'), 29), (('cant', 'say'), 29), (('not', 'is'), 29), (('not', 'bad'), 28), (('not', 'just'), 28), (('not', 'very'), 27), (('never', 'have'), 27), (('no', 'longer'), 27), (('couldnt', 'be'), 26), (('not', 'big'), 26), (('not', 'had'), 25), (('not', 'even'), 24), (('cant', 'be'), 23), (('not', 'need'), 23), (('never', 'used'), 22), (('not', 'work'), 22), (('not', 'good'), 21), (('not', 'having'), 21), (('not', 'want'), 21), (('dont', 'see'), 20), (('dont', 'use'), 20), (('not', 'like'), 19), (('doesnt', 'have'), 18), (('not', 'best'), 18), (('not', 'quite'), 18), (('not', 'come'), 18), (('not', 'using'), 16), (('dont', 'even'), 16), (('wouldnt', 'be'), 16), (('cant', 'really'), 16), (('not', 'better'), 15), (('dont', 'is'), 15), (('cant', 'believe'), 14), (('not', 'do'), 14), (('cant', 'get'), 14), (('not', 'expect'), 14), (('never', 'use'), 14), (('not', 'fit'), 14), (('not', 'enough'), 14), (('not', 'used'), 14), (('not', 'cheap'), 14), (('not', 'go'), 13), (('not', 'being'), 13), (('not', 'disappointed'), 12), (('never', 'really'), 12), (('not', 'same'), 12), (('not', 'know'), 12), (('not', 'sound'), 12), (('not', 'mention'), 12), (('dont', 'expect'), 12), (('never', 'heard'), 12), (('wasnt', 'expecting'), 11), (('not', 'always'), 11), (('cant', 'do'), 11), (('dont', 'be'), 11), (('wont', 'have'), 11), (('not', 'hear'), 11), (('not', 'hold'), 11), (('not', 'tried'), 11), (('not', 'love'), 10), (('doesnt', 'seem'), 10), (('never', 'been'), 10), (('not', 'not'), 10), (('not', 'buy'), 10), (('not', 'regret'), 10), (('doesnt', 'do'), 10), (('wont', 'regret'), 10), (('dont', 'break'), 10), (('dont', 'i'), 10), (('dont', 'are'), 10), (('not', 'more'), 10), (('not', 'playing'), 10), (('doesnt', 'get'), 10), (('couldnt', 'find'), 9), (('not', 'great'), 9), (('not', 'seem'), 9), (('not', 'make'), 9), (('not', 'getting'), 9), (('not', 'believe'), 9), (('isnt', 'much'), 9), (('not', 'last'), 9), (('never', 'thought'), 9), (('not', 'overly'), 9), (('not', 'find'), 9), (('couldnt', 'get'), 9), (('doesnt', 'come'), 9), (('not', 'necessarily'), 8), (('never', 'go'), 8), (('never', 'owned'), 8), (('not', 'beat'), 8), (('not', 'feel'), 8), (('not', 'expensive'), 8), (('never', 'played'), 8), (('not', 'perfect'), 8), (('dont', 'play'), 8), (('dont', 'buy'), 8), (('dont', 'sound'), 8), (('not', 'true'), 8), (('not', 'turn'), 8), (('cant', 'see'), 8), (('not', 'damage'), 8), (('not', 'disappoint'), 8), (('not', 'try'), 8), (('not', 'has'), 8), (('never', 'failed'), 7), (('cant', 'find'), 7), (('doesnt', 'is'), 7), (('not', 'scratch'), 7), (('dont', 'let'), 7), (('dont', 'come'), 7), (('dont', 'worry'), 7), (('not', 'hesitate'), 7), (('never', 'let'), 7), (('dont', 'feel'), 7), (('not', 'take'), 7), (('not', 'been'), 7), (('not', 'say'), 7), (('cant', 'is'), 7), (('not', 'ive'), 7), (('not', 'does'), 7), (('cant', 'have'), 7), (('dont', 'often'), 7), (('dont', 'go'), 7), (('not', 'was'), 7), (('doesnt', 'leave'), 6), (('not', 'professional'), 6), (('not', 'put'), 6), (('not', 'flimsy'), 6), (('isnt', 'too'), 6), (('not', 'when'), 6), (('wasnt', 'really'), 6), (('cant', 'hear'), 6), (('dont', 'other'), 6), (('not', 'allow'), 6), (('not', 'most'), 6), (('doesnt', 'really'), 6), (('wasnt', 'sure'), 6), (('not', 'found'), 6), (('not', 'let'), 6), (('dont', 'too'), 6), (('wont', 'go'), 6), (('not', 'super'), 6), (('not', 'real'), 6), (('never', 'tried'), 6), (('not', 'recommend'), 6), (('not', ...

# %%
# create negative bag of words
neg_BOW = []
neg_BOW.append(df1_MC)
neg_BOW.append(df2_MC)
neg_BOW.append(df3_MC)
neg_BOW.append(df4_MC)
neg_BOW.append(df5_MC)

# %%
# create flat bag of words
common_neg= sum(neg_BOW, [])
common_neg

# %%
def POS_tagger_neg(reviews_tok):
  
  tag = []
  # parts of speech tagging
  for i in reviews_tok:
    temp = []
    #print(i)
    val = nltk.pos_tag(i)
    for j in val:
      # not sure what caused this error, but for some reason, some values of j did not return a tuple
      if len(j) == 2:
          temp.append(j)
    tag.append(temp)
  return tag

# %%
df1_rev_tok = tokenizer_(df_1)
df1_sent_tok = POS_tagger_neg(df1_rev_tok)

# %%
df1_sent_tok
# Out:
# [[('it', 'PRP'),
#   ('hums', 'VBD'),
#   ('crackles', 'NNS'),
#   ('and', 'CC'),
#   ('i', 'JJ'),
#   ('think', 'VBP'),
#   ('im', 'JJ'),
#   ('having', 'VBG'),
#   ('problems', 'NNS'),
#   ('with', 'IN'),
#   ('my', 'PRP$'),
#   ('equipment', 'NN'),
#   ('as', 'RB'),
#   ('soon', 'RB'),
#   ('as', 'IN'),
#   ('i', 'JJ'),
#   ('use', 'VBP'),
#   ('any', 'DT'),
#   ('of', 'IN'),
#   ('my', 'PRP$'),
#   ('other', 'JJ'),
#   ('cords', 'NNS'),
#   ('then', 'RB'),
#   ('the', 'DT'),
#   ('problem', 'NN'),
#   ('is', 'VBZ'),
#   ('gone', 'VBN'),
#   ('hosa', 'JJ'),
#   ('makes', 'VBZ'),
#   ('some', 'DT'),
#   ('other', 'JJ'),
#   ('products', 'NNS'),
#   ('that', 'WDT'),
#   ('have', 'VBP'),
#   ('good', 'JJ'),
#   ('value', 'NN'),
#   ('but', 'CC'),
#   ('based', 'VBN'),
#   ('on', 'IN'),
#   ('my', 'PRP$'),
#   ('experience', 'NN'),
#   ('i', 'NN'),
#   ('dont', 'VBP'),
#   ('recommend', 'VB'),
#   ('this', 'DT'),
#   ('one', 'CD')],
#  [('im', 'VB'),
#   ('a', 'DT'),
#   ('procheapo', 'NN'),
#   ('and', 'CC'),
#   ('i', 'NN'),
#   ('hated', 'VBD'),
#   ('this', 'DT'),
#   ('thing', 'NN'),
#   ('theyre', 'NN'),
#   ('noisy', 'NN'),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('cables', 'NNS'),
#   ('feel', 'VBP'),
#   ('really', 'RB'),
#   ('cheap', 'JJ'),
#   ('gummylike', 'NN'),
#   ('drop', 'NN'),
#   ('few', 'JJ'),
#   ('more', 'JJR'),
#   ('bucks', 'NNS'),
#   ('and', 'CC'),
#   ('get', 'VB'),
#   ('something', 'NN'),
#   ('else', 'RB')],
#  [('received', 'VBD'),
#   ('it', 'PRP'),
#   ('in', 'IN'),
#   ('time', 'NN'),
#   ('standard', 'JJ'),
#   ('blister', 'NN'),
#   ('packaging', 'NN'),
#   ('but', 'CC'),
#   ('the', 'DT'),
#   ('cable', 'NN'),
#   ('stopped', 'VBD'),
#   ('working', 'VBG'),
#   ('after', 'IN'),
#   ('45', 'CD'),
#   ('days', 'NNS'),
#   ('since', 'IN'),
#   ('i', 'NN'),
#   ('was', 'VBD'),
#   ('out', 'IN'),
#   ('of', 'IN'),
#   ('30', 'CD'),
#   ('days', 'NNS'),
#   ('return', 'VBP'),
#   ('time', 'NN'),
#   ('sent', 'VBD'),
#   ('an', 'DT'),
#   ('email', 'NN'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('manufacturer', 'NN'),
#   ('but', 'CC'),
#   ('no', 'DT'),
#   ('response', 'NN'),
#   ('till', 'NN'),
#   ('today', 'NN')],
#  [('these', 'DT'),
#   ('things', 'NNS'),
#   ('are', 'VBP'),
#   ('terrible', 'JJ'),
#   ('one', 'CD'),
#   ('wouldnt', 'NN'),
#   ('fit', 'NN'),
#   ('in', 'IN'),
#   ('my', 'PRP$'),
#   ('soundboard', 'NN'),
#   ('another', 'DT'),
#   ('wouldnt', 'NN'),
#   ('lock', 'NN'),
#   ('in', 'IN'),
#   ('my', 'PRP$'),
#   ('mic', 'JJ'),
#   ('plain', 'NN'),
#   ('and', 'CC'),
#   ('simpleif', 'VB'),
#   ('your', 'PRP$'),
#   ('looking', 'VBG'),
#   ('for', 'IN'),
#   ('crap', 'NN'),
#   ('that', 'WDT'),
#   ('doesnt', 'VBZ'),
#   ('workbuy', 'VBP'),
#   ('this', 'DT')],
#  [('this', 'DT'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('cheap', 'JJ'),
#   ('piece', 'NN'),
#   ('of', 'IN'),
#   ('junk', 'NN'),
#   ('that', 'WDT'),
#   ('does', 'VBZ'),
#   ('what', 'WP'),
#   ('it', 'PRP'),
#   ('says', 'VBZ'),
#   ('it', 'PRP'),
#   ('distorts', 'VBZ'),
#   ('you', 'PRP'),
#   ('want', 'VBP'),
#   ('something', 'NN'),
#   ('to', 'TO'),
#   ('make', 'VB'),
#   ('your', 'PRP$'),
#   ('guitar', 'NN'),
#   ('sound', 'NN'),
#   ('like', 'IN'),
#   ('junk', 'NN'),
#   ('this', 'DT'),
#   ('will', 'MD'),
#   ('do', 'VB'),
#   ('it', 'PRP'),
#   ('why', 'WRB'),
#   ('pedals', 'NNS'),
#   ('that', 'WDT'),
#   ('make', 'VBP'),
#   ('your', 'PRP$'),
#   ('guitar', 'NN'),
#   ('sound', 'NN'),
#   ('like', 'IN'),
#   ('a', 'DT'),
#   ('piece', 'NN'),
#   ('of', 'IN'),
#   ('junk', 'NN'),
#   ('are', 'VBP'),
#   ('the', 'DT'),
#   ('most', 'RBS'),
#   ('popular', 'JJ'),
#   ('is', 'VBZ'),
#   ('beyond', 'IN'),
#   ('me', 'PRP'),
#   ('this', 'DT'),
#   ('is', 'VBZ'),
#   ('not', 'RB'),
#   ('a', 'DT'),
#   ('boutique', 'NN'),
#   ('distortion', 'NN'),
#   ('pedal', 'IN'),
#   ('like', 'IN'),
#   ('hendrix', 'NN'),
#   ('would', 'MD'),
#   ('use', 'VB'),
#   ('boutique', 'NN'),
#   ('and', 'CC'),
#   ('distortion', 'NN'),
#   ('are', 'VBP'),
#   ('an', 'DT'),
#   ('oxymoronthese', 'JJ'),
#   ('things', 'NNS'),
#   ('are', 'VBP'),
#   ('built', 'VBN'),
#   ('with', 'IN'),
#   ('heavy', 'JJ'),
#   ('metal', 'NN'),
#   ('it', 'PRP'),
#   ('should', 'MD'),
#   ('last', 'JJ'),
#   ('i', 'JJ'),
#   ('kinda', 'VBD'),
#   ('hope', 'NN'),
#   ('it', 'PRP'),
#   ('doesntjust', 'VBZ'),
#   ('kidding', 'VBG'),
#   ('you', 'PRP'),
#   ('want', 'VBP'),
#   ('distortion', 'NN'),
#   ('you', 'PRP'),
#   ('got', 'VBD'),
#   ('distortion', 'NN')],
#  [('heres', 'VBZ'),
#   ('the', 'DT'),
#   ('deal', 'NN'),
#   ('with', 'IN'),
#   ('this', 'DT'),
#   ('pedal', 'NN'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('inexpensive', 'JJ'),
#   ('and', 'CC'),
#   ('you', 'PRP'),
#   ('can', 'MD'),
#   ('get', 'VB'),
#   ('a', 'DT'),
#   ('better', 'JJR'),
#   ('pedal', 'NN'),
#   ('with', 'IN'),
#   ('barely', 'RB'),
#   ('a', 'DT'),
#   ('bit', 'NN'),
#   ('more', 'JJR'),
#   ('money', 'NN'),
#   ('and', 'CC'),
#   ('sometimes', 'RB'),
#   ('a', 'DT'),
#   ('little', 'JJ'),
#   ('less', 'JJR'),
#   ('money', 'NN'),
#   ('in', 'IN'),
#   ('my', 'PRP$'),
#   ('opinion', 'NN'),
#   ('for', 'IN'),
#   ('spending', 'NN'),
#   ('less', 'JJR'),
#   ('than', 'IN'),
#   ('100', 'CD'),
#   ('for', 'IN'),
#   ('a', 'DT'),
#   ('distortion', 'NN'),
#   ('pedal', 'IN'),
#   ('whether', 'IN'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('your', 'PRP$'),
#   ('first', 'JJ'),
#   ('pedal', 'NN'),
#   ('or', 'CC'),
#   ('700th', 'CD'),
#   ('pedal', 'NN'),
#   ('a', 'DT'),
#   ('few', 'JJ'),
#   ('more', 'JJR'),
#   ('bucks', 'NNS'),
#   ('will', 'MD'),
#   ('get', 'VB'),
#   ('you', 'PRP'),
#   ('the', 'DT'),
#   ('mxr', 'JJ'),
#   ('badass', 'NN'),
#   ('distortion', 'NN'),
#   ('which', 'WDT'),
#   ('has', 'VBZ'),
#   ('a', 'DT'),
#   ('much', 'RB'),
#   ('crisper', 'JJR'),
#   ('tone', 'NN'),
#   ('to', 'TO'),
#   ('it', 'PRP')],
#  [('these', 'DT'),
#   ('came', 'VBD'),
#   ('stock', 'NN'),
#   ('on', 'IN'),
#   ('my', 'PRP$'),
#   ('jackson', 'NN'),
#   ('kelly', 'RB'),
#   ('kexmg', 'VB'),
#   ('all', 'PDT'),
#   ('the', 'DT'),
#   ('other', 'JJ'),
#   ('guitars', 'NNS'),
#   ('i', 'VBP'),
#   ('own', 'VBP'),
#   ('have', 'VBP'),
#   ('schaller', 'VBN'),
#   ('buttons', 'NNS'),
#   ('on', 'IN'),
#   ('them', 'PRP'),
#   ('and', 'CC'),
#   ('i', 'NNS'),
#   ('have', 'VBP'),
#   ('one', 'CD'),
#   ('main', 'JJ'),
#   ('strap', 'NN'),
#   ('i', 'NN'),
#   ('use', 'NN'),
#   ('for', 'IN'),
#   ('all', 'DT'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('guitars', 'NNS'),
#   ('i', 'VBP'),
#   ('figured', 'VBN'),
#   ('since', 'IN'),
#   ('the', 'DT'),
#   ('guitar', 'NN'),
#   ('came', 'VBD'),
#   ('with', 'IN'),
#   ('them', 'PRP'),
#   ('i', 'NNS'),
#   ('would', 'MD'),
#   ('try', 'VB'),
#   ('them', 'PRP'),
#   ('out', 'RP'),
#   ('not', 'RB'),
#   ('twenty', 'RB'),
#   ('min', 'NN'),
#   ('later', 'RB'),
#   ('i', 'NN'),
#   ('was', 'VBD'),
#   ('removing', 'VBG'),
#   ('them', 'PRP'),
#   ('and', 'CC'),
#   ('putting', 'VBG'),
#   ('schaller', 'NN'),
#   ('buttons', 'NNS'),
#   ('in', 'IN'),
#   ('their', 'PRP$'),
#   ('place', 'NN'),
#   ('here', 'RB'),
#   ('the', 'DT'),
#   ('3', 'CD'),
#   ('major', 'JJ'),
#   ('reasons', 'NNS'),
#   ('i', 'VBP'),
#   ('did', 'VBD'),
#   ('not', 'RB'),
#   ('like', 'IN'),
#   ('them', 'PRP'),
#   ('over', 'RP'),
#   ('schaller1', 'JJ'),
#   ('bulky', 'NN'),
#   ('they', 'PRP'),
#   ('stick', 'VBP'),
#   ('out', 'RP'),
#   ('too', 'RB'),
#   ('far', 'RB'),
#   ('and', 'CC'),
#   ('on', 'IN'),
#   ('any', 'DT'),
#   ('guitar', 'NN'),
#   ('with', 'IN'),
#   ('a', 'DT'),
#   ('strap', 'JJ'),
#   ('button', 'NN'),
#   ('on', 'IN'),
#   ('the', 'DT'),
#   ('back', 'NN'),
#   ('it', 'PRP'),
#   ('jabs', 'VBZ'),
#   ('you', 'PRP'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('stomach', 'NN'),
#   ('or', 'CC'),
#   ('below2', 'NN'),
#   ('problems', 'NNS'),
#   ('engaging', 'VBG'),
#   ('i', 'NN'),
#   ('would', 'MD'),
#   ('push', 'VB'),
#   ('them', 'PRP'),
#   ('into', 'IN'),
#   ('the', 'DT'),
#   ('receiver', 'NN'),
#   ('and', 'CC'),
#   ('they', 'PRP'),
#   ('pop', 'VBP'),
#   ('back', 'RB'),
#   ('out', 'IN'),
#   ('it', 'PRP'),
#   ('wasnt', 'VBZ'),
#   ('until', 'IN'),
#   ('i', 'NNS'),
#   ('forced', 'VBD'),
#   ('them', 'PRP'),
#   ('in', 'IN'),
#   ('while', 'IN'),
#   ('pushing', 'VBG'),
#   ('the', 'DT'),
#   ('button', 'NN'),
#   ('that', 'IN'),
#   ('they', 'PRP'),
#   ('went', 'VBD'),
#   ('in', 'IN'),
#   ('a', 'DT'),
#   ('stayed', 'NN'),
#   ('in', 'IN'),
#   ('schallers', 'NNS'),
#   ('click', 'VBP'),
#   ('in', 'IN'),
#   ('and', 'CC'),
#   ('you', 'PRP'),
#   ('know', 'VBP'),
#   ('they', 'PRP'),
#   ('are', 'VBP'),
#   ('ready', 'JJ'),
#   ('to', 'TO'),
#   ('go3', 'VB'),
#   ('cheap', 'JJ'),
#   ('they', 'PRP'),
#   ('just', 'RB'),
#   ('feel', 'VB'),
#   ('cheap', 'RB'),
#   ('thin', 'JJ'),
#   ('metal', 'NN'),
#   ('is', 'VBZ'),
#   ('used', 'VBN'),
#   ('in', 'IN'),
#   ('comparison', 'NN'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('schallers', 'NNS'),
#   ('which', 'WDT'),
#   ('have', 'VBP'),
#   ('a', 'DT'),
#   ('very', 'RB'),
#   ('heavy', 'JJ'),
#   ('and', 'CC'),
#   ('solid', 'JJ'),
#   ('feel', 'NN'),
#   ('to', 'TO'),
#   ('themfor', 'VB'),
#   ('a', 'DT'),
#   ('few', 'JJ'),
#   ('bucks', 'NNS'),
#   ('more', 'RBR'),
#   ('ill', 'JJ'),
#   ('stick', 'NN'),
#   ('with', 'IN'),
#   ('schallers', 'NNS'),
#   ('i', 'NNS'),
#   ('have', 'VBP'),
#   ('been', 'VBN'),
#   ('using', 'VBG'),
#   ('them', 'PRP'),
#   ('for', 'IN'),
#   ('10', 'CD'),
#   ('years', 'NNS'),
#   ('and', 'CC'),
#   ('have', 'VBP'),
#   ('never', 'RB'),
#   ('seen', 'VBN'),
#   ('one', 'CD'),
#   ('fail', 'NN')],
#  [('i', 'NN'),
#   ('purchased', 'VBD'),
#   ('this', 'DT'),
#   ('after', 'IN'),
#   ('reading', 'VBG'),
#   ('the', 'DT'),
#   ('great', 'JJ'),
#   ('reviews', 'NNS'),
#   ('but', 'CC'),
#   ('like', 'IN'),
#   ('a', 'DT'),
#   ('few', 'JJ'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('comments', 'NNS'),
#   ('that', 'WDT'),
#   ('are', 'VBP'),
#   ('on', 'IN'),
#   ('here', 'RB'),
#   ('lately', 'RB'),
#   ('this', 'DT'),
#   ('thing', 'NN'),
#   ('is', 'VBZ'),
#   ('not', 'RB'),
#   ('good', 'JJ'),
#   ('looked', 'VBD'),
#   ('almost', 'RB'),
#   ('used', 'VBN'),
#   ('when', 'WRB'),
#   ('it', 'PRP'),
#   ('arrived', 'VBD'),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('gooseneck', 'NN'),
#   ('stand', 'NN'),
#   ('is', 'VBZ'),
#   ('useless', 'JJ'),
#   ('does', 'VBZ'),
#   ('not', 'RB'),
#   ('come', 'VB'),
#   ('even', 'RB'),
#   ('close', 'RB'),
#   ('to', 'TO'),
#   ('being', 'VBG'),
#   ('able', 'JJ'),
#   ('to', 'TO'),
#   ('hold', 'VB'),
#   ('up', 'RP'),
#   ('the', 'DT'),
#   ('weight', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('filter', 'NN'),
#   ('i', 'NN'),
#   ('would', 'MD'),
#   ('have', 'VB'),
#   ('returned', 'VBN'),
#   ('it', 'PRP'),
#   ('but', 'CC'),
#   ('i', 'VBZ'),
#   ('completely', 'RB'),
#   ('destroyed', 'VBN'),
#   ('the', 'DT'),
#   ('package', 'NN'),
#   ('getting', 'VBG'),
#   ('it', 'PRP'),
#   ('open', 'JJ'),
#   ('which', 'WDT'),
#   ('oddly', 'RB'),
#   ('had', 'VBD'),
#   ('staples', 'NNS'),
#   ('holding', 'VBG'),
#   ('it', 'PRP'),
#   ('closed', 'VBD')],
#  [('wind', 'NN'),
#   ('screen', 'NN'),
#   ('is', 'VBZ'),
#   ('way', 'NN'),
#   ('too', 'RB'),
#   ('big', 'JJ'),
#   ('its', 'PRP$'),
#   ('bulky', 'NN'),
#   ('and', 'CC'),
#   ('to', 'TO'),
#   ('me', 'PRP'),
#   ('useless', 'IN'),
#   ('the', 'DT'),
#   ('screen', 'NN'),
#   ('came', 'VBD'),
#   ('out', 'RP'),
#   ('was', 'VBD'),
#   ('thinking', 'VBG'),
#   ('of', 'IN'),
#   ('glueing', 'VBG'),
#   ('it', 'PRP'),
#   ('back', 'RB'),
#   ('in', 'IN'),
#   ('but', 'CC'),
#   ('went', 'VBD'),
#   ('to', 'TO'),
#   ('ebay', 'VB'),
#   ('and', 'CC'),
#   ('bought', 'VBD'),
#   ('2', 'CD'),
#   ('metal', 'NN'),
#   ('mesh', 'JJ'),
#   ('pop', 'NN'),
#   ('filters', 'NNS'),
#   ('cheaper', 'VBP'),
#   ('that', 'DT'),
#   ('is', 'VBZ'),
#   ('much', 'RB'),
#   ('betteravoid', 'RBR'),
#   ('this', 'DT')],
#  [('i', 'NN'),
#   ('got', 'VBD'),
#   ('this', 'DT'),
#   ('for', 'IN'),
#   ('my', 'PRP$'),
#   ('boss', 'NN'),
#   ('loop', 'NN'),
#   ('station', 'NN'),
#   ('but', 'CC'),
#   ('it', 'PRP'),
#   ('doesnt', 'VBZ'),
#   ('work', 'NN'),
#   ('very', 'RB'),
#   ('well', 'RB'),
#   ('i', 'JJ'),
#   ('keep', 'VBP'),
#   ('hoping', 'VBG'),
#   ('ill', 'NN'),
#   ('find', 'VB'),
#   ('something', 'NN'),
#   ('it', 'PRP'),
#   ('does', 'VBZ'),
#   ('work', 'VB'),
#   ('well', 'RB'),
#   ('with', 'IN')],
#  [('long', 'RB'),
#   ('story', 'NN'),
#   ('short', 'JJ'),
#   ('this', 'DT'),
#   ('string', 'NN'),
#   ('set', 'NN'),
#   ('has', 'VBZ'),
#   ('a', 'DT'),
#   ('strong', 'JJ'),
#   ('metallic', 'NN'),
#   ('character', 'NN'),
#   ('which', 'WDT'),
#   ('distorts', 'VBZ'),
#   ('the', 'DT'),
#   ('natural', 'JJ'),
#   ('sound', 'NN'),
#   ('of', 'IN'),
#   ('your', 'PRP$'),
#   ('guitar', 'NN'),
#   ('so', 'RB'),
#   ('much', 'JJ'),
#   ('many', 'JJ'),
#   ('people', 'NNS'),
#   ('might', 'MD'),
#   ('like', 'VB'),
#   ('it', 'PRP'),
#   ('but', 'CC'),
#   ('for', 'IN'),
#   ('me', 'PRP'),
#   ('absolutely', 'RB'),
#   ('nooooooooi', 'VBP'),
#   ('have', 'VBP'),
#   ('a', 'DT'),
#   ('seagull', 'JJ'),
#   ('guitar', 'NN'),
#   ('so', 'RB'),
#   ('by', 'IN'),
#   ('its', 'PRP$'),
#   ('nature', 'NN'),
#   ('it', 'PRP'),
#   ('sounds', 'VBZ'),
#   ('mellow', 'JJ'),
#   ('warm', 'NN'),
#   ('and', 'CC'),
#   ('mild', 'NN'),
#   ('with', 'IN'),
#   ('stock', 'NN'),
#   ('strings', 'NNS'),
#   ('so', 'RB'),
#   ('when', 'WRB'),
#   ('my', 'PRP$'),
#   ('strings', 'NNS'),
#   ('wear', 'VBP'),
#   ('out', 'RP'),
#   ('i', 'JJ'),
#   ('got', 'VBD'),
#   ('this', 'DT'),
#   ('now', 'RB'),
#   ('i', 'VBZ'),
#   ('feel', 'VBP'),
#   ('like', 'IN'),
#   ('playing', 'VBG'),
#   ('an', 'DT'),
#   ('emg', 'NN'),
#   ('bridge', 'NN'),
#   ('on', 'IN'),
#   ('my', 'PRP$'),
#   ('fenderarchtops', 'NNS'),
#   ('neck', 'DT'),
#   ('position', 'NN'),
#   ('without', 'IN'),
#   ('the', 'DT'),
#   ('power', 'NN'),
#   ('that', 'IN'),
#   ('an', 'DT'),
#   ('emg', 'NN'),
#   ('pickup', 'NN'),
#   ('has', 'VBZ'),
#   ('to', 'TO'),
#   ('offer', 'VB'),
#   ('yes', 'VB'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('that', 'IN'),
#   ('bad', 'JJ'),
#   ('you', 'PRP'),
#   ('cant', 'VBP'),
#   ('do', 'VB'),
#   ('this', 'DT'),
#   ('to', 'TO'),
#   ('guitars', 'NNS'),
#   ('like', 'IN'),
#   ('seagullsbottom', 'JJ'),
#   ('line', 'NN'),
#   ('i', 'NN'),
#   ('recommend', 'VBP'),
#   ('this', 'DT'),
#   ('string', 'NN'),
#   ('set', 'VBN'),
#   ('for', 'IN'),
#   ('people', 'NNS'),
#   ('looking', 'VBG'),
#   ('to', 'TO'),
#   ('boost', 'VB'),
#   ('distortion', 'NN'),
#   ('on', 'IN'),
#   ('their', 'PRP$'),
#   ('guitar', 'NN'),
#   ('if', 'IN'),
#   ('you', 'PRP'),
#   ('have', 'VBP'),
#   ('guitars', 'NNS'),
#   ('like', 'IN'),
#   ('seagulls', 'NNS'),
#   ('or', 'CC'),
#   ('so', 'RB'),
#   ('definitely', 'RB'),
#   ('avoid', 'VB'),
#   ('this', 'DT'),
#   ('string', 'NN')],
#  [('another', 'DT'),
#   ('item', 'NN'),
#   ('never', 'RB'),
#   ('received', 'VBD'),
#   ('but', 'CC'),
#   ('i', 'NNS'),
#   ('would', 'MD'),
#   ('not', 'RB'),
#   ('use', 'VB'),
#   ('anything', 'NN'),
#   ('over', 'IN'),
#   ('88', 'CD'),
#   ('mm', 'NNS'),
#   ('anyway', 'RB'),
#   ('was', 'VBD'),
#   ('mean', 'VBN'),
#   ('for', 'IN'),
#   ('experimentation', 'NN'),
#   ('i', 'NNS'),
#   ('have', 'VBP'),
#   ('learned', 'VBN'),
#   ('since', 'IN'),
#   ('this', 'DT'),
#   ('purchase', 'NN')],
#  [('this', 'DT'),
#   ('product', 'NN'),
#   ('is', 'VBZ'),
#   ('not', 'RB'),
#   ('what', 'WP'),
#   ('it', 'PRP'),
#   ('seems', 'VBZ'),
#   ('it', 'PRP'),
#   ('has', 'VBZ'),
#   ('a', 'DT'),
#   ('cool', 'JJ'),
#   ('name', 'NN'),
#   ('but', 'CC'),
#   ('thats', 'NNS'),
#   ('about', 'IN'),
#   ('it', 'PRP'),
#   ('its', 'PRP$'),
#   ('a', 'DT'),
#   ('tool', 'NN'),
#   ('oil', 'NN'),
#   ('that', 'IN'),
#   ('stinks', 'VBZ'),
#   ('i', 'RB'),
#   ('tried', 'VBN'),
#   ('my', 'PRP$'),
#   ('best', 'JJS'),
#   ('to', 'TO'),
#   ('get', 'VB'),
#   ('use', 'NN'),
#   ('to', 'TO'),
#   ('this', 'DT'),
#   ('product', 'NN'),
#   ('but', 'CC'),
#   ('learned', 'VBD'),
#   ('that', 'IN'),
#   ('there', 'EX'),
#   ('are', 'VBP'),
#   ('much', 'JJ'),
#   ('better', 'JJR'),
#   ('ways', 'NNS'),
#   ('after', 'IN'),
#   ('going', 'VBG'),
#   ('into', 'IN'),
#   ('the', 'DT'),
#   ('studio', 'NN'),
#   ('and', 'CC'),
#   ('recording', 'NN'),
#   ('for', 'IN'),
#   ('the', 'DT'),
#   ('1st', 'CD'),
#   ('time', 'NN'),
#   ('after', 'IN'),
#   ('doing', 'VBG'),
#   ('away', 'RB'),
#   ('with', 'IN'),
#   ('the', 'DT'),
#   ('fastfret', 'JJ'),
#   ('my', 'PRP$'),
#   ('playing', 'NN'),
#   ('has', 'VBZ'),
#   ('improved', 'VBN'),
#   ('and', 'CC'),
#   ('i', 'JJ'),
#   ('hardly', 'RB'),
#   ('ever', 'RB'),
#   ('have', 'VBP'),
#   ('to', 'TO'),
#   ('change', 'VB'),
#   ('my', 'PRP$'),
#   ('string', 'NN'),
#   ('because', 'IN'),
#   ('of', 'IN'),
#   ('gook', 'NN'),
#   ('not', 'RB'),
#   ('to', 'TO'),
#   ('mention', 'VB'),
#   ('that', 'IN'),
#   ('getting', 'VBG'),
#   ('that', 'DT'),
#   ('crap', 'NN'),
#   ('on', 'IN'),
#   ('my', 'PRP$'),
#   ('fingers', 'NNS'),
#   ('was', 'VBD'),
#   ('just', 'RB'),
#   ('nasty', 'JJ'),
#   ('i', 'NN'),
#   ('now', 'RB'),
#   ('use', 'VBP'),
#   ('old', 'JJ'),
#   ('english', 'NN'),
#   ('and', 'CC'),
#   ('my', 'PRP$'),
#   ('guitars', 'NNS'),
#   ('thank', 'IN'),
#   ('me', 'PRP'),
#   ('my', 'PRP$'),
#   ('nose', 'JJ'),
#   ('thanks', 'NNS'),
#   ('me', 'PRP'),
#   ('and', 'CC'),
#   ('my', 'PRP$'),
#   ('fingers', 'NNS'),
#   ('thank', 'VB'),
#   ('me', 'PRP'),
#   ('you', 'PRP'),
#   ('will', 'MD'),
#   ('too', 'RB')],
#  [('it', 'PRP'),
#   ('just', 'RB'),
#   ('randomly', 'RB'),
#   ('pops', 'VBZ'),
#   ('off', 'IN'),
#   ('my', 'PRP$'),
#   ('bass', 'NN'),
#   ('its', 'PRP$'),
#   ('so', 'RB'),
#   ('slick', 'JJ'),
#   ('that', 'IN'),
#   ('when', 'WRB'),
#   ('you', 'PRP'),
#   ('let', 'VBP'),
#   ('go', 'VB'),
#   ('it', 'PRP'),
#   ('the', 'DT'),
#   ('neck', 'NN'),
#   ('just', 'RB'),
#   ('goes', 'VBZ'),
#   ('straight', 'RB'),
#   ('down', 'RP'),
#   ('i', 'JJ'),
#   ('hate', 'NN'),
#   ('it', 'PRP')],
#  [('years', 'NNS'),
#   ('ago', 'RB'),
#   ('i', 'VBP'),
#   ('used', 'VBD'),
#   ('the', 'DT'),
#   ('clayton', 'NN'),
#   ('34small', 'CD'),
#   ('teardrop34', 'NN'),
#   ('picks', 'NNS'),
#   ('i', 'VBP'),
#   ('couldnt', 'VBP'),
#   ('tell', 'NN'),
#   ('from', 'IN'),
#   ('the', 'DT'),
#   ('picture', 'NN'),
#   ('that', 'IN'),
#   ('these', 'DT'),
#   ('were', 'VBD'),
#   ('full', 'JJ'),
#   ('size', 'NN'),
#   ('and', 'CC'),
#   ('i', 'NN'),
#   ('didnt', 'VBP'),
#   ('check', 'VB'),
#   ('the', 'DT'),
#   ('size', 'NN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('description', 'NN'),
#   ('i', 'NN'),
#   ('still', 'RB'),
#   ('had', 'VBD'),
#   ('a', 'DT'),
#   ('few', 'JJ'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('small', 'JJ'),
#   ('ones', 'NNS'),
#   ('so', 'RB'),
#   ('i', 'RB'),
#   ('used', 'VBD'),
#   ('them', 'PRP'),
#   ('as', 'IN'),
#   ('templates', 'NNS'),
#   ('to', 'TO'),
#   ('cut', 'VB'),
#   ('these', 'DT'),
#   ('down', 'IN'),
#   ('i', 'NN'),
#   ('would', 'MD'),
#   ('have', 'VB'),
#   ('rated', 'VBN'),
#   ('them', 'PRP'),
#   ('higher', 'JJR'),
#   ('if', 'IN'),
#   ('i', 'NN'),
#   ('could', 'MD'),
#   ('have', 'VB'),
#   ('used', 'VBN'),
#   ('them', 'PRP'),
#   ('as', 'IN'),
#   ('is', 'VBZ'),
#   ('its', 'PRP$'),
#   ('my', 'PRP$'),
#   ('own', 'JJ'),
#   ('fault', 'NN'),
#   ('for', 'IN'),
#   ('not', 'RB'),
#   ('looking', 'VBG'),
#   ('at', 'IN'),
#   ('the', 'DT'),
#   ('specifications', 'NNS'),
#   ('i', 'VBP'),
#   ('purchased', 'VBN'),
#   ('two', 'CD'),
#   ('six', 'CD'),
#   ('packs', 'NNS'),
#   ('of', 'IN'),
#   ('clayton', 'NN'),
#   ('teardrop', 'NN'),
#   ('picks', 'NNS'),
#   ('but', 'CC'),
#   ('found', 'VBD'),
#   ('dunlop', 'RB'),
#   ('423r60', 'CD'),
#   ('060mm', 'CD'),
#   ('orange', 'NN'),
#   ('tortex', 'NN'),
#   ('small', 'JJ'),
#   ('tear', 'JJ'),
#   ('drop', 'NN'),
#   ('guitar', 'NN'),
#   ('picks', 'VBZ'),
#   ('36pack', 'CD'),
#   ('which', 'WDT'),
#   ('are', 'VBP'),
#   ('a', 'DT'),
#   ('lot', 'NN'),
#   ('cheaper', 'JJR')],
#  [('total', 'JJ'),
#   ('flimsy', 'JJ'),
#   ('junk', 'NN'),
#   ('it', 'PRP'),
#   ('leans', 'VBZ'),
#   ('wayyy', 'NNS'),
#   ('too', 'RB'),
#   ('far', 'RB'),
#   ('back', 'RB'),
#   ('ill', 'JJ'),
#   ('be', 'VB'),
#   ('damned', 'VBN'),
#   ('if', 'IN'),
#   ('i', 'JJ'),
#   ('put', 'VBD'),
#   ('my', 'PRP$'),
#   ('1000', 'CD'),
#   ('guitars', 'NNS'),
#   ('on', 'IN'),
#   ('these', 'DT'),
#   ('things', 'NNS'),
#   ('on', 'IN'),
#   ('the', 'DT'),
#   ('other', 'JJ'),
#   ('hand', 'NN'),
#   ('chromacast', 'NN'),
#   ('makes', 'VBZ'),
#   ('one', 'CD'),
#   ('thats', 'NNS'),
#   ('very', 'RB'),
#   ('close', 'RB'),
#   ('to', 'TO'),
#   ('this', 'DT'),
#   ('price', 'NN'),
#   ('and', 'CC'),
#   ('i', 'JJ'),
#   ('doubt', 'NN'),
#   ('that', 'IN'),
#   ('it', 'PRP'),
#   ('could', 'MD'),
#   ('have', 'VB'),
#   ('been', 'VBN'),
#   ('more', 'JJR'),
#   ('for', 'IN'),
#   ('the', 'DT'),
#   ('money', 'NN'),
#   ('i', 'NN'),
#   ('paidin', 'VBP'),
#   ('summary', 'JJ'),
#   ('do', 'VBP'),
#   ('not', 'RB'),
#   ('buy', 'VB'),
#   ('this', 'DT'),
#   ('piece', 'NN'),
#   ('of', 'IN'),
#   ('junk', 'NN')],
#  [('for', 'IN'),
#   ('something', 'NN'),
#   ('but', 'CC'),
#   ('not', 'RB'),
#   ('a', 'DT'),
#   ('guitar', 'NN'),
#   ('wasnt', 'NN'),
#   ('sure', 'JJ'),
#   ('what', 'WP'),
#   ('to', 'TO'),
#   ('do', 'VB'),
#   ('with', 'IN'),
#   ('it', 'PRP'),
#   ('so', 'IN'),
#   ('i', 'RB'),
#   ('now', 'RB'),
#   ('use', 'VBP'),
#   ('it', 'PRP'),
#   ('to', 'TO'),
#   ('mount', 'VB'),
#   ('a', 'DT'),
#   ('large', 'JJ'),
#   ('cookbook', 'NN'),
#   ('or', 'CC'),
#   ('notepad', 'JJ'),
#   ('computer', 'NN'),
#   ('so', 'IN'),
#   ('i', 'JJ'),
#   ('can', 'MD'),
#   ('follow', 'VB'),
#   ('a', 'DT'),
#   ('recipe', 'NN'),
#   ('it', 'PRP'),
#   ('seems', 'VBZ'),
#   ('to', 'TO'),
#   ('work', 'VB'),
#   ('okay', 'NN'),
#   ('for', 'IN'),
#   ('that', 'DT'),
#   ('just', 'RB'),
#   ('dont', 'NN'),
#   ('use', 'NN'),
#   ('this', 'DT'),
#   ('for', 'IN'),
#   ('guitars', 'NNS'),
#   ('an', 'DT'),
#   ('electric', 'JJ'),
#   ('guitar', 'NN'),
#   ('will', 'MD'),
#   ('slide', 'VB'),
#   ('out', 'RB'),
#   ('and', 'CC'),
#   ('fall', 'NN'),
#   ('because', 'IN'),
#   ('it', 'PRP'),
#   ('leans', 'VBZ'),
#   ('back', 'RB'),
#   ('too', 'RB'),
#   ('far', 'RB'),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('arms', 'NNS'),
#   ('have', 'VBP'),
#   ('no', 'DT'),
#   ('grip', 'NN'),
#   ('this', 'DT'),
#   ('thing', 'NN'),
#   ('was', 'VBD'),
#   ('obviously', 'RB'),
#   ('created', 'VBN'),
#   ('by', 'IN'),
#   ('a', 'DT'),
#   ('monkey', 'NN'),
#   ('in', 'IN'),
#   ('some', 'DT'),
#   ('closed', 'JJ'),
#   ('door', 'NN'),
#   ('creative', 'JJ'),
#   ('testing', 'VBG'),
#   ('experimental', 'JJ'),
#   ('project', 'NN'),
#   ('it', 'PRP'),
#   ('may', 'MD'),
#   ('even', 'RB'),
#   ('give', 'VB'),
#   ('you', 'PRP'),
#   ('aids', 'NNS'),
#   ('but', 'CC'),
#   ('probably', 'RB'),
#   ('not', 'RB'),
#   ('however', 'RB'),
#   ('animals', 'NNS'),
#   ('could', 'MD'),
#   ('have', 'VB'),
#   ('been', 'VBN'),
#   ('harmed', 'VBN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('making', 'NN'),
#   ('but', 'CC'),
#   ('most', 'RBS'),
#   ('likely', 'JJ'),
#   ('and', 'CC'),
#   ('in', 'IN'),
#   ('reality', 'NN'),
#   ('it', 'PRP'),
#   ('will', 'MD'),
#   ('not', 'RB'),
#   ('hold', 'VB'),
#   ('your', 'PRP$'),
#   ('guitar', 'NN'),
#   ('in', 'IN'),
#   ('a', 'DT'),
#   ('safe', 'JJ'),
#   ('manner', 'NN')],
#  [('i', 'NN'),
#   ('bought', 'VBD'),
#   ('a', 'DT'),
#   ('set', 'NN'),
#   ('as', 'IN'),
#   ('they', 'PRP'),
#   ('were', 'VBD'),
#   ('recommended', 'VBN'),
#   ('to', 'TO'),
#   ('get', 'VB'),
#   ('the', 'DT'),
#   ('tone', 'NN'),
#   ('i', 'NN'),
#   ('was', 'VBD'),
#   ('looking', 'VBG'),
#   ('for', 'IN'),
#   ('on', 'IN'),
#   ('my', 'PRP$'),
#   ('7', 'CD'),
#   ('week', 'NN'),
#   ('old', 'JJ'),
#   ('guitar', 'NN'),
#   ('installed', 'VBD'),
#   ('as', 'IN'),
#   ('usual', 'JJ'),
#   ('and', 'CC'),
#   ('tuned', 'VBD'),
#   ('them', 'PRP'),
#   ('they', 'PRP'),
#   ('sounded', 'VBD'),
#   ('good', 'JJ'),
#   ('when', 'WRB'),
#   ('played', 'VBN'),
#   ('open', 'JJ'),
#   ('but', 'CC'),
#   ('compressing', 'VBG'),
#   ('them', 'PRP'),
#   ('was', 'VBD'),
#   ('nearly', 'RB'),
#   ('impossible', 'JJ'),
#   ('my', 'PRP$'),
#   ('capo', 'NN'),
#   ('could', 'MD'),
#   ('not', 'RB'),
#   ('even', 'RB'),
#   ('hold', 'VB'),
#   ('them', 'PRP'),
#   ('i', 'JJ'),
#   ('set', 'VBD'),
#   ('the', 'DT'),
#   ('guitar', 'NN'),
#   ('aside', 'RB'),
#   ('for', 'IN'),
#   ('a', 'DT'),
#   ('few', 'JJ'),
#   ('minutes', 'NNS'),
#   ('and', 'CC'),
#   ('heard', 'VB'),
#   ('the', 'DT'),
#   ('wood', 'NN'),
#   ('creaking', 'VBG'),
#   ('when', 'WRB'),
#   ('i', 'NN'),
#   ('looked', 'VBD'),
#   ('the', 'DT'),
#   ('face', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('guitar', 'NN'),
#   ('was', 'VBD'),
#   ('bowing', 'VBG'),
#   ('up', 'RB'),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('bridge', 'NN'),
#   ('was', 'VBD'),
#   ('pulling', 'VBG'),
#   ('up', 'RP'),
#   ('and', 'CC'),
#   ('back', 'RB'),
#   ('as', 'IN'),
#   ('if', 'IN'),
#   ('they', 'PRP'),
#   ('were', 'VBD'),
#   ('trying', 'VBG'),
#   ('to', 'TO'),
#   ('pry', 'VB'),
#   ('it', 'PRP'),
#   ('off', 'RP'),
#   ('i', 'NN'),
#   ('released', 'VBD'),
#   ('the', 'DT'),
#   ('tension', 'NN'),
#   ('on', 'IN'),
#   ('all', 'PDT'),
#   ('the', 'DT'),
#   ('strings', 'NNS'),
#   ('as', 'IN'),
#   ('fast', 'NN'),
#   ('as', 'IN'),
#   ('i', 'NN'),
#   ('could', 'MD'),
#   ('and', 'CC'),
#   ('left', 'VBD'),
#   ('it', 'PRP'),
#   ('i', 'VB'),
#   ('returned', 'VBD'),
#   ('them', 'PRP'),
#   ('and', 'CC'),
#   ('got', 'VBD'),
#   ('some', 'DT'),
#   ('lighter', 'JJ'),
#   ('ones', 'NNS'),
#   ('but', 'CC'),
#   ('to', 'TO'),
#   ('no', 'DT'),
#   ('avail', 'NN'),
#   ('the', 'DT'),
#   ('body', 'NN'),
#   ('is', 'VBZ'),
#   ('cracked', 'VBN'),
#   ('around', 'IN'),
#   ('the', 'DT'),
#   ('bridge', 'NN'),
#   ('and', 'CC'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('useless', 'JJ'),
#   ('now', 'RB'),
#   ('use', 'VBP'),
#   ('at', 'IN'),
#   ('your', 'PRP$'),
#   ('own', 'JJ'),
#   ('risk', 'NN'),
#   ('i', 'VBP'),
#   ('personally', 'RB'),
#   ('wouldnt', 'VBP'),
#   ('give', 'VB'),
#   ('a', 'DT'),
#   ('nickel', 'NN'),
#   ('for', 'IN'),
#   ('them', 'PRP')],
#  [('this', 'DT'),
#   ('is', 'VBZ'),
#   ('an', 'DT'),
#   ('update', 'NN'),
#   ('to', 'TO'),
#   ('my', 'PRP$'),
#   ('original', 'JJ'),
#   ('review', 'NN'),
#   ('because', 'IN'),
#   ('i', 'NNS'),
#   ('have', 'VBP'),
#   ('now', 'RB'),
#   ('fully', 'RB'),
#   ('tested', 'VBN'),
#   ('two', 'CD'),
#   ('of', 'IN'),
#   ('these', 'DT'),
#   ('capos', 'NNS'),
#   ('im', 'VBP'),
#   ('truly', 'RB'),
#   ('surprised', 'VBN'),
#   ('by', 'IN'),
#   ('all', 'PDT'),
#   ('the', 'DT'),
#   ('good', 'JJ'),
#   ('reviews', 'NNS'),
#   ('here', 'RB'),
#   ('im', 'VBP'),
#   ('not', 'RB'),
#   ('sure', 'JJ'),
#   ('how', 'WRB'),
#   ('its', 'PRP$'),
#   ('possible', 'JJ'),
#   ('ive', 'JJ'),
#   ('already', 'RB'),
#   ('outlined', 'VBN'),
#   ('below', 'IN'),
#   ('in', 'IN'),
#   ('my', 'PRP$'),
#   ('original', 'JJ'),
#   ('review', 'NN'),
#   ('that', 'IN'),
#   ('these', 'DT'),
#   ('are', 'VBP'),
#   ('not', 'RB'),
#   ('jim', 'JJ'),
#   ('dunlop', 'NN'),
#   ('capos', 'NN'),
#   ('i', 'NN'),
#   ('had', 'VBD'),
#   ('purchased', 'VBN'),
#   ('two', 'CD'),
#   ('which', 'WDT'),
#   ('i', 'NNS'),
#   ('have', 'VBP'),
#   ('now', 'RB'),
#   ('given', 'VBN'),
#   ('away', 'RP'),
#   ('to', 'TO'),
#   ('student', 'NN'),
#   ('players', 'NNS'),
#   ('as', 'IN'),
#   ('i', 'NN'),
#   ('cannot', 'VBP'),
#   ('use', 'IN'),
#   ('them', 'PRP'),
#   ('i', 'VBP'),
#   ('tested', 'VBD'),
#   ('the', 'DT'),
#   ('capos', 'NN'),
#   ('on', 'IN'),
#   ('a', 'DT'),
#   ('standard', 'JJ'),
#   ('acoustic', 'NN'),
#   ('and', 'CC'),
#   ('also', 'RB'),
#   ('an', 'DT'),
#   ('electric', 'JJ'),
#   ('guitar', 'NN'),
#   ('the', 'DT'),
#   ('e', 'NN'),
#   ('string', 'NN'),
#   ('buzzes', 'VBZ'),
#   ('when', 'WRB'),
#   ('the', 'DT'),
#   ('capo', 'NN'),
#   ('is', 'VBZ'),
#   ('applied', 'VBN'),
#   ('and', 'CC'),
#   ('no', 'DT'),
#   ('amount', 'NN'),
#   ('of', 'IN'),
#   ('adjusting', 'VBG'),
#   ('the', 'DT'),
#   ('capo', 'NN'),
#   ('would', 'MD'),
#   ('stop', 'VB'),
#   ('the', 'DT'),
#   ('buzz', 'NN'),
#   ('from', 'IN'),
#   ('occurring', 'VBG'),
#   ('both', 'DT'),
#   ('capos', 'NN'),
#   ('had', 'VBD'),
#   ('this', 'DT'),
#   ('very', 'RB'),
#   ('same', 'JJ'),
#   ('problemwhen', 'NN'),
#   ('i', 'NN'),
#   ('received', 'VBD'),
#   ('these', 'DT'),
#   ('capos', 'NNS'),
#   ('i', 'VBP'),
#   ('noticed', 'VBN'),
#   ('right', 'RB'),
#   ('away', 'RB'),
#   ('that', 'IN'),
#   ('they', 'PRP'),
#   ('were', 'VBD'),
#   ('not', 'RB'),
#   ('the', 'DT'),
#   ('same', 'JJ'),
#   ('excellent', 'JJ'),
#   ('quality', 'NN'),
#   ('as', 'IN'),
#   ('actual', 'JJ'),
#   ('jim', 'NN'),
#   ('dunlop', 'NN'),
#   ('capos', 'VBD'),
#   ('the', 'DT'),
#   ('craftsmanship', 'NN'),
#   ('was', 'VBD'),
#   ('visibly', 'RB'),
#   ('lower', 'JJR'),
#   ('quality', 'NN'),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('materials', 'NNS'),
#   ('used', 'VBN'),
#   ('are', 'VBP'),
#   ('a', 'DT'),
#   ('lesser', 'JJR'),
#   ('quality', 'NN'),
#   ('than', 'IN'),
#   ('official', 'JJ'),
#   ('jim', 'NN'),
#   ('dunlop', 'NN'),
#   ('capos', 'VBD'),
#   ('the', 'DT'),
#   ('rubber', 'NN'),
#   ('has', 'VBZ'),
#   ('a', 'DT'),
#   ('strong', 'JJ'),
#   ('odor', 'NN'),
#   ('and', 'CC'),
#   ('there', 'EX'),
#   ('is', 'VBZ'),
#   ('no', 'DT'),
#   ('brandname', 'NN'),
#   ('printed', 'VBD'),
#   ('anywhere', 'RB'),
#   ('on', 'IN'),
#   ('the', 'DT'),
#   ('product', 'NN'),
#   ('as', 'IN'),
#   ('a', 'DT'),
#   ('professional', 'JJ'),
#   ('musician', 'NN'),
#   ('i', 'NN'),
#   ('need', 'VBP'),
#   ('to', 'TO'),
#   ('purchase', 'VB'),
#   ('reputable', 'JJ'),
#   ('brandname', 'NN'),
#   ('products', 'NNS'),
#   ('because', 'IN'),
#   ('i', 'NN'),
#   ('cant', 'VBP'),
#   ('afford', 'NN'),
#   ('to', 'TO'),
#   ('have', 'VB'),
#   ('my', 'PRP$'),
#   ('gear', 'JJ'),
#   ('failing', 'VBG'),
#   ('during', 'IN'),
#   ('performances', 'NNS'),
#   ('i', 'NNS'),
#   ('have', 'VBP'),
#   ('no', 'DT'),
#   ('idea', 'NN'),
#   ('about', 'IN'),
#   ('the', 'DT'),
#   ('future', 'JJ'),
#   ('performance', 'NN'),
#   ('of', 'IN'),
#   ('these', 'DT'),
#   ('capos', 'NNS'),
#   ('because', 'IN'),
#   ('they', 'PRP'),
#   ('have', 'VBP'),
#   ('no', 'DT'),
#   ('apparent', 'JJ'),
#   ('brand', 'NN'),
#   ('and', 'CC'),
#   ('no', 'DT'),
#   ('measurable', 'JJ'),
#   ('reputation', 'NN'),
#   ('when', 'WRB'),
#   ('i', 'NN'),
#   ('contacted', 'VBD'),
#   ('the', 'DT'),
#   ('seller', 'NN'),
#   ('they', 'PRP'),
#   ('were', 'VBD'),
#   ('not', 'RB'),
#   ('honest', 'VBN'),
#   ('with', 'IN'),
#   ('me', 'PRP')],
#  [('i', 'NN'),
#   ('know', 'VBP'),
#   ('many', 'JJ'),
#   ('people', 'NNS'),
#   ('love', 'VBP'),
#   ('the', 'DT'),
#   ('design', 'NN'),
#   ('but', 'CC'),
#   ('i', 'JJ'),
#   ('find', 'VBP'),
#   ('it', 'PRP'),
#   ('much', 'RB'),
#   ('too', 'RB'),
#   ('frustrating', 'VBG'),
#   ('you', 'PRP'),
#   ('have', 'VBP'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('very', 'RB'),
#   ('careful', 'JJ'),
#   ('putting', 'VBG'),
#   ('it', 'PRP'),
#   ('on', 'IN'),
#   ('the', 'DT'),
#   ('fret', 'NN'),
#   ('correctly', 'RB'),
#   ('then', 'RB'),
#   ('snap', 'VB'),
#   ('it', 'PRP'),
#   ('in', 'IN'),
#   ('then', 'RB'),
#   ('turn', 'NN'),
#   ('and', 'CC'),
#   ('turn', 'VB'),
#   ('the', 'DT'),
#   ('screw', 'NN'),
#   ('oops', 'VBZ'),
#   ('dont', 'JJ'),
#   ('let', 'VB'),
#   ('it', 'PRP'),
#   ('snap', 'VB'),
#   ('off', 'RP'),
#   ('again', 'RB'),
#   ('and', 'CC'),
#   ('fall', 'VB'),
#   ('off', 'RP'),
#   ('while', 'IN'),
#   ('trying', 'VBG'),
#   ('to', 'TO'),
#   ('turn', 'VB'),
#   ('the', 'DT'),
#   ('screw', 'NN'),
#   ('then', 'RB'),
#   ('you', 'PRP'),
#   ('have', 'VBP'),
#   ('to', 'TO'),
#   ('go', 'VB'),
#   ('through', 'IN'),
#   ('the', 'DT'),
#   ('whole', 'JJ'),
#   ('routine', 'NN'),
#   ('again', 'RB'),
#   ('to', 'TO'),
#   ('take', 'VB'),
#   ('it', 'PRP'),
#   ('off', 'RP'),
#   ('and', 'CC'),
#   ('move', 'VB'),
#   ('it', 'PRP'),
#   ('to', 'TO'),
#   ('another', 'DT'),
#   ('fret', 'NN'),
#   ('and', 'CC'),
#   ('put', 'VB'),
#   ('it', 'PRP'),
#   ('on', 'IN'),
#   ('again', 'RB'),
#   ('what', 'WP'),
#   ('a', 'DT'),
#   ('farce', 'NN'),
#   ('this', 'DT'),
#   ('is', 'VBZ'),
#   ('the', 'DT'),
#   ('worst', 'JJS'),
#   ('capo', 'NN'),
#   ('ive', 'NN'),
#   ('owned', 'VBN'),
#   ('and', 'CC'),
#   ('ive', 'JJ'),
#   ('tried', 'VBD'),
#   ('nearly', 'RB'),
#   ('every', 'DT'),
#   ('brand', 'NN'),
#   ('and', 'CC'),
#   ('type', 'NN'),
#   ('yeah', 'NN'),
#   ('ive', 'JJ'),
#   ('had', 'VBD'),
#   ('people', 'NNS'),
#   ('show', 'VBP'),
#   ('me', 'PRP'),
#   ('how', 'WRB'),
#   ('to', 'TO'),
#   ('do', 'VB'),
#   ('it', 'PRP'),
#   ('right', 'RB'),
#   ('and', 'CC'),
#   ('i', 'VB'),
#   ('know', 'VBP'),
#   ('to', 'TO'),
#   ('do', 'VB'),
#   ('it', 'PRP'),
#   ('right', 'VB'),
#   ('its', 'PRP$'),
#   ('just', 'RB'),
#   ('wrong', 'JJ'),
#   ('to', 'TO'),
#   ('have', 'VB'),
#   ('to', 'TO'),
#   ('spend', 'VB'),
#   ('so', 'RB'),
#   ('much', 'JJ'),
#   ('time', 'NN'),
#   ('slipping', 'VBG'),
#   ('it', 'PRP'),
#   ('on', 'IN'),
#   ('snapping', 'VBG'),
#   ('it', 'PRP'),
#   ('screwing', 'VBG'),
#   ('it', 'PRP'),
#   ('in', 'IN'),
#   ('screwing', 'VBG'),
#   ('it', 'PRP'),
#   ('off', 'RP'),
#   ('having', 'VBG'),
#   ('it', 'PRP'),
#   ('fall', 'VB'),
#   ('off', 'RP'),
#   ('forget', 'VB'),
#   ('it', 'PRP'),
#   ('its', 'PRP$'),
#   ('garbage', 'NN'),
#   ('to', 'TO'),
#   ('me', 'PRP'),
#   ('also', 'RB'),
#   ('while', 'IN'),
#   ('im', 'NN'),
#   ('getting', 'VBG'),
#   ('my', 'PRP$'),
#   ('callouses', 'NNS'),
#   ('worked', 'VBN'),
#   ('out', 'RP'),
#   ('playing', 'VBG'),
#   ('for', 'IN'),
#   ('two', 'CD'),
#   ('hours', 'NNS'),
#   ('every', 'DT'),
#   ('day', 'NN'),
#   ('the', 'DT'),
#   ('last', 'JJ'),
#   ('thing', 'NN'),
#   ('i', 'NN'),
#   ('want', 'VBP'),
#   ('is', 'VBZ'),
#   ('to', 'TO'),
#   ('pinch', 'VB'),
#   ('my', 'PRP$'),
#   ('fingers', 'NNS'),
#   ('against', 'IN'),
#   ('metal', 'NN'),
#   ('trying', 'VBG'),
#   ('to', 'TO'),
#   ('turn', 'VB'),
#   ('a', 'DT'),
#   ('screw', 'NN'),
#   ('its', 'PRP$'),
#   ('actually', 'RB'),
#   ('slightly', 'RB'),
#   ('painful', 'JJ'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('fingers', 'NNS'),
#   ('momentarily', 'RB'),
#   ('but', 'CC'),
#   ('why', 'WRB'),
#   ('have', 'VBP'),
#   ('to', 'TO'),
#   ('deal', 'VB'),
#   ('with', 'IN'),
#   ('that', 'DT'),
#   ('to', 'TO'),
#   ('work', 'VB'),
#   ('with', 'IN'),
#   ('this', 'DT'),
#   ('design', 'NN'),
#   ('seems', 'VBZ'),
#   ('like', 'IN'),
#   ('it', 'PRP'),
#   ('was', 'VBD'),
#   ('a', 'DT'),
#   ('non', 'JJ'),
#   ('guitar', 'NN'),
#   ('player', 'NN'),
#   ('who', 'WP'),
#   ('came', 'VBD'),
#   ('up', 'RP'),
#   ('with', 'IN'),
#   ('it', 'PRP'),
#   ('the', 'DT'),
#   ('only', 'RB'),
#   ('good', 'JJ'),
#   ('thing', 'NN'),
#   ('i', 'NN'),
#   ('can', 'MD'),
#   ('say', 'VB'),
#   ('about', 'IN'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('looks', 'JJ'),
#   ('durableno', 'JJ'),
#   ('thanks', 'NNS')],
#  [('i', 'NN'),
#   ('bought', 'VBD'),
#   ('this', 'DT'),
#   ('hoping', 'VBG'),
#   ('to', 'TO'),
#   ('use', 'VB'),
#   ('as', 'IN'),
#   ('intended', 'JJ'),
#   ('angled', 'VBD'),
#   ('into', 'IN'),
#   ('guitar', 'NN'),
#   ('straight', 'VBN'),
#   ('into', 'IN'),
#   ('mixer', 'NN'),
#   ('wrong', 'JJ'),
#   ('have', 'VBP'),
#   ('to', 'TO'),
#   ('use', 'VB'),
#   ('it', 'PRP'),
#   ('the', 'DT'),
#   ('other', 'JJ'),
#   ('way', 'NN'),
#   ('around', 'IN'),
#   ('sad', 'JJ')],
#  [('only', 'RB'),
#   ('lasted', 'VBD'),
#   ('2yr', 'CD'),
#   ('i', 'NNS'),
#   ('have', 'VBP'),
#   ('a', 'DT'),
#   ('lot', 'NN'),
#   ('of', 'IN'),
#   ('cheaper', 'JJR'),
#   ('cables', 'NNS'),
#   ('that', 'WDT'),
#   ('get', 'VBP'),
#   ('more', 'JJR'),
#   ('useabuse', 'NN'),
#   ('than', 'IN'),
#   ('this', 'DT'),
#   ('one', 'NN'),
#   ('that', 'WDT'),
#   ('have', 'VBP'),
#   ('outlasted', 'VBN'),
#   ('it', 'PRP')],
#  [('could', 'MD'),
#   ('not', 'RB'),
#   ('get', 'VB'),
#   ('to', 'TO'),
#   ('fit', 'VB'),
#   ('small', 'JJ'),
#   ('sound', 'JJ'),
#   ('hole', 'NN'),
#   ('once', 'RB'),
#   ('in', 'IN'),
#   ('sound', 'JJ'),
#   ('hole', 'NN'),
#   ('pickup', 'NN'),
#   ('did', 'VBD'),
#   ('not', 'RB'),
#   ('work', 'VB'),
#   ('at', 'IN'),
#   ('all', 'DT'),
#   ('would', 'MD'),
#   ('not', 'RB'),
#   ('buy', 'VB'),
#   ('it', 'PRP')],
#  [('ive', 'NN'),
#   ('used', 'VBN'),
#   ('three', 'CD'),
#   ('pop', 'NN'),
#   ('filters', 'NNS'),
#   ('in', 'IN'),
#   ('my', 'PRP$'),
#   ('experiences', 'NNS'),
#   ('with', 'IN'),
#   ('home', 'NN'),
#   ('recording', 'NN'),
#   ('and', 'CC'),
#   ('podcasting', 'VBG'),
#   ('this', 'DT'),
#   ('one', 'CD'),
#   ('is', 'VBZ'),
#   ('the', 'DT'),
#   ('worst', 'JJS'),
#   ('the', 'DT'),
#   ('plastic', 'NN'),
#   ('screw', 'VBD'),
#   ('yes', 'RB'),
#   ('plastic', 'JJ'),
#   ('that', 'WDT'),
#   ('is', 'VBZ'),
#   ('meant', 'VBN'),
#   ('to', 'TO'),
#   ('grip', 'VB'),
#   ('the', 'DT'),
#   ('pole', 'NN'),
#   ('that', 'IN'),
#   ('you', 'PRP'),
#   ('attach', 'VBP'),
#   ('the', 'DT'),
#   ('pop', 'NN'),
#   ('filter', 'NN'),
#   ('to', 'TO'),
#   ('is', 'VBZ'),
#   ('completely', 'RB'),
#   ('incapable', 'JJ'),
#   ('of', 'IN'),
#   ('supporting', 'VBG'),
#   ('its', 'PRP$'),
#   ('own', 'JJ'),
#   ('weight', 'NN'),
#   ('at', 'IN'),
#   ('nearly', 'RB'),
#   ('any', 'DT'),
#   ('angle', 'JJ'),
#   ('badjust', 'NN'),
#   ('badsecondly', 'RB'),
#   ('there', 'EX'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('metal', 'JJ'),
#   ('piece', 'NN'),
#   ('that', 'WDT'),
#   ('secures', 'VBZ'),
#   ('the', 'DT'),
#   ('flex', 'JJ'),
#   ('arm', 'NN'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('clamp', 'NN'),
#   ('it', 'PRP'),
#   ('seemed', 'VBD'),
#   ('loose', 'JJ'),
#   ('after', 'IN'),
#   ('i', 'NN'),
#   ('got', 'VBD'),
#   ('it', 'PRP'),
#   ('out', 'IN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('packaging', 'NN'),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('flex', 'JJ'),
#   ('arm', 'NN'),
#   ('would', 'MD'),
#   ('wobble', 'VB'),
#   ('and', 'CC'),
#   ('rotate', 'VB'),
#   ('in', 'IN'),
#   ('that', 'DT'),
#   ('spot', 'NN'),
#   ('causing', 'VBG'),
#   ('a', 'DT'),
#   ('major', 'JJ'),
#   ('problem', 'NN'),
#   ('when', 'WRB'),
#   ('it', 'PRP'),
#   ('came', 'VBD'),
#   ('to', 'TO'),
#   ('proper', 'VB'),
#   ('placement', 'NN'),
#   ('after', 'IN'),
#   ('twisting', 'VBG'),
#   ('on', 'IN'),
#   ('it', 'PRP'),
#   ('twice', 'RB'),
#   ('i', 'VBZ'),
#   ('stripped', 'VBD'),
#   ('it', 'PRP'),
#   ('out', 'RP'),
#   ('now', 'RB'),
#   ('the', 'DT'),
#   ('thing', 'NN'),
#   ('is', 'VBZ'),
#   ('worthless', 'JJ'),
#   ('im', 'RB'),
#   ('returning', 'VBG'),
#   ('it', 'PRP'),
#   ('asapi', 'RB'),
#   ('would', 'MD'),
#   ('rather', 'RB'),
#   ('go', 'VB'),
#   ('to', 'TO'),
#   ('a', 'DT'),
#   ('ladys', 'JJ'),
#   ('bag', 'NN'),
#   ('flea', 'NN'),
#   ('market', 'NN'),
#   ('sale', 'NN'),
#   ('with', 'IN'),
#   ('a', 'DT'),
#   ('crazy', 'JJ'),
#   ('woman', 'NN'),
#   ('for', 'IN'),
#   ('a', 'DT'),
#   ('day', 'NN'),
#   ('than', 'IN'),
#   ('continue', 'VBP'),
#   ('to', 'TO'),
#   ('put', 'VB'),
#   ('up', 'RP'),
#   ('with', 'IN'),
#   ('this', 'DT'),
#   ('thing', 'NN'),
#   ('do', 'VB'),
#   ('yourself', 'PRP'),
#   ('a', 'DT'),
#   ('huge', 'JJ'),
#   ('favor', 'NN'),
#   ('and', 'CC'),
#   ('buy', 'VB'),
#   ('the', 'DT'),
#   ('nady', 'JJ'),
#   ('6', 'CD'),
#   ('pop', 'NN'),
#   ('filter', 'NN'),
#   ('if', 'IN'),
#   ('you', 'PRP'),
#   ('dont', 'VBP'),
#   ('youll', 'JJ'),
#   ('wish', 'NN'),
#   ('you', 'PRP'),
#   ('did', 'VBD')],
#  [('its', 'PRP$'),
#   ('poorly', 'NN'),
#   ('made', 'VBN'),
#   ('with', 'IN'),
#   ('attention', 'NN'),
#   ('to', 'TO'),
#   ('detail', 'VB'),
#   ('i', 'NN'),
#   ('ordered', 'VBD'),
#   ('them', 'PRP'),
#   ('to', 'TO'),
#   ('fit', 'VB'),
#   ('on', 'IN'),
#   ('my', 'PRP$'),
#   ('dual', 'JJ'),
#   ('mic', 'JJ'),
#   ('clamp', 'NN'),
#   ('purchased', 'VBN'),
#   ('here', 'RB'),
#   ('at', 'IN'),
#   ('amazon', 'NNS'),
#   ('but', 'CC'),
#   ('they', 'PRP'),
#   ('will', 'MD'),
#   ('not', 'RB'),
#   ('screw', 'VB'),
#   ('down', 'RP'),
#   ('all', 'DT'),
#   ('the', 'DT'),
#   ('way', 'NN'),
#   ('and', 'CC'),
#   ('are', 'VBP'),
#   ('losse', 'JJ'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('useless', 'JJ'),
#   ('other', 'JJ'),
#   ('mic', 'JJ'),
#   ('holders', 'NNS'),
#   ('from', 'IN'),
#   ('different', 'JJ'),
#   ('manufacturers', 'NNS'),
#   ('work', 'VBP'),
#   ('fine', 'JJ')],
#  [('just', 'RB'),
#   ('assembly', 'RB'),
#   ('for', 'IN'),
#   ('a', 'DT'),
#   ('try', 'NN'),
#   ('only', 'RB'),
#   ('few', 'JJ'),
#   ('rolls', 'NNS'),
#   ('with', 'IN'),
#   ('music', 'NN'),
#   ('its', 'PRP$'),
#   ('had', 'VBD'),
#   ('some', 'DT'),
#   ('hole', 'NN'),
#   ('on', 'IN'),
#   ('head', 'NN'),
#   ('thats', 'NNS'),
#   ('mean', 'VBP'),
#   ('bad', 'JJ'),
#   ('quality', 'NN'),
#   ('buyer', 'NN'),
#   ('beware', 'NN'),
#   ('for', 'IN'),
#   ('this', 'DT'),
#   ('kind', 'NN'),
#   ('of', 'IN')],
#  [('crap', 'NN'),
#   ('these', 'DT'),
#   ('strings', 'NNS'),
#   ('are', 'VBP'),
#   ('bad', 'JJ'),
#   ('do', 'VBP'),
#   ('not', 'RB'),
#   ('buy', 'VB'),
#   ('them', 'PRP'),
#   ('if', 'IN'),
#   ('you', 'PRP'),
#   ('play', 'VBP'),
#   ('any', 'DT'),
#   ('kind', 'NN'),
#   ('of', 'IN'),
#   ('harder', 'NN'),
#   ('music', 'NN'),
#   ('or', 'CC'),
#   ('do', 'VB'),
#   ('a', 'DT'),
#   ('lot', 'NN'),
#   ('of', 'IN'),
#   ('string', 'VBG'),
#   ('bends', 'NNS'),
#   ('unless', 'IN'),
#   ('you', 'PRP'),
#   ('like', 'IN'),
#   ('having', 'VBG'),
#   ('strings', 'NNS'),
#   ('almost', 'RB'),
#   ('take', 'VBP'),
#   ('out', 'RP'),
#   ('your', 'PRP$'),
#   ('eyes', 'NNS'),
#   ('then', 'RB'),
#   ('by', 'IN'),
#   ('all', 'DT'),
#   ('means', 'NNS'),
#   ('buy', 'VBP'),
#   ('em', 'IN'),
#   ('errrrr', 'NN'),
#   ('i', 'NN'),
#   ('always', 'RB'),
#   ('buy', 'VBP'),
#   ('ernie', 'JJ'),
#   ('balls', 'NNS'),
#   ('but', 'CC'),
#   ('i', 'JJ'),
#   ('got', 'VBD'),
#   ('cheap', 'JJ'),
#   ('and', 'CC'),
#   ('tryed', 'VBD'),
#   ('to', 'TO'),
#   ('save', 'VB'),
#   ('a', 'DT'),
#   ('few', 'JJ'),
#   ('buck', 'NN'),
#   ('and', 'CC'),
#   ('buy', 'VB'),
#   ('2', 'CD'),
#   ('3', 'CD'),
#   ('packs', 'NNS'),
#   ('of', 'IN'),
#   ('these', 'DT'),
#   ('hunks', 'NNS'),
#   ('of', 'IN'),
#   ('crap', 'NN'),
#   ('for', 'IN'),
#   ('under', 'IN'),
#   ('18', 'CD'),
#   ('bucks', 'NNS'),
#   ('i', 'NN'),
#   ('should', 'MD'),
#   ('have', 'VB'),
#   ('spent', 'VBN'),
#   ('the', 'DT'),
#   ('extra', 'JJ'),
#   ('7', 'CD'),
#   ('bucks', 'NNS'),
#   ('and', 'CC'),
#   ('got', 'VBD'),
#   ('the', 'DT'),
#   ('6', 'CD'),
#   ('pack', 'NN'),
#   ('of', 'IN'),
#   ('ernies', 'NNS'),
#   ('i', 'VBP'),
#   ('didnt', 'VBP'),
#   ('even', 'RB'),
#   ('get', 'VB'),
#   ('a', 'DT'),
#   ('week', 'NN'),
#   ('out', 'IN'),
#   ('of', 'IN'),
#   ('them', 'PRP'),
#   ('and', 'CC'),
#   ('they', 'PRP'),
#   ('were', 'VBD'),
#   ('rusted', 'VBN'),
#   ('and', 'CC'),
#   ('poppin', 'VB'),
#   ('off', 'RP'),
#   ('left', 'NN'),
#   ('and', 'CC'),
#   ('rightnever', 'NN'),
#   ('again', 'RB')],
#  [('this', 'DT'),
#   ('piece', 'NN'),
#   ('of', 'IN'),
#   ('plastic', 'NN'),
#   ('is', 'VBZ'),
#   ('just', 'RB'),
#   ('terrible', 'JJ'),
#   ('youd', 'RB'),
#   ('be', 'VB'),
#   ('better', 'JJR'),
#   ('off', 'RP'),
#   ('with', 'IN'),
#   ('a', 'DT'),
#   ('couple', 'NN'),
#   ('of', 'IN'),
#   ('books', 'NNS'),
#   ('and', 'CC'),
#   ('a', 'DT'),
#   ('towelnot', 'NN'),
#   ('recommended', 'VBD')],
#  [('go', 'VB'),
#   ('build', 'VB'),
#   ('your', 'PRP$'),
#   ('own', 'JJ'),
#   ('build', 'NN'),
#   ('it', 'PRP'),
#   ('to', 'TO'),
#   ('your', 'PRP$'),
#   ('specs', 'NN'),
#   ('and', 'CC'),
#   ('have', 'VBP'),
#   ('a', 'DT'),
#   ('solid', 'JJ'),
#   ('stand', 'NN'),
#   ('if', 'IN'),
#   ('not', 'RB'),
#   ('you', 'PRP'),
#   ('can', 'MD'),
#   ('find', 'VB'),
#   ('a', 'DT'),
#   ('lot', 'NN'),
#   ('better', 'RBR'),
#   ('head', 'NN'),
#   ('stands', 'VBZ'),
#   ('this', 'DT'),
#   ('one', 'NN'),
#   ('was', 'VBD'),
#   ('a', 'DT'),
#   ('huge', 'JJ'),
#   ('disappointment', 'NN'),
#   ('does', 'VBZ'),
#   ('not', 'RB'),
#   ('do', 'VB'),
#   ('what', 'WP'),
#   ('it', 'PRP'),
#   ('says', 'VBZ'),
#   ('and', 'CC'),
#   ('can', 'MD'),
#   ('get', 'VB'),
#   ('you', 'PRP'),
#   ('frustrated', 'VBN'),
#   ('quick', 'JJ'),
#   ('im', 'NN'),
#   ('back', 'RB'),
#   ('with', 'IN'),
#   ('my', 'PRP$'),
#   ('wood', 'NN'),
#   ('block', 'NN'),
#   ('and', 'CC'),
#   ('am', 'VBP'),
#   ('happy', 'JJ')],
#  [('i', 'NN'),
#   ('might', 'MD'),
#   ('have', 'VB'),
#   ('done', 'VBN'),
#   ('something', 'NN'),
#   ('wrongi', 'JJ'),
#   ('read', 'VBN'),
#   ('in', 'IN'),
#   ('a', 'DT'),
#   ('review', 'NN'),
#   ('that', 'IN'),
#   ('these', 'DT'),
#   ('hold', 'VB'),
#   ('six', 'CD'),
#   ('picksit', 'NNS'),
#   ('held', 'VBD'),
#   ('three', 'CD'),
#   ('real', 'JJ'),
#   ('well', 'RB'),
#   ('but', 'CC'),
#   ('on', 'IN'),
#   ('the', 'DT'),
#   ('fourth', 'JJ'),
#   ('insert', 'VBP'),
#   ('the', 'DT'),
#   ('thing', 'NN'),
#   ('just', 'RB'),
#   ('fell', 'VBD'),
#   ('apartill', 'RB'),
#   ('just', 'RB'),
#   ('keep', 'VB'),
#   ('using', 'VBG'),
#   ('my', 'PRP$'),
#   ('pockets', 'NNS')],
#  [('man', 'NN'),
#   ('this', 'DT'),
#   ('thing', 'NN'),
#   ('would', 'MD'),
#   ('not', 'RB'),
#   ('even', 'RB'),
#   ('hold', 'VB'),
#   ('my', 'PRP$'),
#   ('normal', 'JJ'),
#   ('sized', 'JJ'),
#   ('picks', 'NNS'),
#   ('do', 'VBP'),
#   ('not', 'RB'),
#   ('buy', 'VB'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('wast', 'NN'),
#   ('of', 'IN'),
#   ('money', 'NN'),
#   ('ug', 'NN')],
#  [('i', 'NN'),
#   ('use', 'VBP'),
#   ('clayton', 'NN'),
#   ('126mm', 'CD'),
#   ('picks', 'VBZ'),
#   ('a', 'DT'),
#   ('heavy', 'JJ'),
#   ('pick', 'NN'),
#   ('but', 'CC'),
#   ('certainly', 'RB'),
#   ('not', 'RB'),
#   ('oversized', 'VBN'),
#   ('my', 'PRP$'),
#   ('picks', 'NNS'),
#   ('dont', 'VBP'),
#   ('fit', 'JJ'),
#   ('if', 'IN'),
#   ('i', 'JJ'),
#   ('shove', 'VBP'),
#   ('them', 'PRP'),
#   ('in', 'IN'),
#   ('i', 'NN'),
#   ('cant', 'VBP'),
#   ('get', 'VB'),
#   ('them', 'PRP'),
#   ('out', 'RP'),
#   ('also', 'RB'),
#   ('this', 'DT'),
#   ('thing', 'NN'),
#   ('is', 'VBZ'),
#   ('huge', 'JJ'),
#   ('for', 'IN'),
#   ('the', 'DT'),
#   ('back', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('neck', 'NN')],
#  [('dont', 'NN'),
#   ('last', 'JJ'),
#   ('but', 'CC'),
#   ('a', 'DT'),
#   ('couple', 'NN'),
#   ('weeksterrible', 'JJ'),
#   ('feed', 'NN'),
#   ('back', 'RB'),
#   ('as', 'IN'),
#   ('the', 'DT'),
#   ('ends', 'NNS'),
#   ('near', 'IN'),
#   ('the', 'DT'),
#   ('plugs', 'NNS'),
#   ('detirorate', 'VBP'),
#   ('quickly', 'RB'),
#   ('will', 'MD'),
#   ('never', 'RB'),
#   ('buy', 'VB'),
#   ('again', 'RB'),
#   ('even', 'RB'),
#   ('if', 'IN'),
#   ('only', 'RB'),
#   ('5', 'CD'),
#   ('bucks', 'NNS')],
#  [('second', 'JJ'),
#   ('one', 'CD'),
#   ('i', 'NN'),
#   ('bought', 'VBD'),
#   ('lousy', 'JJ'),
#   ('build', 'JJ'),
#   ('quality', 'NN'),
#   ('and', 'CC'),
#   ('only', 'RB'),
#   ('lasted', 'VBD'),
#   ('3', 'CD'),
#   ('months', 'NNS'),
#   ('went', 'VBD'),
#   ('through', 'IN'),
#   ('two', 'CD'),
#   ('of', 'IN'),
#   ('these', 'DT'),
#   ('before', 'IN'),
#   ('i', 'NN'),
#   ('learned', 'VBN'),
#   ('my', 'PRP$'),
#   ('lesson', 'NN'),
#   ('dont', 'JJ'),
#   ('waste', 'NN'),
#   ('your', 'PRP$'),
#   ('money', 'NN'),
#   ('on', 'IN'),
#   ('this', 'DT'),
#   ('junk', 'NN'),
#   ('i', 'NN'),
#   ('love', 'VBP'),
#   ('planet', 'NN'),
#   ('waves', 'NNS'),
#   ('stuff', 'VBP'),
#   ('normally', 'RB'),
#   ('but', 'CC'),
#   ('these', 'DT'),
#   ('are', 'VBP'),
#   ('junk', 'NN')],
#  [('i', 'NN'),
#   ('got', 'VBD'),
#   ('a', 'DT'),
#   ('couple', 'NN'),
#   ('of', 'IN'),
#   ('theseonly', 'RB'),
#   ('buy', 'VB'),
#   ('this', 'DT'),
#   ('cable', 'NN'),
#   ('if', 'IN'),
#   ('there', 'EX'),
#   ('is', 'VBZ'),
#   ('no', 'DT'),
#   ('chance', 'NN'),
#   ('that', 'IN'),
#   ('it', 'PRP'),
#   ('will', 'MD'),
#   ('be', 'VB'),
#   ('ever', 'RB'),
#   ('used', 'VBN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('real', 'JJ'),
#   ('worldafter', 'NN'),
#   ('only', 'RB'),
#   ('a', 'DT'),
#   ('month', 'NN'),
#   ('mine', 'NN'),
#   ('has', 'VBZ'),
#   ('developed', 'VBN'),
#   ('a', 'DT'),
#   ('nasty', 'JJ'),
#   ('short', 'NN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('plugand', 'NN'),
#   ('of', 'IN'),
#   ('course', 'NN'),
#   ('since', 'IN'),
#   ('this', 'DT'),
#   ('cord', 'NN'),
#   ('is', 'VBZ'),
#   ('moldedsealed', 'VBN'),
#   ('up', 'RP'),
#   ('tight', 'JJ'),
#   ('it', 'PRP'),
#   ('cant', 'JJ'),
#   ('be', 'VB'),
#   ('repairedyou', 'VBN'),
#   ('could', 'MD'),
#   ('cut', 'VB'),
#   ('off', 'RP'),
#   ('the', 'DT'),
#   ('plug', 'NN'),
#   ('and', 'CC'),
#   ('solder', 'VB'),
#   ('a', 'DT'),
#   ('good', 'JJ'),
#   ('14', 'CD'),
#   ('inch', 'JJ'),
#   ('plug', 'NN'),
#   ('on', 'IN'),
#   ('itbut', 'NN'),
#   ('why', 'WRB'),
#   ('botherjust', 'NN'),
#   ('save', 'VB'),
#   ('your', 'PRP$'),
#   ('headaches', 'NNS'),
#   ('and', 'CC'),
#   ('money', 'NN'),
#   ('and', 'CC'),
#   ('buy', 'VB'),
#   ('a', 'DT'),
#   ('good', 'JJ'),
#   ('heavy', 'JJ'),
#   ('duty', 'NN'),
#   ('cordthis', 'NN'),
#   ('cord', 'NN'),
#   ('is', 'VBZ'),
#   ('too', 'RB'),
#   ('flimsyits', 'JJ'),
#   ('junk', 'NN'),
#   ('with', 'IN'),
#   ('a', 'DT'),
#   ('fancy', 'NN'),
#   ('molded', 'VBD'),
#   ('plastic', 'JJ'),
#   ('ergonomic', 'JJ'),
#   ('looking', 'VBG'),
#   ('plug', 'NN'),
#   ('housingbut', 'NN'),
#   ('inside', 'IN'),
#   ('its', 'PRP$'),
#   ('junkthrown', 'JJ'),
#   ('away', 'RB'),
#   ('moneybuy', 'VBP'),
#   ('a', 'DT'),
#   ('lottery', 'NN'),
#   ('scratch', 'NN'),
#   ('off', 'IN'),
#   ('instead', 'RB')],
#  [('well', 'RB'),
#   ('this', 'DT'),
#   ('cable', 'NN'),
#   ('certainly', 'RB'),
#   ('didnt', 'VBD'),
#   ('last', 'JJ'),
#   ('long', 'RB'),
#   ('as', 'IN'),
#   ('the', 'DT'),
#   ('title', 'NN'),
#   ('says', 'VBZ'),
#   ('8', 'CD'),
#   ('weeks', 'NNS'),
#   ('bought', 'VBD'),
#   ('a', 'DT'),
#   ('new', 'JJ'),
#   ('fender', 'NN'),
#   ('mustang2', 'NN'),
#   ('v2', 'NN'),
#   ('amp', 'VBD'),
#   ('a', 'DT'),
#   ('week', 'NN'),
#   ('and', 'CC'),
#   ('a', 'DT'),
#   ('half', 'NN'),
#   ('ago', 'IN'),
#   ('last', 'JJ'),
#   ('night', 'NN'),
#   ('amp', 'NN'),
#   ('would', 'MD'),
#   ('turn', 'VB'),
#   ('on', 'IN'),
#   ('but', 'CC'),
#   ('wasnt', 'VB'),
#   ('putting', 'VBG'),
#   ('out', 'RP'),
#   ('any', 'DT'),
#   ('sound', 'NN'),
#   ('from', 'IN'),
#   ('the', 'DT'),
#   ('guitar', 'NN'),
#   ('messed', 'VBN'),
#   ('around', 'IN'),
#   ('a', 'DT'),
#   ('bit', 'NN'),
#   ('and', 'CC'),
#   ('it', 'PRP'),
#   ('started', 'VBD'),
#   ('to', 'TO'),
#   ('work', 'VB'),
#   ('today', 'NN'),
#   ('same', 'JJ'),
#   ('thing', 'NN'),
#   ('and', 'CC'),
#   ('its', 'PRP$'),
#   ('obvious', 'JJ'),
#   ('nothing', 'NN'),
#   ('is', 'VBZ'),
#   ('going', 'VBG'),
#   ('from', 'IN'),
#   ('guitar', 'NN'),
#   ('to', 'TO'),
#   ('amp', 'VB'),
#   ('thought', 'NN'),
#   ('i', 'NN'),
#   ('had', 'VBD'),
#   ('a', 'DT'),
#   ('bad', 'JJ'),
#   ('jack', 'NN'),
#   ('in', 'IN'),
#   ('my', 'PRP$'),
#   ('new', 'JJ'),
#   ('amp', 'NN'),
#   ('and', 'CC'),
#   ('wasnt', 'JJ'),
#   ('very', 'RB'),
#   ('happy', 'JJ'),
#   ('got', 'VBD'),
#   ('out', 'RP'),
#   ('the', 'DT'),
#   ('old', 'JJ'),
#   ('amp', 'NN'),
#   ('and', 'CC'),
#   ('guess', 'VB'),
#   ('what', 'WP'),
#   ('nothing', 'NN'),
#   ('there', 'RB'),
#   ('either', 'RB'),
#   ('at', 'IN'),
#   ('least', 'JJS'),
#   ('my', 'PRP$'),
#   ('new', 'JJ'),
#   ('amp', 'NN'),
#   ('is', 'VBZ'),
#   ('working', 'VBG'),
#   ('and', 'CC'),
#   ('i', 'JJ'),
#   ('only', 'RB'),
#   ('have', 'VBP'),
#   ('to', 'TO'),
#   ('replace', 'VB'),
#   ('a', 'DT'),
#   ('12', 'CD'),
#   ('cordmaybe', 'NN'),
#   ('im', 'NN'),
#   ('just', 'RB'),
#   ('unlucky', 'JJ'),
#   ('and', 'CC'),
#   ('got', 'VBD'),
#   ('a', 'DT'),
#   ('bad', 'JJ'),
#   ('one', 'CD'),
#   ('and', 'CC'),
#   ('if', 'IN'),
#   ('i', 'JJ'),
#   ('bought', 'VBD'),
#   ('it', 'PRP'),
#   ('at', 'IN'),
#   ('a', 'DT'),
#   ('local', 'JJ'),
#   ('store', 'NN'),
#   ('id', 'NN'),
#   ('return', 'VB'),
#   ('it', 'PRP'),
#   ('not', 'RB'),
#   ('going', 'VBG'),
#   ('through', 'IN'),
#   ('the', 'DT'),
#   ('hassles', 'NNS'),
#   ('of', 'IN'),
#   ('mailing', 'VBG'),
#   ('it', 'PRP'),
#   ('back', 'RB'),
#   ('or', 'CC'),
# ...
#   ('it', 'PRP'),
#   ('for', 'IN'),
#   ('about', 'IN'),
#   ('3', 'CD'),
#   ('hrs', 'NNS'),
#   ('and', 'CC'),
#   ('20', 'CD'),
#   ('minutes', 'NNS'),
#   ('mostly', 'RB'),
#   ('carrying', 'VBG'),
#   ('it', 'PRP'),
#   ('on', 'IN'),
#   ('my', 'PRP$'),
#   ('shoulders', 'NNS'),
#   ('sometimes', 'RB'),
#   ('by', 'IN'),
#   ('one', 'CD'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('two', 'CD'),
#   ('handlesthen', 'VBP'),
#   ('the', 'DT'),
#   ('side', 'NN'),
#   ('handle', 'NN'),
#   ('started', 'VBD'),
#   ('coming', 'VBG'),
#   ('apart', 'RB'),
#   ('the', 'DT'),
#   ('seam', 'NN'),
#   ('ripped', 'VBD'),
#   ('on', 'IN'),
#   ('the', 'DT'),
#   ('side', 'NN'),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('handle', 'NN'),
#   ('will', 'MD'),
#   ('eventually', 'RB'),
#   ('fall', 'VB'),
#   ('off', 'RP'),
#   ('if', 'IN'),
#   ('used', 'VBN'),
#   ('it', 'PRP'),
#   ('will', 'MD'),
#   ('be', 'VB'),
#   ('ok', 'JJ'),
#   ('for', 'IN'),
#   ('a', 'DT'),
#   ('while', 'NN'),
#   ('until', 'IN'),
#   ('the', 'DT'),
#   ('shoulder', 'NN'),
#   ('straps', 'NNS'),
#   ('start', 'VBP'),
#   ('breaking', 'VBG'),
#   ('which', 'WDT'),
#   ('i', 'VBP'),
#   ('kind', 'NN'),
#   ('of', 'IN'),
#   ('expect', 'NN'),
#   ('at', 'IN'),
#   ('this', 'DT'),
#   ('point', 'NN'),
#   ('meanwhile', 'RB'),
#   ('im', 'VBZ'),
#   ('going', 'VBG'),
#   ('to', 'TO'),
#   ('buy', 'VB'),
#   ('another', 'DT'),
#   ('sturdier', 'NN'),
#   ('gig', 'NN'),
#   ('bagsave', 'VB'),
#   ('your', 'PRP$'),
#   ('money', 'NN'),
#   ('and', 'CC'),
#   ('get', 'VB'),
#   ('something', 'NN'),
#   ('better', 'JJR'),
#   ('than', 'IN'),
#   ('this', 'DT')],
#  [('this', 'DT'),
#   ('thing', 'NN'),
#   ('is', 'VBZ'),
#   ('crap', 'RB'),
#   ('right', 'JJ'),
#   ('out', 'IN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('box', 'NN'),
#   ('it', 'PRP'),
#   ('had', 'VBD'),
#   ('holes', 'NNS'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('stitching', 'NN'),
#   ('and', 'CC'),
#   ('all', 'PDT'),
#   ('the', 'DT'),
#   ('pockets', 'NNS'),
#   ('were', 'VBD'),
#   ('sown', 'VBN'),
#   ('on', 'IN'),
#   ('crooked', 'NNS'),
#   ('what', 'WP'),
#   ('can', 'MD'),
#   ('you', 'PRP'),
#   ('expect', 'VB'),
#   ('for', 'IN'),
#   ('20', 'CD'),
#   ('tho', 'NN'),
#   ('this', 'DT'),
#   ('was', 'VBD'),
#   ('a', 'DT'),
#   ('temporary', 'JJ'),
#   ('solution', 'NN'),
#   ('i', 'NN'),
#   ('dont', 'VBP'),
#   ('recommend', 'VB'),
#   ('this', 'DT'),
#   ('for', 'IN'),
#   ('long', 'JJ'),
#   ('term', 'NN'),
#   ('use', 'NN'),
#   ('it', 'PRP'),
#   ('will', 'MD'),
#   ('probably', 'RB'),
#   ('fall', 'VB'),
#   ('apart', 'RB')],
#  [('manufacturers', 'NNS'),
#   ('website', 'VBP'),
#   ('claimed', 'VBD'),
#   ('that', 'IN'),
#   ('this', 'DT'),
#   ('case', 'NN'),
#   ('would', 'MD'),
#   ('fit', 'VB'),
#   ('a', 'DT'),
#   ('les', 'JJ'),
#   ('paul', 'NN'),
#   ('style', 'NN'),
#   ('guitar', 'NN'),
#   ('i', 'NN'),
#   ('have', 'VBP'),
#   ('an', 'DT'),
#   ('esp', 'NN'),
#   ('eclipse', 'NN'),
#   ('not', 'RB'),
#   ('even', 'RB'),
#   ('close', 'VB'),
#   ('chromacast', 'NN'),
#   ('products', 'NNS'),
#   ('are', 'VBP'),
#   ('great', 'JJ'),
#   ('they', 'PRP'),
#   ('need', 'VBP'),
#   ('to', 'TO'),
#   ('fix', 'VB'),
#   ('the', 'DT'),
#   ('info', 'NN'),
#   ('on', 'IN'),
#   ('their', 'PRP$'),
#   ('web', 'JJ'),
#   ('page', 'NN'),
#   ('im', 'NN'),
#   ('not', 'RB'),
#   ('a', 'DT'),
#   ('fan', 'NN'),
#   ('of', 'IN'),
#   ('shaped', 'JJ'),
#   ('les', 'NNS'),
#   ('paul', 'VBP'),
#   ('cases', 'NNS'),
#   ('too', 'RB'),
#   ('bad', 'JJ')],
#  [('returned', 'VBN'),
#   ('this', 'DT'),
#   ('item', 'NN'),
#   ('because', 'IN'),
#   ('the', 'DT'),
#   ('zipper', 'NN'),
#   ('was', 'VBD'),
#   ('already', 'RB'),
#   ('broken', 'VBN'),
#   ('when', 'WRB'),
#   ('i', 'NN'),
#   ('received', 'VBD'),
#   ('it', 'PRP'),
#   ('not', 'RB'),
#   ('durable', 'JJ'),
#   ('spend', 'VBP'),
#   ('a', 'DT'),
#   ('few', 'JJ'),
#   ('more', 'JJR'),
#   ('dollars', 'NNS'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('worth', 'IN'),
#   ('it', 'PRP')],
#  [('a', 'DT'),
#   ('great', 'JJ'),
#   ('little', 'JJ'),
#   ('package', 'NN'),
#   ('for', 'IN'),
#   ('the', 'DT'),
#   ('price', 'NN'),
#   ('but', 'CC'),
#   ('unfortunately', 'RB'),
#   ('the', 'DT'),
#   ('zipper', 'NN'),
#   ('failed', 'VBD'),
#   ('the', 'DT'),
#   ('first', 'JJ'),
#   ('time', 'NN'),
#   ('i', 'NN'),
#   ('tried', 'VBD'),
#   ('zipping', 'VBG'),
#   ('it', 'PRP'),
#   ('up', 'IN'),
#   ('i', 'NNS'),
#   ('have', 'VBP'),
#   ('a', 'DT'),
#   ('standard', 'JJ'),
#   ('size', 'NN'),
#   ('acoustic', 'JJ'),
#   ('guitar', 'NN'),
#   ('but', 'CC'),
#   ('be', 'VB'),
#   ('aware', 'JJ'),
#   ('the', 'DT'),
#   ('fit', 'NN'),
#   ('was', 'VBD'),
#   ('snug', 'VBN'),
#   ('but', 'CC'),
#   ('not', 'RB'),
#   ('tight', 'JJ')],
#  [('straight', 'VBN'),
#   ('out', 'IN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('box', 'NN'),
#   ('this', 'DT'),
#   ('product', 'NN'),
#   ('reeked', 'VBD'),
#   ('cheap', 'JJ'),
#   ('no', 'DT'),
#   ('directions', 'NNS'),
#   ('inside', 'RB'),
#   ('or', 'CC'),
#   ('on', 'IN'),
#   ('the', 'DT'),
#   ('box', 'NN'),
#   ('i', 'NN'),
#   ('messed', 'VBD'),
#   ('with', 'IN'),
#   ('it', 'PRP'),
#   ('for', 'IN'),
#   ('about', 'IN'),
#   ('5', 'CD'),
#   ('minutes', 'NNS'),
#   ('i', 'RB'),
#   ('would', 'MD'),
#   ('not', 'RB'),
#   ('trust', 'VB'),
#   ('it', 'PRP'),
#   ('with', 'IN'),
#   ('a', 'DT'),
#   ('heavy', 'JJ'),
#   ('or', 'CC'),
#   ('expensive', 'JJ'),
#   ('mic', 'JJ'),
#   ('i', 'NN'),
#   ('read', 'VBP'),
#   ('the', 'DT'),
#   ('description', 'NN'),
#   ('but', 'CC'),
#   ('it', 'PRP'),
#   ('did', 'VBD'),
#   ('not', 'RB'),
#   ('say', 'VB'),
#   ('cheap', 'JJ'),
#   ('live', 'JJ'),
#   ('and', 'CC'),
#   ('learn', 'VB')],
#  [('amazon', 'NN'),
#   ('and', 'CC'),
#   ('tc', 'NN'),
#   ('electronics', 'NNS'),
#   ('will', 'MD'),
#   ('not', 'RB'),
#   ('tell', 'VB'),
#   ('you', 'PRP'),
#   ('that', 'IN'),
#   ('you', 'PRP'),
#   ('need', 'VBP'),
#   ('a', 'DT'),
#   ('9v', 'CD'),
#   ('power', 'NN'),
#   ('supply', 'NN'),
#   ('i', 'JJ'),
#   ('didnt', 'VBP'),
#   ('see', 'VBP'),
#   ('any', 'DT'),
#   ('warning', 'NN'),
#   ('or', 'CC'),
#   ('advise', 'NN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('point', 'NN'),
#   ('of', 'IN'),
#   ('purchase', 'NN'),
#   ('nor', 'CC'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('package', 'NN'),
#   ('this', 'DT'),
#   ('is', 'VBZ'),
#   ('an', 'DT'),
#   ('unfair', 'JJ'),
#   ('practice', 'NN'),
#   ('from', 'IN'),
#   ('amazon', 'NN'),
#   ('and', 'CC'),
#   ('tc', 'NN'),
#   ('electronics', 'NNS')],
#  [('let', 'VB'),
#   ('me', 'PRP'),
#   ('start', 'VB'),
#   ('by', 'IN'),
#   ('saying', 'VBG'),
#   ('that', 'IN'),
#   ('this', 'DT'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('really', 'RB'),
#   ('cool', 'JJ'),
#   ('pedal', 'NN'),
#   ('and', 'CC'),
#   ('tons', 'NNS'),
#   ('of', 'IN'),
#   ('fun', 'NN'),
#   ('i', 'NN'),
#   ('can', 'MD'),
#   ('see', 'VB'),
#   ('how', 'WRB'),
#   ('this', 'DT'),
#   ('could', 'MD'),
#   ('make', 'VB'),
#   ('you', 'PRP'),
#   ('a', 'DT'),
#   ('better', 'JJR'),
#   ('player', 'NN'),
#   ('and', 'CC'),
#   ('i', 'NN'),
#   ('think', 'VBP'),
#   ('it', 'PRP'),
#   ('could', 'MD'),
#   ('also', 'RB'),
#   ('be', 'VB'),
#   ('used', 'VBN'),
#   ('livebut', 'NN'),
#   ('and', 'CC'),
#   ('this', 'DT'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('big', 'JJ'),
#   ('but', 'CC'),
#   ('this', 'DT'),
#   ('is', 'VBZ'),
#   ('my', 'PRP$'),
#   ('first', 'JJ'),
#   ('one', 'CD'),
#   ('star', 'NN'),
#   ('review', 'NN'),
#   ('evermy', 'VBP'),
#   ('first', 'JJ'),
#   ('lessthan5starreview', 'NN'),
#   ('eversame', 'NN'),
#   ('as', 'IN'),
#   ('others', 'NNS'),
#   ('switch', 'VBP'),
#   ('failed', 'VBD'),
#   ('less', 'JJR'),
#   ('than', 'IN'),
#   ('ten', 'JJ'),
#   ('days', 'NNS'),
#   ('of', 'IN'),
#   ('owning', 'VBG'),
#   ('it', 'PRP'),
#   ('used', 'VBD'),
#   ('less', 'JJR'),
#   ('than', 'IN'),
#   ('ten', 'CD'),
#   ('times', 'NNS'),
#   ('total', 'JJ'),
#   ('light', 'JJ'),
#   ('use', 'NN'),
#   ('at', 'IN'),
#   ('home', 'NN'),
#   ('i', 'NN'),
#   ('wasnt', 'VBD'),
#   ('even', 'RB'),
#   ('wearing', 'VBG'),
#   ('shoes', 'NNS'),
#   ('by', 'IN'),
#   ('the', 'DT'),
#   ('way', 'NN'),
#   ('a', 'DT'),
#   ('giggingrecording', 'NN'),
#   ('musician', 'NN'),
#   ('for', 'IN'),
#   ('over', 'IN'),
#   ('25', 'CD'),
#   ('years', 'NNS'),
#   ('so', 'RB'),
#   ('i', 'RB'),
#   ('am', 'VBP'),
#   ('not', 'RB'),
#   ('a', 'DT'),
#   ('youngster', 'NN'),
#   ('that', 'WDT'),
#   ('misuses', 'VBZ'),
#   ('my', 'PRP$'),
#   ('stuff', 'JJ'),
#   ('bummer', 'NN'),
#   ('too', 'RB'),
#   ('great', 'JJ'),
#   ('ideapoorly', 'JJ'),
#   ('executedi', 'NN'),
#   ('will', 'MD'),
#   ('not', 'RB'),
#   ('buy', 'VB'),
#   ('anther', 'IN'),
#   ('one', 'CD'),
#   ('i', 'NN'),
#   ('will', 'MD'),
#   ('not', 'RB'),
#   ('recommend', 'VB'),
#   ('to', 'TO'),
#   ('other', 'JJ'),
#   ('musicians', 'NNS')],
#  [('i', 'NN'),
#   ('purchased', 'VBD'),
#   ('this', 'DT'),
#   ('pedal', 'NN'),
#   ('at', 'IN'),
#   ('a', 'DT'),
#   ('local', 'JJ'),
#   ('music', 'NN'),
#   ('store', 'NN'),
#   ('for', 'IN'),
#   ('practice', 'NN'),
#   ('and', 'CC'),
#   ('possibly', 'RB'),
#   ('doing', 'VBG'),
#   ('some', 'DT'),
#   ('loops', 'NNS'),
#   ('at', 'IN'),
#   ('open', 'JJ'),
#   ('mics', 'NNS'),
#   ('with', 'IN'),
#   ('my', 'PRP$'),
#   ('roland', 'NN'),
#   ('gr55', 'NN'),
#   ('which', 'WDT'),
#   ('has', 'VBZ'),
#   ('a', 'DT'),
#   ('flawless', 'JJ'),
#   ('basic', 'JJ'),
#   ('looper', 'NN'),
#   ('built', 'VBN'),
#   ('in', 'IN'),
#   ('but', 'CC'),
#   ('only', 'RB'),
#   ('20', 'CD'),
#   ('seconds', 'NNS'),
#   ('record', 'NN'),
#   ('and', 'CC'),
#   ('no', 'DT'),
#   ('undo', 'NN'),
#   ('i', 'NN'),
#   ('had', 'VBD'),
#   ('hoped', 'VBN'),
#   ('that', 'IN'),
#   ('it', 'PRP'),
#   ('would', 'MD'),
#   ('at', 'IN'),
#   ('least', 'JJS'),
#   ('last', 'JJ'),
#   ('one', 'CD'),
#   ('hour', 'NN'),
#   ('on', 'IN'),
#   ('with', 'IN'),
#   ('a', 'DT'),
#   ('battery', 'NN'),
#   ('so', 'IN'),
#   ('that', 'IN'),
#   ('i', 'NN'),
#   ('wouldnt', 'VBP'),
#   ('need', 'NN'),
#   ('to', 'TO'),
#   ('carry', 'VB'),
#   ('a', 'DT'),
#   ('power', 'NN'),
#   ('adapter', 'NN'),
#   ('alongthe', 'NN'),
#   ('factory', 'NN'),
#   ('battery', 'NN'),
#   ('lasted', 'VBD'),
#   ('about', 'IN'),
#   ('1', 'CD'),
#   ('hour', 'NN'),
#   ('the', 'DT'),
#   ('second', 'JJ'),
#   ('brand', 'NN'),
#   ('new', 'JJ'),
#   ('fresh', 'JJ'),
#   ('duracell', 'NN'),
#   ('battery', 'NN'),
#   ('lasted', 'VBD'),
#   ('about', 'IN'),
#   ('20', 'CD'),
#   ('minutes', 'NNS'),
#   ('i', 'RB'),
#   ('started', 'VBD'),
#   ('recording', 'VBG'),
#   ('a', 'DT'),
#   ('loop', 'NN'),
#   ('with', 'IN'),
#   ('another', 'DT'),
#   ('3rd', 'CD'),
#   ('fresh', 'JJ'),
#   ('battery', 'NN'),
#   ('tested', 'VBD'),
#   ('910', 'CD'),
#   ('v', 'NN'),
#   ('with', 'IN'),
#   ('a', 'DT'),
#   ('multimeter', 'NN'),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('unit', 'NN'),
#   ('started', 'VBD'),
#   ('behaving', 'VBG'),
#   ('erratically', 'RB'),
#   ('after', 'IN'),
#   ('a', 'DT'),
#   ('few', 'JJ'),
#   ('seconds', 'NNS'),
#   ('of', 'IN'),
#   ('recording', 'VBG'),
#   ('suggesting', 'VBG'),
#   ('that', 'IN'),
#   ('it', 'PRP'),
#   ('was', 'VBD'),
#   ('faulty', 'VBG'),
#   ('the', 'DT'),
#   ('lights', 'NNS'),
#   ('started', 'VBD'),
#   ('coming', 'VBG'),
#   ('on', 'IN'),
#   ('and', 'CC'),
#   ('off', 'IN'),
#   ('randomly', 'RB'),
#   ('recordundoall', 'VB'),
#   ('three', 'CD'),
#   ('together', 'RB'),
#   ('then', 'RB'),
#   ('off', 'RP'),
#   ('then', 'RB'),
#   ('undo', 'RB'),
#   ('on', 'IN'),
#   ('then', 'RB'),
#   ('all', 'DT'),
#   ('three', 'CD'),
#   ('on', 'IN'),
#   ('etc', 'NN'),
#   ('etcthe', 'NN'),
#   ('first', 'JJ'),
#   ('time', 'NN'),
#   ('i', 'NN'),
#   ('used', 'VBD'),
#   ('the', 'DT'),
#   ('jamman', 'NN'),
#   ('xt', 'NN'),
#   ('with', 'IN'),
#   ('the', 'DT'),
#   ('factory', 'NN'),
#   ('battery', 'NN'),
#   ('it', 'PRP'),
#   ('seemed', 'VBD'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('working', 'VBG'),
#   ('ok', 'JJ'),
#   ('and', 'CC'),
#   ('all', 'DT'),
#   ('i', 'NN'),
#   ('can', 'MD'),
#   ('say', 'VB'),
#   ('is', 'VBZ'),
#   ('that', 'IN'),
#   ('as', 'IN'),
#   ('a', 'DT'),
#   ('basic', 'JJ'),
#   ('looper', 'NN'),
#   ('it', 'PRP'),
#   ('suckedi', 'VBZ'),
#   ('am', 'VBP'),
#   ('used', 'VBN'),
#   ('to', 'TO'),
#   ('synching', 'VBG'),
#   ('loops', 'NNS'),
#   ('with', 'IN'),
#   ('other', 'JJ'),
#   ('loopers', 'NNS'),
#   ('and', 'CC'),
#   ('timing', 'NN'),
#   ('is', 'VBZ'),
#   ('everything', 'NN'),
#   ('so', 'RB'),
#   ('i', 'RB'),
#   ('know', 'VBP'),
#   ('it', 'PRP'),
#   ('was', 'VBD'),
#   ('not', 'RB'),
#   ('my', 'PRP$'),
#   ('poor', 'JJ'),
#   ('technique', 'NN'),
#   ('the', 'DT'),
#   ('main', 'JJ'),
#   ('problem', 'NN'),
#   ('was', 'VBD'),
#   ('that', 'IN'),
#   ('it', 'PRP'),
#   ('didnt', 'VBZ'),
#   ('matter', 'RBR'),
#   ('how', 'WRB'),
#   ('hard', 'JJ'),
#   ('i', 'NN'),
#   ('tried', 'VBD'),
#   ('even', 'RB'),
#   ('if', 'IN'),
#   ('i', 'NN'),
#   ('did', 'VBD'),
#   ('a', 'DT'),
#   ('manual', 'JJ'),
#   ('fade', 'NN'),
#   ('out', 'IN'),
#   ('there', 'RB'),
#   ('was', 'VBD'),
#   ('always', 'RB'),
#   ('a', 'DT'),
#   ('gap', 'NN'),
#   ('of', 'IN'),
#   ('about', 'IN'),
#   ('2', 'CD'),
#   ('seconds', 'NNS'),
#   ('between', 'IN'),
#   ('the', 'DT'),
#   ('end', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('loop', 'NN'),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('start', 'NN'),
#   ('this', 'DT'),
#   ('makes', 'VBZ'),
#   ('the', 'DT'),
#   ('unit', 'NN'),
#   ('uselessalso', 'JJ'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('poorly', 'RB'),
#   ('conceived', 'VBN'),
#   ('in', 'IN'),
#   ('that', 'DT'),
#   ('to', 'TO'),
#   ('replace', 'VB'),
#   ('the', 'DT'),
#   ('battery', 'NN'),
#   ('you', 'PRP'),
#   ('have', 'VBP'),
#   ('to', 'TO'),
#   ('take', 'VB'),
#   ('out', 'RP'),
#   ('2', 'CD'),
#   ('screws', 'NNS'),
#   ('exposing', 'VBG'),
#   ('the', 'DT'),
#   ('delicate', 'NN'),
#   ('printed', 'VBD'),
#   ('circuit', 'NN'),
#   ('boardthe', 'NN'),
#   ('potential', 'NN'),
#   ('for', 'IN'),
#   ('damage', 'NN'),
#   ('here', 'RB'),
#   ('is', 'VBZ'),
#   ('very', 'RB'),
#   ('high', 'JJ'),
#   ('also', 'RB'),
#   ('replacing', 'VBG'),
#   ('the', 'DT'),
#   ('screws', 'NN'),
#   ('needs', 'VBZ'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('done', 'VBN'),
#   ('very', 'RB'),
#   ('carefully', 'RB'),
#   ('to', 'TO'),
#   ('avoid', 'VB'),
#   ('cross', 'NN'),
#   ('threading', 'VBG'),
#   ('the', 'DT'),
#   ('screws', 'NNS'),
#   ('and', 'CC'),
#   ('messing', 'VBG'),
#   ('up', 'RP'),
#   ('the', 'DT'),
#   ('receiver', 'NN'),
#   ('nuts', 'NNS'),
#   ('which', 'WDT'),
#   ('are', 'VBP'),
#   ('mounted', 'VBN'),
#   ('directly', 'RB'),
#   ('onto', 'IN'),
#   ('the', 'DT'),
#   ('circuit', 'NN'),
#   ('board', 'NN'),
#   ('to', 'TO'),
#   ('save', 'VB'),
#   ('a', 'DT'),
#   ('few', 'JJ'),
#   ('dollars', 'NNS'),
#   ('digitech', 'RB'),
#   ('did', 'VBD'),
#   ('not', 'RB'),
#   ('have', 'VB'),
#   ('the', 'DT'),
#   ('foresight', 'NN'),
#   ('to', 'TO'),
#   ('manufacture', 'VB'),
#   ('the', 'DT'),
#   ('unit', 'NN'),
#   ('with', 'IN'),
#   ('a', 'DT'),
#   ('battery', 'NN'),
#   ('box', 'NN'),
#   ('which', 'WDT'),
#   ('would', 'MD'),
#   ('have', 'VB'),
#   ('protected', 'VBN'),
#   ('the', 'DT'),
#   ('electronics', 'NNS'),
#   ('and', 'CC'),
#   ('possible', 'JJ'),
#   ('read', 'NN'),
#   ('inevitable', 'JJ'),
#   ('damagei', 'NNS'),
#   ('have', 'VBP'),
#   ('owned', 'VBN'),
#   ('quite', 'RB'),
#   ('a', 'DT'),
#   ('few', 'JJ'),
#   ('digitech', 'NN'),
#   ('products', 'NNS'),
#   ('over', 'IN'),
#   ('the', 'DT'),
#   ('years', 'NNS'),
#   ('and', 'CC'),
#   ('generally', 'RB'),
#   ('they', 'PRP'),
#   ('are', 'VBP'),
#   ('well', 'RB'),
#   ('thought', 'VBN'),
#   ('out', 'RP'),
#   ('and', 'CC'),
#   ('well', 'RB'),
#   ('constructed', 'VBN'),
#   ('but', 'CC'),
#   ('they', 'PRP'),
#   ('have', 'VBP'),
#   ('really', 'RB'),
#   ('dropped', 'VBN'),
#   ('the', 'DT'),
#   ('ball', 'NN'),
#   ('on', 'IN'),
#   ('this', 'DT'),
#   ('oneits', 'VBZ'),
#   ('going', 'VBG'),
#   ('back', 'RB'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('store', 'NN'),
#   ('where', 'WRB'),
#   ('i', 'NN'),
#   ('purchased', 'VBD'),
#   ('it', 'PRP')],
#  [('i', 'NN'),
#   ('really', 'RB'),
#   ('wanted', 'VBD'),
#   ('to', 'TO'),
#   ('like', 'IN'),
#   ('these', 'DT'),
#   ('but', 'CC'),
#   ('theyre', 'VBD'),
#   ('a', 'DT'),
#   ('frickin', 'JJ'),
#   ('lintcatching', 'NN'),
#   ('sticky', 'JJ'),
#   ('frickin', 'NN'),
#   ('mess', 'NN'),
#   ('they', 'PRP'),
#   ('went', 'VBD'),
#   ('from', 'IN'),
#   ('my', 'PRP$'),
#   ('wifes', 'NN'),
#   ('snare', 'NN'),
#   ('back', 'RB'),
#   ('into', 'IN'),
#   ('the', 'DT'),
#   ('holder', 'NN'),
#   ('in', 'IN'),
#   ('a', 'DT'),
#   ('new', 'JJ'),
#   ('york', 'NN'),
#   ('minute', 'NN'),
#   ('have', 'VBP'),
#   ('never', 'RB'),
#   ('seen', 'VBN'),
#   ('the', 'DT'),
#   ('light', 'NN'),
#   ('of', 'IN'),
#   ('day', 'NN'),
#   ('and', 'CC'),
#   ('may', 'MD'),
#   ('have', 'VB'),
#   ('been', 'VBN'),
#   ('thrown', 'VBN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('garbage', 'NN'),
#   ('save', 'VB'),
#   ('your', 'PRP$'),
#   ('money', 'NN'),
#   ('we', 'PRP'),
#   ('use', 'VBP'),
#   ('a', 'DT'),
#   ('heavy', 'JJ'),
#   ('stoneware', 'NN'),
#   ('coaster', 'NN'),
#   ('with', 'IN'),
#   ('a', 'DT'),
#   ('cork', 'NN'),
#   ('back', 'RB'),
#   ('to', 'TO'),
#   ('quieten', 'VB'),
#   ('her', 'PRP$'),
#   ('snare', 'NN'),
#   ('now', 'RB')]]

# %%
df1_rev_tok
# Out:
# [['it',
#   'hums',
#   'crackles',
#   'and',
#   'i',
#   'think',
#   'im',
#   'having',
#   'problems',
#   'with',
#   'my',
#   'equipment',
#   'as',
#   'soon',
#   'as',
#   'i',
#   'use',
#   'any',
#   'of',
#   'my',
#   'other',
#   'cords',
#   'then',
#   'the',
#   'problem',
#   'is',
#   'gone',
#   'hosa',
#   'makes',
#   'some',
#   'other',
#   'products',
#   'that',
#   'have',
#   'good',
#   'value',
#   'but',
#   'based',
#   'on',
#   'my',
#   'experience',
#   'i',
#   'dont',
#   'recommend',
#   'this',
#   'one'],
#  ['im',
#   'a',
#   'procheapo',
#   'and',
#   'i',
#   'hated',
#   'this',
#   'thing',
#   'theyre',
#   'noisy',
#   'and',
#   'the',
#   'cables',
#   'feel',
#   'really',
#   'cheap',
#   'gummylike',
#   'drop',
#   'few',
#   'more',
#   'bucks',
#   'and',
#   'get',
#   'something',
#   'else'],
#  ['received',
#   'it',
#   'in',
#   'time',
#   'standard',
#   'blister',
#   'packaging',
#   'but',
#   'the',
#   'cable',
#   'stopped',
#   'working',
#   'after',
#   '45',
#   'days',
#   'since',
#   'i',
#   'was',
#   'out',
#   'of',
#   '30',
#   'days',
#   'return',
#   'time',
#   'sent',
#   'an',
#   'email',
#   'to',
#   'the',
#   'manufacturer',
#   'but',
#   'no',
#   'response',
#   'till',
#   'today'],
#  ['these',
#   'things',
#   'are',
#   'terrible',
#   'one',
#   'wouldnt',
#   'fit',
#   'in',
#   'my',
#   'soundboard',
#   'another',
#   'wouldnt',
#   'lock',
#   'in',
#   'my',
#   'mic',
#   'plain',
#   'and',
#   'simpleif',
#   'your',
#   'looking',
#   'for',
#   'crap',
#   'that',
#   'doesnt',
#   'workbuy',
#   'this'],
#  ['this',
#   'is',
#   'a',
#   'cheap',
#   'piece',
#   'of',
#   'junk',
#   'that',
#   'does',
#   'what',
#   'it',
#   'says',
#   'it',
#   'distorts',
#   'you',
#   'want',
#   'something',
#   'to',
#   'make',
#   'your',
#   'guitar',
#   'sound',
#   'like',
#   'junk',
#   'this',
#   'will',
#   'do',
#   'it',
#   'why',
#   'pedals',
#   'that',
#   'make',
#   'your',
#   'guitar',
#   'sound',
#   'like',
#   'a',
#   'piece',
#   'of',
#   'junk',
#   'are',
#   'the',
#   'most',
#   'popular',
#   'is',
#   'beyond',
#   'me',
#   'this',
#   'is',
#   'not',
#   'a',
#   'boutique',
#   'distortion',
#   'pedal',
#   'like',
#   'hendrix',
#   'would',
#   'use',
#   'boutique',
#   'and',
#   'distortion',
#   'are',
#   'an',
#   'oxymoronthese',
#   'things',
#   'are',
#   'built',
#   'with',
#   'heavy',
#   'metal',
#   'it',
#   'should',
#   'last',
#   'i',
#   'kinda',
#   'hope',
#   'it',
#   'doesntjust',
#   'kidding',
#   'you',
#   'want',
#   'distortion',
#   'you',
#   'got',
#   'distortion'],
#  ['heres',
#   'the',
#   'deal',
#   'with',
#   'this',
#   'pedal',
#   'it',
#   'is',
#   'inexpensive',
#   'and',
#   'you',
#   'can',
#   'get',
#   'a',
#   'better',
#   'pedal',
#   'with',
#   'barely',
#   'a',
#   'bit',
#   'more',
#   'money',
#   'and',
#   'sometimes',
#   'a',
#   'little',
#   'less',
#   'money',
#   'in',
#   'my',
#   'opinion',
#   'for',
#   'spending',
#   'less',
#   'than',
#   '100',
#   'for',
#   'a',
#   'distortion',
#   'pedal',
#   'whether',
#   'it',
#   'is',
#   'your',
#   'first',
#   'pedal',
#   'or',
#   '700th',
#   'pedal',
#   'a',
#   'few',
#   'more',
#   'bucks',
#   'will',
#   'get',
#   'you',
#   'the',
#   'mxr',
#   'badass',
#   'distortion',
#   'which',
#   'has',
#   'a',
#   'much',
#   'crisper',
#   'tone',
#   'to',
#   'it'],
#  ['these',
#   'came',
#   'stock',
#   'on',
#   'my',
#   'jackson',
#   'kelly',
#   'kexmg',
#   'all',
#   'the',
#   'other',
#   'guitars',
#   'i',
#   'own',
#   'have',
#   'schaller',
#   'buttons',
#   'on',
#   'them',
#   'and',
#   'i',
#   'have',
#   'one',
#   'main',
#   'strap',
#   'i',
#   'use',
#   'for',
#   'all',
#   'of',
#   'the',
#   'guitars',
#   'i',
#   'figured',
#   'since',
#   'the',
#   'guitar',
#   'came',
#   'with',
#   'them',
#   'i',
#   'would',
#   'try',
#   'them',
#   'out',
#   'not',
#   'twenty',
#   'min',
#   'later',
#   'i',
#   'was',
#   'removing',
#   'them',
#   'and',
#   'putting',
#   'schaller',
#   'buttons',
#   'in',
#   'their',
#   'place',
#   'here',
#   'the',
#   '3',
#   'major',
#   'reasons',
#   'i',
#   'did',
#   'not',
#   'like',
#   'them',
#   'over',
#   'schaller1',
#   'bulky',
#   'they',
#   'stick',
#   'out',
#   'too',
#   'far',
#   'and',
#   'on',
#   'any',
#   'guitar',
#   'with',
#   'a',
#   'strap',
#   'button',
#   'on',
#   'the',
#   'back',
#   'it',
#   'jabs',
#   'you',
#   'in',
#   'the',
#   'stomach',
#   'or',
#   'below2',
#   'problems',
#   'engaging',
#   'i',
#   'would',
#   'push',
#   'them',
#   'into',
#   'the',
#   'receiver',
#   'and',
#   'they',
#   'pop',
#   'back',
#   'out',
#   'it',
#   'wasnt',
#   'until',
#   'i',
#   'forced',
#   'them',
#   'in',
#   'while',
#   'pushing',
#   'the',
#   'button',
#   'that',
#   'they',
#   'went',
#   'in',
#   'a',
#   'stayed',
#   'in',
#   'schallers',
#   'click',
#   'in',
#   'and',
#   'you',
#   'know',
#   'they',
#   'are',
#   'ready',
#   'to',
#   'go3',
#   'cheap',
#   'they',
#   'just',
#   'feel',
#   'cheap',
#   'thin',
#   'metal',
#   'is',
#   'used',
#   'in',
#   'comparison',
#   'to',
#   'the',
#   'schallers',
#   'which',
#   'have',
#   'a',
#   'very',
#   'heavy',
#   'and',
#   'solid',
#   'feel',
#   'to',
#   'themfor',
#   'a',
#   'few',
#   'bucks',
#   'more',
#   'ill',
#   'stick',
#   'with',
#   'schallers',
#   'i',
#   'have',
#   'been',
#   'using',
#   'them',
#   'for',
#   '10',
#   'years',
#   'and',
#   'have',
#   'never',
#   'seen',
#   'one',
#   'fail'],
#  ['i',
#   'purchased',
#   'this',
#   'after',
#   'reading',
#   'the',
#   'great',
#   'reviews',
#   'but',
#   'like',
#   'a',
#   'few',
#   'of',
#   'the',
#   'comments',
#   'that',
#   'are',
#   'on',
#   'here',
#   'lately',
#   'this',
#   'thing',
#   'is',
#   'not',
#   'good',
#   'looked',
#   'almost',
#   'used',
#   'when',
#   'it',
#   'arrived',
#   'and',
#   'the',
#   'gooseneck',
#   'stand',
#   'is',
#   'useless',
#   'does',
#   'not',
#   'come',
#   'even',
#   'close',
#   'to',
#   'being',
#   'able',
#   'to',
#   'hold',
#   'up',
#   'the',
#   'weight',
#   'of',
#   'the',
#   'filter',
#   'i',
#   'would',
#   'have',
#   'returned',
#   'it',
#   'but',
#   'i',
#   'completely',
#   'destroyed',
#   'the',
#   'package',
#   'getting',
#   'it',
#   'open',
#   'which',
#   'oddly',
#   'had',
#   'staples',
#   'holding',
#   'it',
#   'closed'],
#  ['wind',
#   'screen',
#   'is',
#   'way',
#   'too',
#   'big',
#   'its',
#   'bulky',
#   'and',
#   'to',
#   'me',
#   'useless',
#   'the',
#   'screen',
#   'came',
#   'out',
#   'was',
#   'thinking',
#   'of',
#   'glueing',
#   'it',
#   'back',
#   'in',
#   'but',
#   'went',
#   'to',
#   'ebay',
#   'and',
#   'bought',
#   '2',
#   'metal',
#   'mesh',
#   'pop',
#   'filters',
#   'cheaper',
#   'that',
#   'is',
#   'much',
#   'betteravoid',
#   'this'],
#  ['i',
#   'got',
#   'this',
#   'for',
#   'my',
#   'boss',
#   'loop',
#   'station',
#   'but',
#   'it',
#   'doesnt',
#   'work',
#   'very',
#   'well',
#   'i',
#   'keep',
#   'hoping',
#   'ill',
#   'find',
#   'something',
#   'it',
#   'does',
#   'work',
#   'well',
#   'with'],
#  ['long',
#   'story',
#   'short',
#   'this',
#   'string',
#   'set',
#   'has',
#   'a',
#   'strong',
#   'metallic',
#   'character',
#   'which',
#   'distorts',
#   'the',
#   'natural',
#   'sound',
#   'of',
#   'your',
#   'guitar',
#   'so',
#   'much',
#   'many',
#   'people',
#   'might',
#   'like',
#   'it',
#   'but',
#   'for',
#   'me',
#   'absolutely',
#   'nooooooooi',
#   'have',
#   'a',
#   'seagull',
#   'guitar',
#   'so',
#   'by',
#   'its',
#   'nature',
#   'it',
#   'sounds',
#   'mellow',
#   'warm',
#   'and',
#   'mild',
#   'with',
#   'stock',
#   'strings',
#   'so',
#   'when',
#   'my',
#   'strings',
#   'wear',
#   'out',
#   'i',
#   'got',
#   'this',
#   'now',
#   'i',
#   'feel',
#   'like',
#   'playing',
#   'an',
#   'emg',
#   'bridge',
#   'on',
#   'my',
#   'fenderarchtops',
#   'neck',
#   'position',
#   'without',
#   'the',
#   'power',
#   'that',
#   'an',
#   'emg',
#   'pickup',
#   'has',
#   'to',
#   'offer',
#   'yes',
#   'it',
#   'is',
#   'that',
#   'bad',
#   'you',
#   'cant',
#   'do',
#   'this',
#   'to',
#   'guitars',
#   'like',
#   'seagullsbottom',
#   'line',
#   'i',
#   'recommend',
#   'this',
#   'string',
#   'set',
#   'for',
#   'people',
#   'looking',
#   'to',
#   'boost',
#   'distortion',
#   'on',
#   'their',
#   'guitar',
#   'if',
#   'you',
#   'have',
#   'guitars',
#   'like',
#   'seagulls',
#   'or',
#   'so',
#   'definitely',
#   'avoid',
#   'this',
#   'string'],
#  ['another',
#   'item',
#   'never',
#   'received',
#   'but',
#   'i',
#   'would',
#   'not',
#   'use',
#   'anything',
#   'over',
#   '88',
#   'mm',
#   'anyway',
#   'was',
#   'mean',
#   'for',
#   'experimentation',
#   'i',
#   'have',
#   'learned',
#   'since',
#   'this',
#   'purchase'],
#  ['this',
#   'product',
#   'is',
#   'not',
#   'what',
#   'it',
#   'seems',
#   'it',
#   'has',
#   'a',
#   'cool',
#   'name',
#   'but',
#   'thats',
#   'about',
#   'it',
#   'its',
#   'a',
#   'tool',
#   'oil',
#   'that',
#   'stinks',
#   'i',
#   'tried',
#   'my',
#   'best',
#   'to',
#   'get',
#   'use',
#   'to',
#   'this',
#   'product',
#   'but',
#   'learned',
#   'that',
#   'there',
#   'are',
#   'much',
#   'better',
#   'ways',
#   'after',
#   'going',
#   'into',
#   'the',
#   'studio',
#   'and',
#   'recording',
#   'for',
#   'the',
#   '1st',
#   'time',
#   'after',
#   'doing',
#   'away',
#   'with',
#   'the',
#   'fastfret',
#   'my',
#   'playing',
#   'has',
#   'improved',
#   'and',
#   'i',
#   'hardly',
#   'ever',
#   'have',
#   'to',
#   'change',
#   'my',
#   'string',
#   'because',
#   'of',
#   'gook',
#   'not',
#   'to',
#   'mention',
#   'that',
#   'getting',
#   'that',
#   'crap',
#   'on',
#   'my',
#   'fingers',
#   'was',
#   'just',
#   'nasty',
#   'i',
#   'now',
#   'use',
#   'old',
#   'english',
#   'and',
#   'my',
#   'guitars',
#   'thank',
#   'me',
#   'my',
#   'nose',
#   'thanks',
#   'me',
#   'and',
#   'my',
#   'fingers',
#   'thank',
#   'me',
#   'you',
#   'will',
#   'too'],
#  ['it',
#   'just',
#   'randomly',
#   'pops',
#   'off',
#   'my',
#   'bass',
#   'its',
#   'so',
#   'slick',
#   'that',
#   'when',
#   'you',
#   'let',
#   'go',
#   'it',
#   'the',
#   'neck',
#   'just',
#   'goes',
#   'straight',
#   'down',
#   'i',
#   'hate',
#   'it'],
#  ['years',
#   'ago',
#   'i',
#   'used',
#   'the',
#   'clayton',
#   '34small',
#   'teardrop34',
#   'picks',
#   'i',
#   'couldnt',
#   'tell',
#   'from',
#   'the',
#   'picture',
#   'that',
#   'these',
#   'were',
#   'full',
#   'size',
#   'and',
#   'i',
#   'didnt',
#   'check',
#   'the',
#   'size',
#   'in',
#   'the',
#   'description',
#   'i',
#   'still',
#   'had',
#   'a',
#   'few',
#   'of',
#   'the',
#   'small',
#   'ones',
#   'so',
#   'i',
#   'used',
#   'them',
#   'as',
#   'templates',
#   'to',
#   'cut',
#   'these',
#   'down',
#   'i',
#   'would',
#   'have',
#   'rated',
#   'them',
#   'higher',
#   'if',
#   'i',
#   'could',
#   'have',
#   'used',
#   'them',
#   'as',
#   'is',
#   'its',
#   'my',
#   'own',
#   'fault',
#   'for',
#   'not',
#   'looking',
#   'at',
#   'the',
#   'specifications',
#   'i',
#   'purchased',
#   'two',
#   'six',
#   'packs',
#   'of',
#   'clayton',
#   'teardrop',
#   'picks',
#   'but',
#   'found',
#   'dunlop',
#   '423r60',
#   '060mm',
#   'orange',
#   'tortex',
#   'small',
#   'tear',
#   'drop',
#   'guitar',
#   'picks',
#   '36pack',
#   'which',
#   'are',
#   'a',
#   'lot',
#   'cheaper'],
#  ['total',
#   'flimsy',
#   'junk',
#   'it',
#   'leans',
#   'wayyy',
#   'too',
#   'far',
#   'back',
#   'ill',
#   'be',
#   'damned',
#   'if',
#   'i',
#   'put',
#   'my',
#   '1000',
#   'guitars',
#   'on',
#   'these',
#   'things',
#   'on',
#   'the',
#   'other',
#   'hand',
#   'chromacast',
#   'makes',
#   'one',
#   'thats',
#   'very',
#   'close',
#   'to',
#   'this',
#   'price',
#   'and',
#   'i',
#   'doubt',
#   'that',
#   'it',
#   'could',
#   'have',
#   'been',
#   'more',
#   'for',
#   'the',
#   'money',
#   'i',
#   'paidin',
#   'summary',
#   'do',
#   'not',
#   'buy',
#   'this',
#   'piece',
#   'of',
#   'junk'],
#  ['for',
#   'something',
#   'but',
#   'not',
#   'a',
#   'guitar',
#   'wasnt',
#   'sure',
#   'what',
#   'to',
#   'do',
#   'with',
#   'it',
#   'so',
#   'i',
#   'now',
#   'use',
#   'it',
#   'to',
#   'mount',
#   'a',
#   'large',
#   'cookbook',
#   'or',
#   'notepad',
#   'computer',
#   'so',
#   'i',
#   'can',
#   'follow',
#   'a',
#   'recipe',
#   'it',
#   'seems',
#   'to',
#   'work',
#   'okay',
#   'for',
#   'that',
#   'just',
#   'dont',
#   'use',
#   'this',
#   'for',
#   'guitars',
#   'an',
#   'electric',
#   'guitar',
#   'will',
#   'slide',
#   'out',
#   'and',
#   'fall',
#   'because',
#   'it',
#   'leans',
#   'back',
#   'too',
#   'far',
#   'and',
#   'the',
#   'arms',
#   'have',
#   'no',
#   'grip',
#   'this',
#   'thing',
#   'was',
#   'obviously',
#   'created',
#   'by',
#   'a',
#   'monkey',
#   'in',
#   'some',
#   'closed',
#   'door',
#   'creative',
#   'testing',
#   'experimental',
#   'project',
#   'it',
#   'may',
#   'even',
#   'give',
#   'you',
#   'aids',
#   'but',
#   'probably',
#   'not',
#   'however',
#   'animals',
#   'could',
#   'have',
#   'been',
#   'harmed',
#   'in',
#   'the',
#   'making',
#   'but',
#   'most',
#   'likely',
#   'and',
#   'in',
#   'reality',
#   'it',
#   'will',
#   'not',
#   'hold',
#   'your',
#   'guitar',
#   'in',
#   'a',
#   'safe',
#   'manner'],
#  ['i',
#   'bought',
#   'a',
#   'set',
#   'as',
#   'they',
#   'were',
#   'recommended',
#   'to',
#   'get',
#   'the',
#   'tone',
#   'i',
#   'was',
#   'looking',
#   'for',
#   'on',
#   'my',
#   '7',
#   'week',
#   'old',
#   'guitar',
#   'installed',
#   'as',
#   'usual',
#   'and',
#   'tuned',
#   'them',
#   'they',
#   'sounded',
#   'good',
#   'when',
#   'played',
#   'open',
#   'but',
#   'compressing',
#   'them',
#   'was',
#   'nearly',
#   'impossible',
#   'my',
#   'capo',
#   'could',
#   'not',
#   'even',
#   'hold',
#   'them',
#   'i',
#   'set',
#   'the',
#   'guitar',
#   'aside',
#   'for',
#   'a',
#   'few',
#   'minutes',
#   'and',
#   'heard',
#   'the',
#   'wood',
#   'creaking',
#   'when',
#   'i',
#   'looked',
#   'the',
#   'face',
#   'of',
#   'the',
#   'guitar',
#   'was',
#   'bowing',
#   'up',
#   'and',
#   'the',
#   'bridge',
#   'was',
#   'pulling',
#   'up',
#   'and',
#   'back',
#   'as',
#   'if',
#   'they',
#   'were',
#   'trying',
#   'to',
#   'pry',
#   'it',
#   'off',
#   'i',
#   'released',
#   'the',
#   'tension',
#   'on',
#   'all',
#   'the',
#   'strings',
#   'as',
#   'fast',
#   'as',
#   'i',
#   'could',
#   'and',
#   'left',
#   'it',
#   'i',
#   'returned',
#   'them',
#   'and',
#   'got',
#   'some',
#   'lighter',
#   'ones',
#   'but',
#   'to',
#   'no',
#   'avail',
#   'the',
#   'body',
#   'is',
#   'cracked',
#   'around',
#   'the',
#   'bridge',
#   'and',
#   'it',
#   'is',
#   'useless',
#   'now',
#   'use',
#   'at',
#   'your',
#   'own',
#   'risk',
#   'i',
#   'personally',
#   'wouldnt',
#   'give',
#   'a',
#   'nickel',
#   'for',
#   'them'],
#  ['this',
#   'is',
#   'an',
#   'update',
#   'to',
#   'my',
#   'original',
#   'review',
#   'because',
#   'i',
#   'have',
#   'now',
#   'fully',
#   'tested',
#   'two',
#   'of',
#   'these',
#   'capos',
#   'im',
#   'truly',
#   'surprised',
#   'by',
#   'all',
#   'the',
#   'good',
#   'reviews',
#   'here',
#   'im',
#   'not',
#   'sure',
#   'how',
#   'its',
#   'possible',
#   'ive',
#   'already',
#   'outlined',
#   'below',
#   'in',
#   'my',
#   'original',
#   'review',
#   'that',
#   'these',
#   'are',
#   'not',
#   'jim',
#   'dunlop',
#   'capos',
#   'i',
#   'had',
#   'purchased',
#   'two',
#   'which',
#   'i',
#   'have',
#   'now',
#   'given',
#   'away',
#   'to',
#   'student',
#   'players',
#   'as',
#   'i',
#   'cannot',
#   'use',
#   'them',
#   'i',
#   'tested',
#   'the',
#   'capos',
#   'on',
#   'a',
#   'standard',
#   'acoustic',
#   'and',
#   'also',
#   'an',
#   'electric',
#   'guitar',
#   'the',
#   'e',
#   'string',
#   'buzzes',
#   'when',
#   'the',
#   'capo',
#   'is',
#   'applied',
#   'and',
#   'no',
#   'amount',
#   'of',
#   'adjusting',
#   'the',
#   'capo',
#   'would',
#   'stop',
#   'the',
#   'buzz',
#   'from',
#   'occurring',
#   'both',
#   'capos',
#   'had',
#   'this',
#   'very',
#   'same',
#   'problemwhen',
#   'i',
#   'received',
#   'these',
#   'capos',
#   'i',
#   'noticed',
#   'right',
#   'away',
#   'that',
#   'they',
#   'were',
#   'not',
#   'the',
#   'same',
#   'excellent',
#   'quality',
#   'as',
#   'actual',
#   'jim',
#   'dunlop',
#   'capos',
#   'the',
#   'craftsmanship',
#   'was',
#   'visibly',
#   'lower',
#   'quality',
#   'and',
#   'the',
#   'materials',
#   'used',
#   'are',
#   'a',
#   'lesser',
#   'quality',
#   'than',
#   'official',
#   'jim',
#   'dunlop',
#   'capos',
#   'the',
#   'rubber',
#   'has',
#   'a',
#   'strong',
#   'odor',
#   'and',
#   'there',
#   'is',
#   'no',
#   'brandname',
#   'printed',
#   'anywhere',
#   'on',
#   'the',
#   'product',
#   'as',
#   'a',
#   'professional',
#   'musician',
#   'i',
#   'need',
#   'to',
#   'purchase',
#   'reputable',
#   'brandname',
#   'products',
#   'because',
#   'i',
#   'cant',
#   'afford',
#   'to',
#   'have',
#   'my',
#   'gear',
#   'failing',
#   'during',
#   'performances',
#   'i',
#   'have',
#   'no',
#   'idea',
#   'about',
#   'the',
#   'future',
#   'performance',
#   'of',
#   'these',
#   'capos',
#   'because',
#   'they',
#   'have',
#   'no',
#   'apparent',
#   'brand',
#   'and',
#   'no',
#   'measurable',
#   'reputation',
#   'when',
#   'i',
#   'contacted',
#   'the',
#   'seller',
#   'they',
#   'were',
#   'not',
#   'honest',
#   'with',
#   'me'],
#  ['i',
#   'know',
#   'many',
#   'people',
#   'love',
#   'the',
#   'design',
#   'but',
#   'i',
#   'find',
#   'it',
#   'much',
#   'too',
#   'frustrating',
#   'you',
#   'have',
#   'to',
#   'be',
#   'very',
#   'careful',
#   'putting',
#   'it',
#   'on',
#   'the',
#   'fret',
#   'correctly',
#   'then',
#   'snap',
#   'it',
#   'in',
#   'then',
#   'turn',
#   'and',
#   'turn',
#   'the',
#   'screw',
#   'oops',
#   'dont',
#   'let',
#   'it',
#   'snap',
#   'off',
#   'again',
#   'and',
#   'fall',
#   'off',
#   'while',
#   'trying',
#   'to',
#   'turn',
#   'the',
#   'screw',
#   'then',
#   'you',
#   'have',
#   'to',
#   'go',
#   'through',
#   'the',
#   'whole',
#   'routine',
#   'again',
#   'to',
#   'take',
#   'it',
#   'off',
#   'and',
#   'move',
#   'it',
#   'to',
#   'another',
#   'fret',
#   'and',
#   'put',
#   'it',
#   'on',
#   'again',
#   'what',
#   'a',
#   'farce',
#   'this',
#   'is',
#   'the',
#   'worst',
#   'capo',
#   'ive',
#   'owned',
#   'and',
#   'ive',
#   'tried',
#   'nearly',
#   'every',
#   'brand',
#   'and',
#   'type',
#   'yeah',
#   'ive',
#   'had',
#   'people',
#   'show',
#   'me',
#   'how',
#   'to',
#   'do',
#   'it',
#   'right',
#   'and',
#   'i',
#   'know',
#   'to',
#   'do',
#   'it',
#   'right',
#   'its',
#   'just',
#   'wrong',
#   'to',
#   'have',
#   'to',
#   'spend',
#   'so',
#   'much',
#   'time',
#   'slipping',
#   'it',
#   'on',
#   'snapping',
#   'it',
#   'screwing',
#   'it',
#   'in',
#   'screwing',
#   'it',
#   'off',
#   'having',
#   'it',
#   'fall',
#   'off',
#   'forget',
#   'it',
#   'its',
#   'garbage',
#   'to',
#   'me',
#   'also',
#   'while',
#   'im',
#   'getting',
#   'my',
#   'callouses',
#   'worked',
#   'out',
#   'playing',
#   'for',
#   'two',
#   'hours',
#   'every',
#   'day',
#   'the',
#   'last',
#   'thing',
#   'i',
#   'want',
#   'is',
#   'to',
#   'pinch',
#   'my',
#   'fingers',
#   'against',
#   'metal',
#   'trying',
#   'to',
#   'turn',
#   'a',
#   'screw',
#   'its',
#   'actually',
#   'slightly',
#   'painful',
#   'to',
#   'the',
#   'fingers',
#   'momentarily',
#   'but',
#   'why',
#   'have',
#   'to',
#   'deal',
#   'with',
#   'that',
#   'to',
#   'work',
#   'with',
#   'this',
#   'design',
#   'seems',
#   'like',
#   'it',
#   'was',
#   'a',
#   'non',
#   'guitar',
#   'player',
#   'who',
#   'came',
#   'up',
#   'with',
#   'it',
#   'the',
#   'only',
#   'good',
#   'thing',
#   'i',
#   'can',
#   'say',
#   'about',
#   'it',
#   'is',
#   'looks',
#   'durableno',
#   'thanks'],
#  ['i',
#   'bought',
#   'this',
#   'hoping',
#   'to',
#   'use',
#   'as',
#   'intended',
#   'angled',
#   'into',
#   'guitar',
#   'straight',
#   'into',
#   'mixer',
#   'wrong',
#   'have',
#   'to',
#   'use',
#   'it',
#   'the',
#   'other',
#   'way',
#   'around',
#   'sad'],
#  ['only',
#   'lasted',
#   '2yr',
#   'i',
#   'have',
#   'a',
#   'lot',
#   'of',
#   'cheaper',
#   'cables',
#   'that',
#   'get',
#   'more',
#   'useabuse',
#   'than',
#   'this',
#   'one',
#   'that',
#   'have',
#   'outlasted',
#   'it'],
#  ['could',
#   'not',
#   'get',
#   'to',
#   'fit',
#   'small',
#   'sound',
#   'hole',
#   'once',
#   'in',
#   'sound',
#   'hole',
#   'pickup',
#   'did',
#   'not',
#   'work',
#   'at',
#   'all',
#   'would',
#   'not',
#   'buy',
#   'it'],
#  ['ive',
#   'used',
#   'three',
#   'pop',
#   'filters',
#   'in',
#   'my',
#   'experiences',
#   'with',
#   'home',
#   'recording',
#   'and',
#   'podcasting',
#   'this',
#   'one',
#   'is',
#   'the',
#   'worst',
#   'the',
#   'plastic',
#   'screw',
#   'yes',
#   'plastic',
#   'that',
#   'is',
#   'meant',
#   'to',
#   'grip',
#   'the',
#   'pole',
#   'that',
#   'you',
#   'attach',
#   'the',
#   'pop',
#   'filter',
#   'to',
#   'is',
#   'completely',
#   'incapable',
#   'of',
#   'supporting',
#   'its',
#   'own',
#   'weight',
#   'at',
#   'nearly',
#   'any',
#   'angle',
#   'badjust',
#   'badsecondly',
#   'there',
#   'is',
#   'a',
#   'metal',
#   'piece',
#   'that',
#   'secures',
#   'the',
#   'flex',
#   'arm',
#   'to',
#   'the',
#   'clamp',
#   'it',
#   'seemed',
#   'loose',
#   'after',
#   'i',
#   'got',
#   'it',
#   'out',
#   'of',
#   'the',
#   'packaging',
#   'and',
#   'the',
#   'flex',
#   'arm',
#   'would',
#   'wobble',
#   'and',
#   'rotate',
#   'in',
#   'that',
#   'spot',
#   'causing',
#   'a',
#   'major',
#   'problem',
#   'when',
#   'it',
#   'came',
#   'to',
#   'proper',
#   'placement',
#   'after',
#   'twisting',
#   'on',
#   'it',
#   'twice',
#   'i',
#   'stripped',
#   'it',
#   'out',
#   'now',
#   'the',
#   'thing',
#   'is',
#   'worthless',
#   'im',
#   'returning',
#   'it',
#   'asapi',
#   'would',
#   'rather',
#   'go',
#   'to',
#   'a',
#   'ladys',
#   'bag',
#   'flea',
#   'market',
#   'sale',
#   'with',
#   'a',
#   'crazy',
#   'woman',
#   'for',
#   'a',
#   'day',
#   'than',
#   'continue',
#   'to',
#   'put',
#   'up',
#   'with',
#   'this',
#   'thing',
#   'do',
#   'yourself',
#   'a',
#   'huge',
#   'favor',
#   'and',
#   'buy',
#   'the',
#   'nady',
#   '6',
#   'pop',
#   'filter',
#   'if',
#   'you',
#   'dont',
#   'youll',
#   'wish',
#   'you',
#   'did'],
#  ['its',
#   'poorly',
#   'made',
#   'with',
#   'attention',
#   'to',
#   'detail',
#   'i',
#   'ordered',
#   'them',
#   'to',
#   'fit',
#   'on',
#   'my',
#   'dual',
#   'mic',
#   'clamp',
#   'purchased',
#   'here',
#   'at',
#   'amazon',
#   'but',
#   'they',
#   'will',
#   'not',
#   'screw',
#   'down',
#   'all',
#   'the',
#   'way',
#   'and',
#   'are',
#   'losse',
#   'it',
#   'is',
#   'useless',
#   'other',
#   'mic',
#   'holders',
#   'from',
#   'different',
#   'manufacturers',
#   'work',
#   'fine'],
#  ['just',
#   'assembly',
#   'for',
#   'a',
#   'try',
#   'only',
#   'few',
#   'rolls',
#   'with',
#   'music',
#   'its',
#   'had',
#   'some',
#   'hole',
#   'on',
#   'head',
#   'thats',
#   'mean',
#   'bad',
#   'quality',
#   'buyer',
#   'beware',
#   'for',
#   'this',
#   'kind',
#   'of'],
#  ['crap',
#   'these',
#   'strings',
#   'are',
#   'bad',
#   'do',
#   'not',
#   'buy',
#   'them',
#   'if',
#   'you',
#   'play',
#   'any',
#   'kind',
#   'of',
#   'harder',
#   'music',
#   'or',
#   'do',
#   'a',
#   'lot',
#   'of',
#   'string',
#   'bends',
#   'unless',
#   'you',
#   'like',
#   'having',
#   'strings',
#   'almost',
#   'take',
#   'out',
#   'your',
#   'eyes',
#   'then',
#   'by',
#   'all',
#   'means',
#   'buy',
#   'em',
#   'errrrr',
#   'i',
#   'always',
#   'buy',
#   'ernie',
#   'balls',
#   'but',
#   'i',
#   'got',
#   'cheap',
#   'and',
#   'tryed',
#   'to',
#   'save',
#   'a',
#   'few',
#   'buck',
#   'and',
#   'buy',
#   '2',
#   '3',
#   'packs',
#   'of',
#   'these',
#   'hunks',
#   'of',
#   'crap',
#   'for',
#   'under',
#   '18',
#   'bucks',
#   'i',
#   'should',
#   'have',
#   'spent',
#   'the',
#   'extra',
#   '7',
#   'bucks',
#   'and',
#   'got',
#   'the',
#   '6',
#   'pack',
#   'of',
#   'ernies',
#   'i',
#   'didnt',
#   'even',
#   'get',
#   'a',
#   'week',
#   'out',
#   'of',
#   'them',
#   'and',
#   'they',
#   'were',
#   'rusted',
#   'and',
#   'poppin',
#   'off',
#   'left',
#   'and',
#   'rightnever',
#   'again'],
#  ['this',
#   'piece',
#   'of',
#   'plastic',
#   'is',
#   'just',
#   'terrible',
#   'youd',
#   'be',
#   'better',
#   'off',
#   'with',
#   'a',
#   'couple',
#   'of',
#   'books',
#   'and',
#   'a',
#   'towelnot',
#   'recommended'],
#  ['go',
#   'build',
#   'your',
#   'own',
#   'build',
#   'it',
#   'to',
#   'your',
#   'specs',
#   'and',
#   'have',
#   'a',
#   'solid',
#   'stand',
#   'if',
#   'not',
#   'you',
#   'can',
#   'find',
#   'a',
#   'lot',
#   'better',
#   'head',
#   'stands',
#   'this',
#   'one',
#   'was',
#   'a',
#   'huge',
#   'disappointment',
#   'does',
#   'not',
#   'do',
#   'what',
#   'it',
#   'says',
#   'and',
#   'can',
#   'get',
#   'you',
#   'frustrated',
#   'quick',
#   'im',
#   'back',
#   'with',
#   'my',
#   'wood',
#   'block',
#   'and',
#   'am',
#   'happy'],
#  ['i',
#   'might',
#   'have',
#   'done',
#   'something',
#   'wrongi',
#   'read',
#   'in',
#   'a',
#   'review',
#   'that',
#   'these',
#   'hold',
#   'six',
#   'picksit',
#   'held',
#   'three',
#   'real',
#   'well',
#   'but',
#   'on',
#   'the',
#   'fourth',
#   'insert',
#   'the',
#   'thing',
#   'just',
#   'fell',
#   'apartill',
#   'just',
#   'keep',
#   'using',
#   'my',
#   'pockets'],
#  ['man',
#   'this',
#   'thing',
#   'would',
#   'not',
#   'even',
#   'hold',
#   'my',
#   'normal',
#   'sized',
#   'picks',
#   'do',
#   'not',
#   'buy',
#   'it',
#   'is',
#   'a',
#   'wast',
#   'of',
#   'money',
#   'ug'],
#  ['i',
#   'use',
#   'clayton',
#   '126mm',
#   'picks',
#   'a',
#   'heavy',
#   'pick',
#   'but',
#   'certainly',
#   'not',
#   'oversized',
#   'my',
#   'picks',
#   'dont',
#   'fit',
#   'if',
#   'i',
#   'shove',
#   'them',
#   'in',
#   'i',
#   'cant',
#   'get',
#   'them',
#   'out',
#   'also',
#   'this',
#   'thing',
#   'is',
#   'huge',
#   'for',
#   'the',
#   'back',
#   'of',
#   'the',
#   'neck'],
#  ['dont',
#   'last',
#   'but',
#   'a',
#   'couple',
#   'weeksterrible',
#   'feed',
#   'back',
#   'as',
#   'the',
#   'ends',
#   'near',
#   'the',
#   'plugs',
#   'detirorate',
#   'quickly',
#   'will',
#   'never',
#   'buy',
#   'again',
#   'even',
#   'if',
#   'only',
#   '5',
#   'bucks'],
#  ['second',
#   'one',
#   'i',
#   'bought',
#   'lousy',
#   'build',
#   'quality',
#   'and',
#   'only',
#   'lasted',
#   '3',
#   'months',
#   'went',
#   'through',
#   'two',
#   'of',
#   'these',
#   'before',
#   'i',
#   'learned',
#   'my',
#   'lesson',
#   'dont',
#   'waste',
#   'your',
#   'money',
#   'on',
#   'this',
#   'junk',
#   'i',
#   'love',
#   'planet',
#   'waves',
#   'stuff',
#   'normally',
#   'but',
#   'these',
#   'are',
#   'junk'],
#  ['i',
#   'got',
#   'a',
#   'couple',
#   'of',
#   'theseonly',
#   'buy',
#   'this',
#   'cable',
#   'if',
#   'there',
#   'is',
#   'no',
#   'chance',
#   'that',
#   'it',
#   'will',
#   'be',
#   'ever',
#   'used',
#   'in',
#   'the',
#   'real',
#   'worldafter',
#   'only',
#   'a',
#   'month',
#   'mine',
#   'has',
#   'developed',
#   'a',
#   'nasty',
#   'short',
#   'in',
#   'the',
#   'plugand',
#   'of',
#   'course',
#   'since',
#   'this',
#   'cord',
#   'is',
#   'moldedsealed',
#   'up',
#   'tight',
#   'it',
#   'cant',
#   'be',
#   'repairedyou',
#   'could',
#   'cut',
#   'off',
#   'the',
#   'plug',
#   'and',
#   'solder',
#   'a',
#   'good',
#   '14',
#   'inch',
#   'plug',
#   'on',
#   'itbut',
#   'why',
#   'botherjust',
#   'save',
#   'your',
#   'headaches',
#   'and',
#   'money',
#   'and',
#   'buy',
#   'a',
#   'good',
#   'heavy',
#   'duty',
#   'cordthis',
#   'cord',
#   'is',
#   'too',
#   'flimsyits',
#   'junk',
#   'with',
#   'a',
#   'fancy',
#   'molded',
#   'plastic',
#   'ergonomic',
#   'looking',
#   'plug',
#   'housingbut',
#   'inside',
#   'its',
#   'junkthrown',
#   'away',
#   'moneybuy',
#   'a',
#   'lottery',
#   'scratch',
#   'off',
#   'instead'],
#  ['well',
#   'this',
#   'cable',
#   'certainly',
#   'didnt',
#   'last',
#   'long',
#   'as',
#   'the',
#   'title',
#   'says',
#   '8',
#   'weeks',
#   'bought',
#   'a',
#   'new',
#   'fender',
#   'mustang2',
#   'v2',
#   'amp',
#   'a',
#   'week',
#   'and',
#   'a',
#   'half',
#   'ago',
#   'last',
#   'night',
#   'amp',
#   'would',
#   'turn',
#   'on',
#   'but',
#   'wasnt',
#   'putting',
#   'out',
#   'any',
#   'sound',
#   'from',
#   'the',
#   'guitar',
#   'messed',
#   'around',
#   'a',
#   'bit',
#   'and',
#   'it',
#   'started',
#   'to',
#   'work',
#   'today',
#   'same',
#   'thing',
#   'and',
#   'its',
#   'obvious',
#   'nothing',
#   'is',
#   'going',
#   'from',
#   'guitar',
#   'to',
#   'amp',
#   'thought',
#   'i',
#   'had',
#   'a',
#   'bad',
#   'jack',
#   'in',
#   'my',
#   'new',
#   'amp',
#   'and',
#   'wasnt',
#   'very',
#   'happy',
#   'got',
#   'out',
#   'the',
#   'old',
#   'amp',
#   'and',
#   'guess',
#   'what',
#   'nothing',
#   'there',
#   'either',
#   'at',
#   'least',
#   'my',
#   'new',
#   'amp',
#   'is',
#   'working',
#   'and',
#   'i',
#   'only',
#   'have',
#   'to',
#   'replace',
#   'a',
#   '12',
#   'cordmaybe',
#   'im',
#   'just',
#   'unlucky',
#   'and',
#   'got',
#   'a',
#   'bad',
#   'one',
#   'and',
#   'if',
#   'i',
#   'bought',
#   'it',
#   'at',
#   'a',
#   'local',
#   'store',
#   'id',
#   'return',
#   'it',
#   'not',
#   'going',
#   'through',
#   'the',
#   'hassles',
#   'of',
#   'mailing',
#   'it',
#   'back',
#   'or',
#   'asking',
#   'for',
#   'a',
#   'refund',
#   'will',
#   'just',
#   'move',
#   'on',
#   'to',
#   'another',
#   'companys',
#   'cord'],
#  ['the',
#   'cable',
#   'died',
#   'on',
#   'me',
#   'in',
#   'less',
#   'than',
#   'a',
#   'month',
#   'very',
#   'disappointed',
#   'in',
#   'built',
#   'quality'],
#  ['i',
#   'purchased',
#   '2',
#   'of',
#   'these',
#   'items',
#   'to',
#   'use',
#   'with',
#   'my',
#   'band',
#   'for',
#   'the',
#   'guitarists',
#   'i',
#   'was',
#   'disapointed',
#   'when',
#   'i',
#   'mounted',
#   'a',
#   'shure',
#   'sm',
#   '58',
#   'mic',
#   'on',
#   'it',
#   'and',
#   'found',
#   'that',
#   'the',
#   'goose',
#   'neck',
#   'would',
#   'not',
#   'stay',
#   'erect',
#   'these',
#   'are',
#   'made',
#   'far',
#   'too',
#   'loose',
#   'and',
#   'flexible',
#   'for',
#   'most',
#   'professional',
#   'mics',
#   'they',
#   'may',
#   'work',
#   'on',
#   'very',
#   'small',
#   'and',
#   'light',
#   'weight',
#   'units',
#   'but',
#   'for',
#   'my',
#   'needs',
#   'they',
#   'are',
#   'totally',
#   'unuseable',
#   'it',
#   'would',
#   'have',
#   'been',
#   'helpful',
#   'to',
#   'include',
#   'the',
#   'suggested',
#   'weight',
#   'that',
#   'this',
#   'goose',
#   'neck',
#   'would',
#   'support',
#   'in',
#   'the',
#   'sales',
#   'description',
#   'i',
#   'wasted',
#   'my',
#   'money',
#   'dont',
#   'waste',
#   'yours',
#   'perhaps',
#   'viagra',
#   'would',
#   'be',
#   'helpful'],
#  ['this',
#   'arrived',
#   'and',
#   'when',
#   'i',
#   'tried',
#   'to',
#   'use',
#   'it',
#   'it',
#   'turned',
#   'out',
#   'that',
#   'the',
#   'male',
#   'threads',
#   'were',
#   'some',
#   'oddball',
#   'metric',
#   'size',
#   'that',
#   'does',
#   'not',
#   'fit',
#   'any',
#   'standard',
#   'adapterinstead',
#   'these',
#   'theads',
#   'stripped',
#   'the',
#   'fitting',
#   'on',
#   'my',
#   'mike',
#   'clip',
#   'so',
#   'now',
#   'i',
#   'have',
#   'to',
#   'go',
#   'somewhere',
#   'else',
#   'and',
#   'buy',
#   'a',
#   'new',
#   'gooseneck',
#   'and',
#   'a',
#   'clipthis',
#   'is',
#   'such',
#   'a',
#   'standard',
#   'item',
#   'that',
#   'there',
#   'is',
#   'no',
#   'excuse',
#   'for',
#   'making',
#   'it',
#   'with',
#   'nonstandard',
#   'threads',
#   'and',
#   'no',
#   'excuse',
#   'at',
#   'all',
#   'for',
#   'advertising',
#   'it',
#   'as',
#   'standard',
#   '58ths'],
#  ['i',
#   'have',
#   'several',
#   'mxr',
#   'pedals',
#   'every',
#   'one',
#   'is',
#   'superbexcept',
#   'for',
#   'this',
#   'phase',
#   '90',
#   'the',
#   'nonscript',
#   'version',
#   'reviewed',
#   'here',
#   'this',
#   'phase',
#   '90',
#   'is',
#   'worthless',
#   'for',
#   'anyone',
#   'who',
#   'wants',
#   'to',
#   'use',
#   'it',
#   'while',
#   'playing',
#   'clean',
#   'for',
#   'it',
#   'adds',
#   'a',
#   'tsunami',
#   'of',
#   'irritating',
#   'distortion',
#   'a',
#   'swoosh',
#   'of',
#   'sonic',
#   'dirt',
#   'i',
#   'did',
#   'some',
#   'research',
#   'and',
#   'discovered',
#   'that',
#   'other',
#   'people',
#   'who',
#   'also',
#   'hate',
#   'this',
#   'pedals',
#   'distortion',
#   'suggest',
#   'some',
#   'modifications',
#   'look',
#   'up',
#   'mxr',
#   'phase',
#   '90',
#   'mods',
#   'and',
#   'eriks',
#   'corner',
#   'will',
#   'show',
#   'you',
#   'how',
#   'i',
#   'made',
#   'the',
#   'r28',
#   'c11',
#   'and',
#   'c12',
#   'modifications',
#   'the',
#   'result',
#   'a',
#   'slightly',
#   'improved',
#   'phaser',
#   'one',
#   'that',
#   'still',
#   'churned',
#   'out',
#   'plenty',
#   'of',
#   'distortion',
#   'finally',
#   'i',
#   'tried',
#   'adjusting',
#   'the',
#   'internal',
#   'trim',
#   'pot',
#   'on',
#   'no',
#   'setting',
#   'could',
#   'i',
#   'get',
#   'rid',
#   'of',
#   'you',
#   'guessed',
#   'it',
#   'distortion',
#   'i',
#   'spent',
#   'literally',
#   'hours',
#   'in',
#   'a',
#   'futile',
#   'and',
#   'frustrating',
#   'effort',
#   'to',
#   'make',
#   'this',
#   'pedal',
#   'sound',
#   'merely',
#   'acceptable',
#   'no',
#   'luck',
#   'bottom',
#   'line',
#   'if',
#   'you',
#   'want',
#   'a',
#   'phaser',
#   'that',
#   'doesnt',
#   'add',
#   'significant',
#   'distortion',
#   'avoid',
#   'this',
#   'incarnation',
#   'of',
#   'the',
#   'phase',
#   '90'],
#  ['okay',
#   'color',
#   'coding',
#   'is',
#   'a',
#   'great',
#   'ideadivas',
#   'will',
#   'not',
#   'use',
#   'the',
#   'red',
#   'ball',
#   'windscreenwhybecause',
#   'from',
#   'a',
#   'distance',
#   'it',
#   'looks',
#   'like',
#   'they',
#   'have',
#   'a',
#   'clown',
#   'noseno',
#   'kidding',
#   'i',
#   'have',
#   'had',
#   'several',
#   'tell',
#   'this',
#   'to',
#   'me',
#   'and',
#   'my',
#   'sound',
#   'tech',
#   'so',
#   'save',
#   'your',
#   'dough',
#   'buy',
#   'any',
#   'color',
#   'but',
#   'reddivas',
#   'what',
#   'can',
#   'i',
#   'say'],
#  ['yes',
#   'you',
#   'can',
#   'tweak',
#   'it',
#   'so',
#   'its',
#   'less',
#   'but',
#   'cant',
#   'even',
#   'use',
#   'it',
#   'for',
#   'recording',
#   'with',
#   'or',
#   'without',
#   'an',
#   'amp',
#   'so',
#   'much',
#   'hiss',
#   'its',
#   'unusable'],
#  ['do',
#   'not',
#   'use',
#   'these',
#   'to',
#   'polish',
#   'your',
#   'guitar',
#   'it',
#   'leaves',
#   'tons',
#   'of',
#   'small',
#   'fibers',
#   'all',
#   'over',
#   'and',
#   'is',
#   'hard',
#   'to',
#   'clean',
#   'up',
#   'a',
#   'total',
#   'disaster',
#   'these',
#   'are',
#   'good',
#   'for',
#   'maybe',
#   'wiping',
#   'up',
#   'dog',
#   'poop',
#   'but',
#   'not',
#   'cleaning',
#   'anything'],
#  ['if',
#   'you',
#   'are',
#   'looking',
#   'for',
#   'a',
#   '100',
#   'leather',
#   'mandolin',
#   'strap',
#   'consider',
#   'another',
#   'strap',
#   'the',
#   'outside',
#   'surface',
#   'of',
#   'the',
#   'planet',
#   'waves',
#   'strap',
#   'is',
#   'leather',
#   'but',
#   'the',
#   'inside',
#   'surface',
#   'is',
#   'some',
#   'kind',
#   'of',
#   'manmade',
#   'material',
#   'glued',
#   'to',
#   'the',
#   'thin',
#   'leather',
#   'part',
#   'i',
#   'will',
#   'be',
#   'ordering',
#   'the',
#   'levys',
#   'leather',
#   'mandolin',
#   'strap',
#   'walnut'],
#  ['i',
#   'bought',
#   'this',
#   'to',
#   'replace',
#   'a',
#   'cord',
#   'i',
#   'was',
#   'using',
#   'to',
#   'practice',
#   'my',
#   'guitar',
#   'my',
#   'first',
#   'cheap',
#   'cord',
#   'wasnt',
#   'actually',
#   'broken',
#   'but',
#   'i',
#   'didnt',
#   'want',
#   'any',
#   'down',
#   'time',
#   'so',
#   'i',
#   'had',
#   'this',
#   'just',
#   'sitting',
#   'there',
#   'as',
#   'a',
#   'replacement',
#   'fast',
#   'forward',
#   'some',
#   'time',
#   'and',
#   'i',
#   'just',
#   'wanted',
#   'to',
#   'try',
#   'it',
#   'out',
#   'even',
#   'though',
#   'my',
#   'cheap',
#   'cord',
#   'was',
#   'still',
#   'working',
#   'fine',
#   'i',
#   'really',
#   'wanted',
#   'to',
#   'just',
#   'try',
#   'out',
#   'the',
#   'new',
#   'cordi',
#   'really',
#   'wish',
#   'i',
#   'had',
#   'done',
#   'that',
#   'in',
#   'the',
#   'first',
#   '30',
#   'days',
#   'this',
#   'cord',
#   'did',
#   'not',
#   'work',
#   'right',
#   'at',
#   'all',
#   'it',
#   'seems',
#   'like',
#   'there',
#   'is',
#   'a',
#   'short',
#   'in',
#   'it',
#   'somewhere',
#   'i',
#   'had',
#   'to',
#   'unplugplug',
#   'maneuver',
#   'into',
#   'place',
#   'of',
#   'course',
#   'since',
#   'it',
#   'is',
#   'for',
#   'guitar',
#   'it',
#   'falls',
#   'almost',
#   'immediately',
#   'out',
#   'of',
#   'place',
#   'again',
#   'so',
#   'i',
#   'am',
#   'back',
#   'to',
#   'the',
#   'cheap',
#   'cord',
#   'that',
#   'hasnt',
#   'failed',
#   'unlike',
#   'this',
#   'brand',
#   'new',
#   'bad',
#   'cable'],
#  ['the',
#   'small',
#   'estring',
#   'and',
#   'the',
#   'g',
#   'string',
#   'both',
#   'broke',
#   'on',
#   'the',
#   'ball',
#   'end',
#   'while',
#   'tuning',
#   'i',
#   'havent',
#   'broke',
#   'a',
#   'string',
#   'while',
#   'tuning',
#   'in',
#   '20',
#   'years',
#   'never',
#   'ever',
#   'had',
#   'one',
#   'break',
#   'on',
#   'the',
#   'ball',
#   'endluckily',
#   'i',
#   'bought',
#   'the',
#   'three',
#   'packbut',
#   'i',
#   'cant',
#   'recommend',
#   'this',
#   'product'],
#  ['i',
#   'thought',
#   'something',
#   'was',
#   'drastically',
#   'wrong',
#   'with',
#   'my',
#   'guitar',
#   'but',
#   'it',
#   'was',
#   'these',
#   'strings',
#   'they',
#   'buzzed',
#   'and',
#   'move',
#   'so',
#   'much',
#   'they',
#   'hit',
#   'every',
#   'metal',
#   'on',
#   'every',
#   'fret'],
#  ['based',
#   'upon',
#   'some',
#   'of',
#   'the',
#   'other',
#   'reviews',
#   'i',
#   'feel',
#   'i',
#   'got',
#   'a',
#   'different',
#   'product',
#   'as',
#   'it',
#   'didnt',
#   'fit',
#   'the',
#   'descriptions',
#   'given',
#   'by',
#   'others',
#   'i',
#   'ordered',
#   'two',
#   'of',
#   'these',
#   'and',
#   'both',
#   'were',
#   'very',
#   'thin',
#   'material',
#   'not',
#   'sturdy',
#   'at',
#   'all',
#   'second',
#   'both',
#   'straps',
#   'were',
#   'not',
#   'adjustable',
#   'to',
#   '5934',
#   'both',
#   'mine',
#   'measured',
#   '4534',
#   'from',
#   'strap',
#   'button',
#   'hole',
#   'to',
#   'strap',
#   'button',
#   'hole',
#   'fullyextended',
#   'they',
#   'are',
#   'useless',
#   'to',
#   'me',
#   'as',
#   'my',
#   'guitar',
#   'a',
#   'dreadnought',
#   'covers',
#   'the',
#   'middle',
#   'of',
#   'my',
#   'chest',
#   'when',
#   'i',
#   'put',
#   'it',
#   'on',
#   'i',
#   'believe',
#   'i',
#   'was',
#   'given',
#   'a',
#   'substitute',
#   'product',
#   'since',
#   'when',
#   'i',
#   'ordered',
#   'these',
#   'straps',
#   'the',
#   'price',
#   'was',
#   'just',
#   '100',
#   'and',
#   'now',
#   'theyre',
#   'back',
#   'up',
#   'to',
#   '495',
#   'as',
#   'i',
#   'write',
#   'this',
#   'im',
#   'really',
#   'sick',
#   'of',
#   'these',
#   'amazon',
#   'substitutions',
#   'for',
#   'what',
#   'i',
#   'paid',
#   'i',
#   'wont',
#   'bother',
#   'returning',
#   'themnot',
#   'worth',
#   'the',
#   'hassle',
#   'i',
#   'will',
#   'donate',
#   'them',
#   'to',
#   'a',
#   'local',
#   'music',
#   'teacher',
#   'who',
#   'has',
#   'students',
#   'with',
#   'smaller',
#   'guitars',
#   'very',
#   'disappointed',
#   'warningif',
#   'you',
#   'see',
#   'a',
#   'price',
#   'drop',
#   'below',
#   '495',
#   'dont',
#   'buyits',
#   'probably',
#   'not',
#   'the',
#   'product',
#   'thats',
#   'described',
#   'here'],
#  ['i',
#   'really',
#   'wanted',
#   'this',
#   'to',
#   'work',
#   'but',
#   'it',
#   'doesnt',
#   'dont',
#   'botherit',
#   'doesnt',
#   'mute',
#   'the',
#   'strings',
#   'at',
#   'all',
#   'one',
#   'star',
#   'just',
#   'for',
#   'it',
#   'getting',
#   'here',
#   'on',
#   'time'],
#  ['i',
#   'bought',
#   'a',
#   'glaesel',
#   'bridge',
#   'this',
#   'glaesel',
#   'rubber',
#   'mute',
#   'together',
#   'i',
#   'bought',
#   'this',
#   'because',
#   'it',
#   'was',
#   'cheap',
#   'and',
#   'had',
#   'so',
#   'many',
#   'good',
#   'reviews',
#   'the',
#   'mute',
#   'fits',
#   'the',
#   'bridge',
#   'fine',
#   'but',
#   'compared',
#   'to',
#   'a',
#   'brass',
#   'mute',
#   'which',
#   'of',
#   'course',
#   'works',
#   'very',
#   'well',
#   'this',
#   'mute',
#   'seems',
#   'to',
#   'do',
#   'absolutely',
#   'nothing',
#   'there',
#   'is',
#   'almost',
#   'no',
#   'discernible',
#   'difference',
#   'in',
#   'playing',
#   'the',
#   'violin',
#   'with',
#   'or',
#   'without',
#   'this',
#   'mute',
#   'on',
#   'also',
#   'the',
#   'mute',
#   'can',
#   'affect',
#   'your',
#   'playing',
#   'so',
#   'certain',
#   'notes',
#   'screech',
#   'or',
#   'stutter',
#   'or',
#   'produce',
#   'other',
#   'undesirable',
#   'noisesif',
#   'you',
#   'want',
#   'or',
#   'need',
#   'a',
#   'mute',
#   'for',
#   'practicing',
#   'quietly',
#   'as',
#   'many',
#   'of',
#   'us',
#   'do',
#   'i',
#   'suggest',
#   'you',
#   'buy',
#   'something',
#   'else',
#   'this',
#   'item',
#   'does',
#   'not',
#   'work',
#   'and',
#   'is',
#   'a',
#   'total',
#   'waste',
#   'of',
#   'money',
#   'i',
#   'tried',
#   'this',
#   'mute',
#   'on',
#   'a',
#   'regular',
#   'acoustic',
#   'violin',
#   'as',
#   'well',
#   'as',
#   'a',
#   'new',
#   'electric',
#   'violin',
#   'bought',
#   'here',
#   'on',
#   'amazon',
#   'fyi',
#   'that',
#   'cheap',
#   'little',
#   'electric',
#   'violin',
#   'is',
#   'an',
#   'awesome',
#   'fun',
#   'item',
#   'just',
#   'make',
#   'sure',
#   'you',
#   'buythe',
#   'original',
#   'peg',
#   'drops',
#   'by',
#   'ardsley',
#   'aglaesel',
#   'selfadjusting',
#   '44',
#   'violin',
#   'bridge',
#   'mediumwith',
#   'iti',
#   'consider',
#   'this',
#   'mute',
#   'completely',
#   'useless',
#   'since',
#   'it',
#   'does',
#   'not',
#   'do',
#   'anything',
#   'at',
#   'all',
#   'it',
#   'does',
#   'not',
#   'mute',
#   'or',
#   'lower',
#   'the',
#   'volume',
#   'of',
#   'any',
#   'violin',
#   'in',
#   'any',
#   'noticeable',
#   'way'],
#  ['pedal',
#   'is',
#   'not',
#   'working',
#   'it',
#   'just',
#   'making',
#   'noise',
#   'poor',
#   'quality',
#   'controlactually',
#   'it',
#   'looks',
#   'like',
#   'used',
#   'pedal',
#   'not',
#   'like',
#   'newdont',
#   'recommend',
#   'this',
#   'product'],
#  ['i',
#   'purchased',
#   'this',
#   'as',
#   'an',
#   'extra',
#   'cv',
#   'controller',
#   'for',
#   'a',
#   'digitech',
#   'control',
#   '2',
#   'when',
#   'i',
#   'got',
#   'it',
#   'i',
#   'tried',
#   'it',
#   'out',
#   'as',
#   'a',
#   'volume',
#   'pedal',
#   'just',
#   'for',
#   'kicks',
#   'and',
#   'yes',
#   'it',
#   'does',
#   'suck',
#   'the',
#   'tone',
#   'right',
#   'out',
#   'of',
#   'the',
#   'signal',
#   'as',
#   'far',
#   'as',
#   'a',
#   'cv',
#   'controler',
#   'it',
#   'sucks',
#   'at',
#   'that',
#   'too',
#   'why',
#   'it',
#   'squeaks',
#   'as',
#   'you',
#   'move',
#   'it',
#   'after',
#   '5',
#   'minutes',
#   'use',
#   'right',
#   'out',
#   'of',
#   'the',
#   'box',
#   'behringer',
#   'is',
#   'a',
#   'joke',
#   'and',
#   'gives',
#   'german',
#   'engineering',
#   'a',
#   'bad',
#   'name',
#   'although',
#   'only',
#   'conceived',
#   'in',
#   'germanyits',
#   'a',
#   'direct',
#   'copy',
#   'of',
#   'the',
#   'yamaha',
#   'fc9',
#   'and',
#   'so',
#   'i',
#   'am',
#   'about',
#   'to',
#   'purchase',
#   'one',
#   'of',
#   'those',
#   'and',
#   'see',
#   'how',
#   'it',
#   'compares',
#   'im',
#   'betting',
#   'the',
#   'extra',
#   '45',
#   'dollars',
#   'will',
#   'be',
#   'well',
#   'worth',
#   'italso',
#   'you',
#   'may',
#   'say',
#   'who',
#   'cares',
#   'if',
#   'it',
#   'squeaks',
#   'a',
#   'little',
#   'well',
#   'i',
#   'do',
#   'when',
#   'i',
#   'am',
#   'controlling',
#   'volume',
#   'swells',
#   'or',
#   'a',
#   'wah',
#   'effect',
#   'at',
#   'low',
#   'volume',
#   'in',
#   'the',
#   'studiogood',
#   'luck',
#   'if',
#   'you',
#   'buy',
#   'it'],
#  ['pretty',
#   'disappointed',
#   'in',
#   'the',
#   'color',
#   'as',
#   'the',
#   'review',
#   'title',
#   'indicates',
#   'what',
#   'i',
#   'received',
#   'is',
#   'more',
#   'of',
#   'a',
#   'black',
#   'chrome',
#   'or',
#   'dingy',
#   'stainless',
#   'color',
#   'these',
#   'are',
#   'simply',
#   'not',
#   'going',
#   'to',
#   'work',
#   'with',
#   'the',
#   'mots',
#   'pickguard',
#   'i',
#   'purchased',
#   'them',
#   'for',
#   'perhaps',
#   'they',
#   'would',
#   'blend',
#   'in',
#   'better',
#   'on',
#   'a',
#   'black',
#   'black',
#   'pearl',
#   'or',
#   'tort',
#   'pickguardi',
#   'ordered',
#   'another',
#   'package',
#   'from',
#   'another',
#   'vendor',
#   'and',
#   'got',
#   'the',
#   'same',
#   'result',
#   'perhaps',
#   'it',
#   'is',
#   'a',
#   'large',
#   'factory',
#   'shipment',
#   'that',
#   'is',
#   'bad',
#   'some',
#   'are',
#   'very',
#   'dull',
#   'looking',
#   'very',
#   'disappointing',
#   'really'],
#  ['i',
#   'cant',
#   'believe',
#   'these',
#   'were',
#   'actually',
#   'sent',
#   'to',
#   'me',
#   'the',
#   'heads',
#   'are',
#   'smaller',
#   'than',
#   'normal',
#   'pickguard',
#   'screws',
#   'and',
#   'the',
#   'metal',
#   'is',
#   'blackened',
#   'they',
#   'come',
#   'from',
#   'taiwan',
#   'but',
#   'look',
#   'like',
#   'they',
#   'were',
#   'subcontracted',
#   'to',
#   'china',
#   'i',
#   'am',
#   'sending',
#   'them',
#   'back',
#   'there',
#   'is',
#   'no',
#   'way',
#   'i',
#   'would',
#   'use',
#   'these',
#   'any',
#   'screw',
#   'you',
#   'get',
#   'from',
#   'home',
#   'depot',
#   'would',
#   'work',
#   'better',
#   'and',
#   'look',
#   'more',
#   'attractive',
#   'i',
#   'am',
#   'seeing',
#   'nothing',
#   'but',
#   'product',
#   'after',
#   'product',
#   'like',
#   'this',
#   'coming',
#   'from',
#   'fender',
#   'and',
#   'it',
#   'is',
#   'a',
#   'clear',
#   'sign',
#   'they',
#   'are',
#   'simply',
#   'trying',
#   'to',
#   'maximize',
#   'profits',
#   'at',
#   'any',
#   'cost'],
#  ['this',
#   'pickguard',
#   'was',
#   'used',
#   'it',
#   'not',
#   'only',
#   'was',
#   'missing',
#   'the',
#   'protective',
#   'plastic',
#   'but',
#   'it',
#   'actually',
#   'was',
#   'scratched',
#   'from',
#   'being',
#   'on',
#   'a',
#   'guitar',
#   'before'],
#  ['bought',
#   'this',
#   'a',
#   'while',
#   'back',
#   'just',
#   'got',
#   'around',
#   'to',
#   'installing',
#   'it',
#   'on',
#   'my',
#   'mexi',
#   'strat',
#   'doesnt',
#   'fit',
#   'perfect',
#   'kinda',
#   'bummed',
#   'but',
#   'oh',
#   'well'],
#  ['need',
#   '2',
#   'volume',
#   'knobs',
#   'and',
#   '1',
#   'tone',
#   'so',
#   'for',
#   'the',
#   'price',
#   'and',
#   'in',
#   'the',
#   'past',
#   'i',
#   'have',
#   'always',
#   'purchased',
#   '2',
#   'packs',
#   'together',
#   'with',
#   'no',
#   'issues',
#   'however',
#   'recently',
#   'i',
#   'needed',
#   'and',
#   'ordered',
#   'some',
#   'and',
#   'i',
#   'found',
#   'out',
#   'of',
#   '4',
#   'sets',
#   'no',
#   'consistency',
#   'in',
#   'quality',
#   'example',
#   'the',
#   'lettering',
#   'is',
#   'thinner',
#   'on',
#   'some',
#   'than',
#   'others',
#   'within',
#   'the',
#   'same',
#   'set',
#   'and',
#   'between',
#   'sets',
#   'of',
#   'the',
#   'same',
#   'item',
#   'also',
#   'some',
#   'had',
#   'bright',
#   'white',
#   'lettering',
#   'and',
#   'others',
#   'did',
#   'not',
#   'but',
#   'where',
#   'not',
#   'vintage',
#   'lettering',
#   'either',
#   'guess',
#   'these',
#   'are',
#   'too',
#   'cheap',
#   'for',
#   'fender',
#   'to',
#   'have',
#   'qc',
#   'onwill',
#   'try',
#   'other',
#   'brands',
#   'next',
#   'time'],
#  ['unless',
#   'you',
#   'guys',
#   'are',
#   'receiving',
#   'something',
#   'i',
#   'am',
#   'not',
#   'how',
#   'can',
#   'you',
#   'give',
#   'this',
#   'anything',
#   'more',
#   'than',
#   'one',
#   'star',
#   'my',
#   'backplate',
#   'is',
#   'so',
#   'thin',
#   'and',
#   'cut',
#   'so',
#   'close',
#   'to',
#   'the',
#   'screws',
#   'that',
#   'you',
#   'can',
#   'actually',
#   'see',
#   'were',
#   'the',
#   'route',
#   'begins',
#   'on',
#   'the',
#   'back',
#   'of',
#   'my',
#   'fender',
#   'stratocaster',
#   'this',
#   'is',
#   'inexcusable',
#   'all',
#   'the',
#   'other',
#   'fender',
#   'backplates',
#   'i',
#   'have',
#   'have',
#   'enough',
#   'lip',
#   'to',
#   'cover',
#   'the',
#   'route',
#   'but',
#   'not',
#   'this',
#   'mint',
#   'green',
#   'one',
#   'i',
#   'simply',
#   'cannot',
#   'understand',
#   'what',
#   'fender',
#   'is',
#   'thinking',
#   'i',
#   'am',
#   'seeing',
#   'nothing',
#   'but',
#   'product',
#   'after',
#   'product',
#   'like',
#   'this',
#   'coming',
#   'from',
#   'fender',
#   'and',
#   'it',
#   'is',
#   'a',
#   'clear',
#   'sign',
#   'they',
#   'are',
#   'simply',
#   'trying',
#   'to',
#   'maximize',
#   'profits',
#   'at',
#   'any',
#   'cost'],
#  ['these',
#   'strings',
#   'are',
#   'great',
#   'if',
#   'you',
#   'need',
#   'practice',
#   'changing',
#   'your',
#   'strings',
#   'these',
#   'strings',
#   'last',
#   '2',
#   'days',
#   'and',
#   'then',
#   'they',
#   'are',
#   'dull',
#   'and',
#   'lifeless',
#   'and',
#   'need',
#   'to',
#   'be',
#   'changed',
#   'the',
#   'high',
#   'e',
#   'and',
#   'the',
#   'b',
#   'string',
#   'tend',
#   'to',
#   'break',
#   'before',
#   'they',
#   'even',
#   'get',
#   'tuned',
#   'to',
#   'pitch',
#   'ernie',
#   'ball',
#   'strings',
#   'are',
#   'garbage',
#   'the',
#   'only',
#   'time',
#   'i',
#   'will',
#   'buy',
#   'these',
#   'is',
#   'if',
#   'its',
#   'the',
#   'only',
#   'thing',
#   'available',
#   'most',
#   'people',
#   'like',
#   'these',
#   'because',
#   'they',
#   'are',
#   'endorsed',
#   'by',
#   'so',
#   'many',
#   'musicians',
#   'that',
#   'are',
#   'paid',
#   'to',
#   'say',
#   'that',
#   'they',
#   'like',
#   'this',
#   'garbage',
#   'and',
#   'even',
#   'if',
#   'they',
#   'do',
#   'like',
#   'them',
#   'they',
#   'are',
#   'not',
#   'your',
#   'average',
#   'players',
#   'that',
#   'need',
#   'more',
#   'than',
#   '2',
#   'days',
#   'out',
#   'of',
#   'a',
#   'set',
#   'of',
#   'strings',
#   'touring',
#   'musicians',
#   'have',
#   'the',
#   'guitar',
#   'tech',
#   'change',
#   'the',
#   'strings',
#   'after',
#   'they',
#   'play',
#   'their',
#   'set',
#   'and',
#   'they',
#   'get',
#   'an',
#   'unlimited',
#   'amount',
#   'of',
#   'these',
#   'crap',
#   'strings',
#   'so',
#   'their',
#   'guitars',
#   'always',
#   'sound',
#   'fresh',
#   'you',
#   'can',
#   'spend',
#   '4',
#   'for',
#   'a',
#   'set',
#   'of',
#   'ernie',
#   'ball',
#   'or',
#   'daddario',
#   'every',
#   '2',
#   'days',
#   'or',
#   'you',
#   'can',
#   'spend',
#   '7',
#   'for',
#   'a',
#   'set',
#   'of',
#   'dr',
#   'strings',
#   'and',
#   'change',
#   'them',
#   'once',
#   'a',
#   'month',
#   'or',
#   'you',
#   'can',
#   'spend',
#   '10',
#   'for',
#   'a',
#   'set',
#   'of',
#   'elixir',
#   'polywebs',
#   'and',
#   'change',
#   'your',
#   'strings',
#   'once',
#   'every',
#   '3',
#   'months',
#   'it',
#   'doesnt',
#   'make',
#   'sense',
#   'to',
#   'use',
#   'these',
#   'crappy',
#   'ernies',
#   'unless',
#   'you',
#   'are',
#   'sponsored',
#   'by',
#   'eb',
#   'and',
#   'have',
#   'an',
#   'endless',
#   'supply',
#   'and',
#   'a',
#   'tech',
#   'to',
#   'change',
#   'them',
#   'for',
#   'you',
#   'like',
#   'the',
#   'rockstars'],
#  ['it',
#   'is',
#   'ok',
#   'but',
#   'it',
#   'does',
#   'not',
#   'compare',
#   'to',
#   'the',
#   'ergo',
#   'holderwhich',
#   'you',
#   'may',
#   'find',
#   'heredunlop',
#   'ergo',
#   'pickholderthe',
#   'main',
#   'problem',
#   'with',
#   'this',
#   'pickholder',
#   'is',
#   'that',
#   'it',
#   'is',
#   'very',
#   'difficult',
#   'to',
#   'get',
#   'your',
#   'pick',
#   'out',
#   'and',
#   'it',
#   'is',
#   'extremely',
#   'fragile'],
#  ['i',
#   'bought',
#   'one',
#   'of',
#   'each',
#   'soft',
#   'medium',
#   'and',
#   'hard',
#   'wedgie',
#   'rubber',
#   'picks',
#   'and',
#   'even',
#   'though',
#   'the',
#   'colours',
#   'were',
#   'right',
#   'the',
#   'hard',
#   'is',
#   'as',
#   'soft',
#   'as',
#   'the',
#   'soft',
#   'they',
#   'felt',
#   'exactly',
#   'the',
#   'same',
#   'in',
#   'fact',
#   'the',
#   'medium',
#   'was',
#   'the',
#   'hardest',
#   'out',
#   'of',
#   'the',
#   'bunchpackaging',
#   'error',
#   'i',
#   'have',
#   'no',
#   'idea',
#   'the',
#   'fact',
#   'that',
#   'each',
#   'stiffness',
#   'only',
#   'comes',
#   'in',
#   'one',
#   'colour',
#   'and',
#   'the',
#   'colours',
#   'were',
#   'right',
#   'lead',
#   'me',
#   'to',
#   'think',
#   'something',
#   'is',
#   'wrong',
#   'with',
#   'the',
#   'manufacturing',
#   'so',
#   'check',
#   'with',
#   'what',
#   'you',
#   'getsound',
#   'wise',
#   'the',
#   'rubber',
#   'really',
#   'removes',
#   'the',
#   'treble',
#   'on',
#   'my',
#   'acoustic',
#   'guitar',
#   'making',
#   'it',
#   'sound',
#   'really',
#   'dull',
#   'and',
#   'mutedthere',
#   'is',
#   'a',
#   'lot',
#   'more',
#   'friction',
#   'from',
#   'the',
#   'rubber',
#   'on',
#   'the',
#   'strings',
#   'that',
#   'i',
#   'do',
#   'not',
#   'think',
#   'it',
#   'is',
#   'idea',
#   'for',
#   'strummingthe',
#   'only',
#   'reason',
#   'i',
#   'can',
#   'think',
#   'of',
#   'using',
#   'is',
#   'if',
#   'you',
#   'want',
#   'to',
#   'reduce',
#   'the',
#   'noise',
#   'but',
#   'frankly',
#   'you',
#   'would',
#   'have',
#   'much',
#   'more',
#   'control',
#   'if',
#   'you',
# ...
#   'amps',
#   'and',
#   'i',
#   'get',
#   'the',
#   'same',
#   'results',
#   'regardless',
#   'of',
#   'the',
#   'amp',
#   'or',
#   'the',
#   'instrument'],
#  ['update',
#   'received',
#   '6',
#   'of',
#   'these',
#   '5',
#   'are',
#   'ok',
#   'but',
#   'one',
#   'has',
#   'a',
#   'bad',
#   'weld',
#   'joint',
#   'at',
#   'the',
#   'top',
#   'retainer',
#   'it',
#   'was',
#   'held',
#   'by',
#   'only',
#   'one',
#   'small',
#   'tac',
#   'weldi',
#   'got',
#   'what',
#   'i',
#   'paid',
#   'for',
#   'cheap',
#   'price',
#   'and',
#   'cheap',
#   'product',
#   'no',
#   'excuse',
#   'to',
#   'make',
#   'this',
#   'kind',
#   'of',
#   'low',
#   'quality',
#   'guitar',
#   'stand',
#   'putting',
#   'a',
#   '500',
#   'guitar',
#   'on',
#   'this',
#   'is',
#   'asking',
#   'for',
#   'guitar',
#   'damage',
#   'when',
#   'the',
#   'stand',
#   'falls',
#   'apart',
#   'not',
#   'worth',
#   'the',
#   'time',
#   'to',
#   'send',
#   'it',
#   'back',
#   'to',
#   'amazon',
#   'one',
#   'star',
#   'only',
#   'for',
#   'this',
#   'product',
#   'good',
#   'chance',
#   'that',
#   'you',
#   'will',
#   'get',
#   'a',
#   'crappy',
#   'one',
#   'if',
#   'you',
#   'order',
#   'this',
#   'less',
#   'than',
#   'one',
#   'star',
#   'for',
#   'this',
#   'piece',
#   'of'],
#  ['this',
#   'is',
#   'a',
#   'cheap',
#   'stand',
#   'and',
#   'i',
#   'was',
#   'not',
#   'surprised',
#   'to',
#   'see',
#   'it',
#   'had',
#   'broke',
#   'less',
#   'than',
#   '2',
#   'day',
#   'after',
#   'it',
#   'had',
#   'arrived',
#   'the',
#   'top',
#   'cup',
#   'that',
#   'holds',
#   'the',
#   'neck',
#   'of',
#   'your',
#   'guitar',
#   'was',
#   'welded',
#   'in',
#   'one',
#   'spot',
#   'only',
#   'and',
#   'it',
#   'was',
#   'very',
#   'thin',
#   'metal',
#   'where',
#   'the',
#   'weld',
#   'was',
#   'made',
#   'i',
#   'do',
#   'not',
#   'recommend',
#   'this',
#   'product'],
#  ['if',
#   'you',
#   'only',
#   'want',
#   'to',
#   'use',
#   'this',
#   'thing',
#   'as',
#   'a',
#   'detune',
#   'effect',
#   'to',
#   'add',
#   'a',
#   'static',
#   'nonoscillating',
#   'chorus',
#   'like',
#   'effect',
#   'its',
#   'fine',
#   'for',
#   'that',
#   'as',
#   'an',
#   'actual',
#   'pitch',
#   'shifter',
#   'though',
#   'this',
#   'thing',
#   'is',
#   'awful',
#   'all',
#   'the',
#   'pitch',
#   'shift',
#   'settings',
#   'sound',
#   'like',
#   'theyre',
#   '30',
#   'cents',
#   'sharp',
#   'this',
#   'is',
#   'especially',
#   'awful',
#   'sounding',
#   'when',
#   'used',
#   'as',
#   'an',
#   'octave',
#   'effect',
#   'i',
#   'suppose',
#   'i',
#   'could',
#   'have',
#   'opened',
#   'it',
#   'up',
#   'to',
#   'see',
#   'if',
#   'there',
#   'was',
#   'an',
#   'adjustment',
#   'pot',
#   'inside',
#   'but',
#   'i',
#   'did',
#   'not',
#   'want',
#   'to',
#   'void',
#   'the',
#   'warranty',
#   'so',
#   'i',
#   'just',
#   'returned',
#   'it',
#   'its',
#   'hard',
#   'to',
#   'believe',
#   'that',
#   'nobody',
#   'at',
#   'the',
#   'company',
#   'could',
#   'hear',
#   'how',
#   'badly',
#   'out',
#   'of',
#   'tune',
#   'this',
#   'pedal',
#   'is',
#   'ive',
#   'read',
#   'the',
#   'same',
#   'complaint',
#   'about',
#   'their',
#   'pure',
#   'octave',
#   'pedal',
#   'also',
#   'this',
#   'is',
#   'really',
#   'too',
#   'bad',
#   'because',
#   'all',
#   'the',
#   'other',
#   'pedals',
#   'for',
#   'mooer',
#   'seem',
#   'to',
#   'be',
#   'quite',
#   'good',
#   'i',
#   'own',
#   'their',
#   'reecho',
#   'delay',
#   'pedal',
#   'and',
#   'quite',
#   'like',
#   'it',
#   'and',
#   'im',
#   'also',
#   'tempted',
#   'to',
#   'get',
#   'their',
#   'green',
#   'mile',
#   'pedalif',
#   'youre',
#   'not',
#   'that',
#   'sensitive',
#   'to',
#   'pitch',
#   'inaccuracies',
#   'this',
#   'pedal',
#   'maybe',
#   'fine',
#   'for',
#   'you',
#   'but',
#   'i',
#   'doubt',
#   'that',
#   'many',
#   'will',
#   'find',
#   'this',
#   'pedal',
#   'to',
#   'be',
#   'satisfactoryone',
#   'minor',
#   'quibble',
#   'about',
#   'the',
#   'rubber',
#   'padding',
#   'used',
#   'at',
#   'the',
#   'bottom',
#   'of',
#   'these',
#   'pedals',
#   'it',
#   'does',
#   'not',
#   'stick',
#   'to',
#   'the',
#   'adhesive',
#   'on',
#   'any',
#   'of',
#   'the',
#   'velcro',
#   'strips',
#   'ive',
#   'tried',
#   'to',
#   'use'],
#  ['i',
#   'got',
#   'one',
#   'of',
#   'these',
#   'from',
#   'another',
#   'source',
#   'but',
#   'have',
#   'returned',
#   'it',
#   'for',
#   'exchange',
#   'because',
#   'of',
#   'the',
#   'following',
#   'issue',
#   'when',
#   'i',
#   'record',
#   'a',
#   'track',
#   'either',
#   'with',
#   'the',
#   'audio',
#   'recorder',
#   'or',
#   'guitar',
#   'amp',
#   'screens',
#   'in',
#   'garageband',
#   'on',
#   'my',
#   'ipad',
#   '3',
#   'ios7',
#   'the',
#   'recording',
#   'is',
#   'great',
#   'but',
#   'once',
#   'i',
#   'toggle',
#   'over',
#   'to',
#   'the',
#   'multitrack',
#   'view',
#   'and',
#   'attempt',
#   'to',
#   'play',
#   'the',
#   'recording',
#   'just',
#   'made',
#   'there',
#   'is',
#   'godawful',
#   'distortion',
#   'and',
#   'the',
#   'audio',
#   'is',
#   'completely',
#   'unlistenable',
#   'heres',
#   'the',
#   'other',
#   'part',
#   'of',
#   'this',
#   'i',
#   'can',
#   'use',
#   'apogee',
#   'jam',
#   'guitar',
#   'interface',
#   'and',
#   'irig',
#   'pre',
#   'microphone',
#   'interface',
#   'and',
#   'garageband',
#   'behaves',
#   'as',
#   'it',
#   'should',
#   'and',
#   'i',
#   'can',
#   'play',
#   'the',
#   'multitrack',
#   'view',
#   'with',
#   'no',
#   'problems',
#   'whatsoever',
#   'the',
#   'focusrite',
#   'support',
#   'folks',
#   'suggested',
#   'i',
#   'do',
#   'a',
#   'backup',
#   'of',
#   'my',
#   'ipad',
#   'contents',
#   'and',
#   'then',
#   'do',
#   'a',
#   'software',
#   'restore',
#   'but',
#   'i',
#   'opted',
#   'to',
#   'return',
#   'the',
#   'unit',
#   'instead',
#   'since',
#   'the',
#   'apogee',
#   'and',
#   'irig',
#   'both',
#   'work',
#   'perfectly',
#   'with',
#   'garageband',
#   'so',
#   'i',
#   'dont',
#   'know',
#   'if',
#   'the',
#   'unit',
#   'is',
#   'having',
#   'a',
#   'problem',
#   'with',
#   'ios7',
#   'or',
#   'i',
#   'just',
#   'happened',
#   'to',
#   'get',
#   'a',
#   'lemon',
#   'but',
#   'ill',
#   'find',
#   'out',
#   'when',
#   'the',
#   'new',
#   'one',
#   'comes',
#   'next',
#   'week',
#   'if',
#   'it',
#   'works',
#   'correctly',
#   'ill',
#   'update',
#   'this',
#   'review',
#   'after',
#   'doing',
#   'a',
#   'few',
#   'recordings',
#   'but',
#   'i',
#   'would',
#   'say',
#   'if',
#   'youve',
#   'just',
#   'updated',
#   'to',
#   'ios7',
#   'or',
#   'are',
#   'thinking',
#   'about',
#   'it',
#   'and',
#   'you',
#   'want',
#   'to',
#   'get',
#   'this',
#   'unit',
#   'you',
#   'might',
#   'want',
#   'to',
#   'hold',
#   'off',
#   'on',
#   'that',
#   'upgrade',
#   'update',
#   'got',
#   'a',
#   'replacement',
#   'unit',
#   'and',
#   'even',
#   'did',
#   'a',
#   'restore',
#   'on',
#   'my',
#   'ipad',
#   'as',
#   'suggested',
#   'by',
#   'a',
#   'focusrite',
#   'support',
#   'tech',
#   'and',
#   'still',
#   'have',
#   'the',
#   'problem',
#   'i',
#   'discussed',
#   'above',
#   'so',
#   'this',
#   'product',
#   'simply',
#   'has',
#   'turned',
#   'out',
#   'to',
#   'be',
#   'a',
#   'dud',
#   'for',
#   'me',
#   'if',
#   'anyone',
#   'else',
#   'has',
#   'a',
#   'similar',
#   'issue',
#   'with',
#   'this',
#   'and',
#   'find',
#   'a',
#   'resolution',
#   'please',
#   'let',
#   'me',
#   'know'],
#  ['i',
#   'have',
#   'been',
#   'using',
#   'this',
#   'gig',
#   'bag',
#   'for',
#   'the',
#   'past',
#   'few',
#   'months',
#   'if',
#   'i',
#   'do',
#   'the',
#   'math',
#   'i',
#   'probably',
#   'didnt',
#   'use',
#   'it',
#   'more',
#   'than',
#   '10',
#   'times',
#   'basically',
#   'from',
#   'home',
#   'to',
#   'the',
#   'subway',
#   'from',
#   'the',
#   'subway',
#   'to',
#   'the',
#   'studio',
#   'and',
#   'back',
#   'so',
#   'maybe',
#   '20',
#   'minutes',
#   'walk',
#   'each',
#   'time',
#   'so',
#   'i',
#   'used',
#   'it',
#   'for',
#   'about',
#   '3',
#   'hrs',
#   'and',
#   '20',
#   'minutes',
#   'mostly',
#   'carrying',
#   'it',
#   'on',
#   'my',
#   'shoulders',
#   'sometimes',
#   'by',
#   'one',
#   'of',
#   'the',
#   'two',
#   'handlesthen',
#   'the',
#   'side',
#   'handle',
#   'started',
#   'coming',
#   'apart',
#   'the',
#   'seam',
#   'ripped',
#   'on',
#   'the',
#   'side',
#   'and',
#   'the',
#   'handle',
#   'will',
#   'eventually',
#   'fall',
#   'off',
#   'if',
#   'used',
#   'it',
#   'will',
#   'be',
#   'ok',
#   'for',
#   'a',
#   'while',
#   'until',
#   'the',
#   'shoulder',
#   'straps',
#   'start',
#   'breaking',
#   'which',
#   'i',
#   'kind',
#   'of',
#   'expect',
#   'at',
#   'this',
#   'point',
#   'meanwhile',
#   'im',
#   'going',
#   'to',
#   'buy',
#   'another',
#   'sturdier',
#   'gig',
#   'bagsave',
#   'your',
#   'money',
#   'and',
#   'get',
#   'something',
#   'better',
#   'than',
#   'this'],
#  ['this',
#   'thing',
#   'is',
#   'crap',
#   'right',
#   'out',
#   'of',
#   'the',
#   'box',
#   'it',
#   'had',
#   'holes',
#   'in',
#   'the',
#   'stitching',
#   'and',
#   'all',
#   'the',
#   'pockets',
#   'were',
#   'sown',
#   'on',
#   'crooked',
#   'what',
#   'can',
#   'you',
#   'expect',
#   'for',
#   '20',
#   'tho',
#   'this',
#   'was',
#   'a',
#   'temporary',
#   'solution',
#   'i',
#   'dont',
#   'recommend',
#   'this',
#   'for',
#   'long',
#   'term',
#   'use',
#   'it',
#   'will',
#   'probably',
#   'fall',
#   'apart'],
#  ['manufacturers',
#   'website',
#   'claimed',
#   'that',
#   'this',
#   'case',
#   'would',
#   'fit',
#   'a',
#   'les',
#   'paul',
#   'style',
#   'guitar',
#   'i',
#   'have',
#   'an',
#   'esp',
#   'eclipse',
#   'not',
#   'even',
#   'close',
#   'chromacast',
#   'products',
#   'are',
#   'great',
#   'they',
#   'need',
#   'to',
#   'fix',
#   'the',
#   'info',
#   'on',
#   'their',
#   'web',
#   'page',
#   'im',
#   'not',
#   'a',
#   'fan',
#   'of',
#   'shaped',
#   'les',
#   'paul',
#   'cases',
#   'too',
#   'bad'],
#  ['returned',
#   'this',
#   'item',
#   'because',
#   'the',
#   'zipper',
#   'was',
#   'already',
#   'broken',
#   'when',
#   'i',
#   'received',
#   'it',
#   'not',
#   'durable',
#   'spend',
#   'a',
#   'few',
#   'more',
#   'dollars',
#   'it',
#   'is',
#   'worth',
#   'it'],
#  ['a',
#   'great',
#   'little',
#   'package',
#   'for',
#   'the',
#   'price',
#   'but',
#   'unfortunately',
#   'the',
#   'zipper',
#   'failed',
#   'the',
#   'first',
#   'time',
#   'i',
#   'tried',
#   'zipping',
#   'it',
#   'up',
#   'i',
#   'have',
#   'a',
#   'standard',
#   'size',
#   'acoustic',
#   'guitar',
#   'but',
#   'be',
#   'aware',
#   'the',
#   'fit',
#   'was',
#   'snug',
#   'but',
#   'not',
#   'tight'],
#  ['straight',
#   'out',
#   'of',
#   'the',
#   'box',
#   'this',
#   'product',
#   'reeked',
#   'cheap',
#   'no',
#   'directions',
#   'inside',
#   'or',
#   'on',
#   'the',
#   'box',
#   'i',
#   'messed',
#   'with',
#   'it',
#   'for',
#   'about',
#   '5',
#   'minutes',
#   'i',
#   'would',
#   'not',
#   'trust',
#   'it',
#   'with',
#   'a',
#   'heavy',
#   'or',
#   'expensive',
#   'mic',
#   'i',
#   'read',
#   'the',
#   'description',
#   'but',
#   'it',
#   'did',
#   'not',
#   'say',
#   'cheap',
#   'live',
#   'and',
#   'learn'],
#  ['amazon',
#   'and',
#   'tc',
#   'electronics',
#   'will',
#   'not',
#   'tell',
#   'you',
#   'that',
#   'you',
#   'need',
#   'a',
#   '9v',
#   'power',
#   'supply',
#   'i',
#   'didnt',
#   'see',
#   'any',
#   'warning',
#   'or',
#   'advise',
#   'in',
#   'the',
#   'point',
#   'of',
#   'purchase',
#   'nor',
#   'in',
#   'the',
#   'package',
#   'this',
#   'is',
#   'an',
#   'unfair',
#   'practice',
#   'from',
#   'amazon',
#   'and',
#   'tc',
#   'electronics'],
#  ['let',
#   'me',
#   'start',
#   'by',
#   'saying',
#   'that',
#   'this',
#   'is',
#   'a',
#   'really',
#   'cool',
#   'pedal',
#   'and',
#   'tons',
#   'of',
#   'fun',
#   'i',
#   'can',
#   'see',
#   'how',
#   'this',
#   'could',
#   'make',
#   'you',
#   'a',
#   'better',
#   'player',
#   'and',
#   'i',
#   'think',
#   'it',
#   'could',
#   'also',
#   'be',
#   'used',
#   'livebut',
#   'and',
#   'this',
#   'is',
#   'a',
#   'big',
#   'but',
#   'this',
#   'is',
#   'my',
#   'first',
#   'one',
#   'star',
#   'review',
#   'evermy',
#   'first',
#   'lessthan5starreview',
#   'eversame',
#   'as',
#   'others',
#   'switch',
#   'failed',
#   'less',
#   'than',
#   'ten',
#   'days',
#   'of',
#   'owning',
#   'it',
#   'used',
#   'less',
#   'than',
#   'ten',
#   'times',
#   'total',
#   'light',
#   'use',
#   'at',
#   'home',
#   'i',
#   'wasnt',
#   'even',
#   'wearing',
#   'shoes',
#   'by',
#   'the',
#   'way',
#   'a',
#   'giggingrecording',
#   'musician',
#   'for',
#   'over',
#   '25',
#   'years',
#   'so',
#   'i',
#   'am',
#   'not',
#   'a',
#   'youngster',
#   'that',
#   'misuses',
#   'my',
#   'stuff',
#   'bummer',
#   'too',
#   'great',
#   'ideapoorly',
#   'executedi',
#   'will',
#   'not',
#   'buy',
#   'anther',
#   'one',
#   'i',
#   'will',
#   'not',
#   'recommend',
#   'to',
#   'other',
#   'musicians'],
#  ['i',
#   'purchased',
#   'this',
#   'pedal',
#   'at',
#   'a',
#   'local',
#   'music',
#   'store',
#   'for',
#   'practice',
#   'and',
#   'possibly',
#   'doing',
#   'some',
#   'loops',
#   'at',
#   'open',
#   'mics',
#   'with',
#   'my',
#   'roland',
#   'gr55',
#   'which',
#   'has',
#   'a',
#   'flawless',
#   'basic',
#   'looper',
#   'built',
#   'in',
#   'but',
#   'only',
#   '20',
#   'seconds',
#   'record',
#   'and',
#   'no',
#   'undo',
#   'i',
#   'had',
#   'hoped',
#   'that',
#   'it',
#   'would',
#   'at',
#   'least',
#   'last',
#   'one',
#   'hour',
#   'on',
#   'with',
#   'a',
#   'battery',
#   'so',
#   'that',
#   'i',
#   'wouldnt',
#   'need',
#   'to',
#   'carry',
#   'a',
#   'power',
#   'adapter',
#   'alongthe',
#   'factory',
#   'battery',
#   'lasted',
#   'about',
#   '1',
#   'hour',
#   'the',
#   'second',
#   'brand',
#   'new',
#   'fresh',
#   'duracell',
#   'battery',
#   'lasted',
#   'about',
#   '20',
#   'minutes',
#   'i',
#   'started',
#   'recording',
#   'a',
#   'loop',
#   'with',
#   'another',
#   '3rd',
#   'fresh',
#   'battery',
#   'tested',
#   '910',
#   'v',
#   'with',
#   'a',
#   'multimeter',
#   'and',
#   'the',
#   'unit',
#   'started',
#   'behaving',
#   'erratically',
#   'after',
#   'a',
#   'few',
#   'seconds',
#   'of',
#   'recording',
#   'suggesting',
#   'that',
#   'it',
#   'was',
#   'faulty',
#   'the',
#   'lights',
#   'started',
#   'coming',
#   'on',
#   'and',
#   'off',
#   'randomly',
#   'recordundoall',
#   'three',
#   'together',
#   'then',
#   'off',
#   'then',
#   'undo',
#   'on',
#   'then',
#   'all',
#   'three',
#   'on',
#   'etc',
#   'etcthe',
#   'first',
#   'time',
#   'i',
#   'used',
#   'the',
#   'jamman',
#   'xt',
#   'with',
#   'the',
#   'factory',
#   'battery',
#   'it',
#   'seemed',
#   'to',
#   'be',
#   'working',
#   'ok',
#   'and',
#   'all',
#   'i',
#   'can',
#   'say',
#   'is',
#   'that',
#   'as',
#   'a',
#   'basic',
#   'looper',
#   'it',
#   'suckedi',
#   'am',
#   'used',
#   'to',
#   'synching',
#   'loops',
#   'with',
#   'other',
#   'loopers',
#   'and',
#   'timing',
#   'is',
#   'everything',
#   'so',
#   'i',
#   'know',
#   'it',
#   'was',
#   'not',
#   'my',
#   'poor',
#   'technique',
#   'the',
#   'main',
#   'problem',
#   'was',
#   'that',
#   'it',
#   'didnt',
#   'matter',
#   'how',
#   'hard',
#   'i',
#   'tried',
#   'even',
#   'if',
#   'i',
#   'did',
#   'a',
#   'manual',
#   'fade',
#   'out',
#   'there',
#   'was',
#   'always',
#   'a',
#   'gap',
#   'of',
#   'about',
#   '2',
#   'seconds',
#   'between',
#   'the',
#   'end',
#   'of',
#   'the',
#   'loop',
#   'and',
#   'the',
#   'start',
#   'this',
#   'makes',
#   'the',
#   'unit',
#   'uselessalso',
#   'it',
#   'is',
#   'poorly',
#   'conceived',
#   'in',
#   'that',
#   'to',
#   'replace',
#   'the',
#   'battery',
#   'you',
#   'have',
#   'to',
#   'take',
#   'out',
#   '2',
#   'screws',
#   'exposing',
#   'the',
#   'delicate',
#   'printed',
#   'circuit',
#   'boardthe',
#   'potential',
#   'for',
#   'damage',
#   'here',
#   'is',
#   'very',
#   'high',
#   'also',
#   'replacing',
#   'the',
#   'screws',
#   'needs',
#   'to',
#   'be',
#   'done',
#   'very',
#   'carefully',
#   'to',
#   'avoid',
#   'cross',
#   'threading',
#   'the',
#   'screws',
#   'and',
#   'messing',
#   'up',
#   'the',
#   'receiver',
#   'nuts',
#   'which',
#   'are',
#   'mounted',
#   'directly',
#   'onto',
#   'the',
#   'circuit',
#   'board',
#   'to',
#   'save',
#   'a',
#   'few',
#   'dollars',
#   'digitech',
#   'did',
#   'not',
#   'have',
#   'the',
#   'foresight',
#   'to',
#   'manufacture',
#   'the',
#   'unit',
#   'with',
#   'a',
#   'battery',
#   'box',
#   'which',
#   'would',
#   'have',
#   'protected',
#   'the',
#   'electronics',
#   'and',
#   'possible',
#   'read',
#   'inevitable',
#   'damagei',
#   'have',
#   'owned',
#   'quite',
#   'a',
#   'few',
#   'digitech',
#   'products',
#   'over',
#   'the',
#   'years',
#   'and',
#   'generally',
#   'they',
#   'are',
#   'well',
#   'thought',
#   'out',
#   'and',
#   'well',
#   'constructed',
#   'but',
#   'they',
#   'have',
#   'really',
#   'dropped',
#   'the',
#   'ball',
#   'on',
#   'this',
#   'oneits',
#   'going',
#   'back',
#   'to',
#   'the',
#   'store',
#   'where',
#   'i',
#   'purchased',
#   'it'],
#  ['i',
#   'really',
#   'wanted',
#   'to',
#   'like',
#   'these',
#   'but',
#   'theyre',
#   'a',
#   'frickin',
#   'lintcatching',
#   'sticky',
#   'frickin',
#   'mess',
#   'they',
#   'went',
#   'from',
#   'my',
#   'wifes',
#   'snare',
#   'back',
#   'into',
#   'the',
#   'holder',
#   'in',
#   'a',
#   'new',
#   'york',
#   'minute',
#   'have',
#   'never',
#   'seen',
#   'the',
#   'light',
#   'of',
#   'day',
#   'and',
#   'may',
#   'have',
#   'been',
#   'thrown',
#   'in',
#   'the',
#   'garbage',
#   'save',
#   'your',
#   'money',
#   'we',
#   'use',
#   'a',
#   'heavy',
#   'stoneware',
#   'coaster',
#   'with',
#   'a',
#   'cork',
#   'back',
#   'to',
#   'quieten',
#   'her',
#   'snare',
#   'now']]

# %%
def df_tokenizer_neg(df_sent_tok):
  t=df_sent_tok

  full_vec = []
  for i in range(0, len(t)):
    vec = []
    for j in range(0, len(t[i])-1):
    
    # print('j', t[i][j])
      if t[i][j][0] in negation_list:
    
        tup = (t[i][j][0],t[i][j+1][0])
        vec.append(tup)
    full_vec.append(vec)
        #full_vec.append(vec)
        #for x in neg_BOW:
          #if tup in x:
            #print("FOUND")
  return full_vec

# %%
full_vec = df_tokenizer_neg(df1_sent_tok)

# %%
len(full_vec)
# Out:
# 217

# %%
common_neg

# %%
def vectorize_neg(full_vec):
  f_vec = []
  for j in full_vec:
    t_vec = []
    for i in common_neg:
      
      if i in j:
        t_vec.append(1)
      else:
        t_vec.append(0)

    #f_vec.append(t_vec)
    f_vec.append(hash(str(t_vec))%1000000)
  #full_vec
  return f_vec

# %%
x = vectorize_neg(full_vec)

# %%
len(x)
# Out:
# 217

# %%
def negation(df_org):
  df_rev_tok = tokenizer_(df_org)
  df_sent_tok = POS_tagger_neg(df_rev_tok)
  full_vec = df_tokenizer_neg(df_sent_tok)
  final = vectorize_neg(full_vec)

  return final

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-346-c6b849755c19> in <module>()
# ----> 1 len(final)
#
# NameError: name 'final' is not defined

# %%
NEG_df1 = negation(df_1)
print(len(NEG_df1))
# Out:
# 217

# %%
NEG_df2 = negation(df_2)
print(len(NEG_df2))
# Out:
# 250

# %%
NEG_df3 = negation(df_3)
NEG_df4 = negation(df_4)
NEG_df5 = negation(df_5)

# %%
total_NEG_col = []
total_NEG_col.append(NEG_df1)
total_NEG_col.append(NEG_df2)
total_NEG_col.append(NEG_df3)
total_NEG_col.append(NEG_df4)
total_NEG_col.append(NEG_df5)

total_NEG_col_FL= sum(total_NEG_col, [])

# %%
df_dataset['Neg_Token_Vector']=total_NEG_col_FL

# %%
df_dataset
# Out:
#                                                  Reviews  ...  Neg_Token_Vector
# 52     it hums crackles and i think im having problem...  ...            566754
# 89     im a procheapo and i hated this thing theyre n...  ...            712708
# 223    received it in time standard blister packaging...  ...            712708
# 224    these things are terrible one wouldnt fit in m...  ...            886937
# 408    this is a cheap piece of junk that does what i...  ...            712708
# ...                                                  ...  ...               ...
# 10251  true to phosphor bronze these strings have a m...  ...            745810
# 10252  ive used elixirs for about five years now this...  ...            712708
# 10254  i really like these strings  while they are no...  ...            972789
# 10256               great just as expected  thank to all  ...            712708
# 10257  ive been thinking about trying the nanoweb str...  ...            139402
#
# [10261 rows x 4 columns]

# %%
df_dataset.to_csv('music_dataset_w_neg.csv')

# %% [markdown]
# ## Creating Token Score
#
#
# ---

# %%
tokens1
# Out:
# ['is',
#  'not',
#  'was',
#  'have',
#  'i',
#  'are',
#  'just',
#  'be',
#  'so',
#  'very',
#  'when',
#  'get',
#  'really',
#  'had',
#  'has',
#  'good',
#  'even',
#  'too',
#  'other',
#  'got',
#  'back',
#  'only',
#  'have',
#  'buy',
#  'i',
#  'then',
#  'i',
#  'cheap',
#  'use',
#  'i',
#  'few',
#  'did',
#  'bought',
#  'well',
#  'were',
#  'more',
#  'am',
#  'work',
#  'also',
#  'now',
#  'does',
#  'same',
#  'used',
#  'great',
#  'do',
#  'bad',
#  'going',
#  'new',
#  'how',
#  'want',
#  'again',
#  'dont',
#  'been',
#  'never']

# %%
tokens2_plus[0][0]
# Out:
# ('is', 'VBZ')

# %% [markdown]
# ### How many instances of each token in each star class?

# %%
#added 1 to get rid of issue
def token_counter(target_tokens_arr, flag):
  if flag == 1:
    all_token_arrs = [tokens1_plus, tokens2_plus, tokens3_plus, tokens4_plus, tokens5_plus]
  else:
    all_token_arrs = [x1, x2, x3, x4, x5]

  #token = target_tokens_arr[0][0]
  tokens1_array = []
  

  for x in target_tokens_arr:
    temp_arr = []
    temp_arr.append(x[0])
    for token_arr in all_token_arrs:
      for j in token_arr: 
        flag = False
       
        if x[0] == j[0]:
          #print('x=',x)
          temp_arr.append(j[1]+1)
          flag = True
          break
     
      if flag == False:
        temp_arr.append(1)
    tokens1_array.append(temp_arr)

  return tokens1_array

# %%
token_counter_1 = token_counter(tokens1_plus,1)
token_counter_2 = token_counter(tokens2_plus,1
token_counter_3 = token_counter(tokens3_plus,1)
token_counter_4 = token_counter(tokens4_plus,1)
token_counter_5 = token_counter(tokens5_plus,1)

# %%
x1

# %%
token_counter_1_neg = token_counter(x1,0)
token_counter_2_neg = token_counter(x2,0)
token_counter_3_neg = token_counter(x3,0)
token_counter_4_neg = token_counter(x4,0)
token_counter_5_neg = token_counter(x5,0)

# %%
token_counter_5_neg

# %%
token_counter_1[0][1]
# Out:
# 312

# %%
k = token_counter_1[0]
k[1]


#for k in token_counter_1:
  #print("k=",k)

k = token_counter_1[2]
k
# Out:
# [('was', 'VBD'), 168, 173, 377, 797, 2508]

# %%
df_1 = df_1.append(token_counter_1_neg)
df_2 = df_2.append(token_counter_2_neg)
df_3 = df_3.append(token_counter_3_neg)
df_4 = df_4.append(token_counter_4_neg)
df_5 = df_5.append(token_counter_5_neg)

# %%
token_length_list = [len(df_1), len(df_2), len(df_3), len(df_4), len(df_5)]

# %%
token_length_list
# Out:
# [271, 312, 965, 2605, 8672]

# %%
token_counter_1[0][1]
# Out:
# 312

# %%
token_counter_1[0][0+1]
# Out:
# 312

# %%
#def score(i, token_count):

def score(token_counter):
  token1_scores = []
  for v in token_counter:
    k = v
    for k in token_counter:
      temp = []
      top = 0
      for x in range(1, 6):
        y = len(df_5)/token_length_list[x-1]
        #print(k[x+1])
        top = top+ (x * y * k[x])

      bottom = 0
      for x in range(1, 6):
        y = len(df_5)/token_length_list[x-1]
        bottom = bottom + (y * k[x])

      temp.append(k[0])
      temp.append(k[1])
      temp.append(top/bottom)
      token1_scores.append(temp)

  return token1_scores

# %%
_1 = score(token_counter_1)
_2 = score(token_counter_2)
_3 = score(token_counter_3)
_4 = score(token_counter_4)
_5 = score(token_counter_5)

# %%
_total = []
_total.append(_1)
_total.append(_2)
_total.append(_3)
_total.append(_4)
_total.append(_5)


_total = sum(_total, [])

# %%
# tested the means here -- 5 doesn't work as expected. Not sure why. Probably will skew the results
df_x=pd.DataFrame(np.array(_5))

df_x[2].mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# 2.8747890060645283

# %%
df1_sent_tok[0]
# Out:
# [('it', 'PRP'),
#  ('hums', 'VBD'),
#  ('crackles', 'NNS'),
#  ('and', 'CC'),
#  ('i', 'JJ'),
#  ('think', 'VBP'),
#  ('im', 'JJ'),
#  ('having', 'VBG'),
#  ('problems', 'NNS'),
#  ('with', 'IN'),
#  ('my', 'PRP$'),
#  ('equipment', 'NN'),
#  ('as', 'RB'),
#  ('soon', 'RB'),
#  ('as', 'IN'),
#  ('i', 'JJ'),
#  ('use', 'VBP'),
#  ('any', 'DT'),
#  ('of', 'IN'),
#  ('my', 'PRP$'),
#  ('other', 'JJ'),
#  ('cords', 'NNS'),
#  ('then', 'RB'),
#  ('the', 'DT'),
#  ('problem', 'NN'),
#  ('is', 'VBZ'),
#  ('gone', 'VBN'),
#  ('hosa', 'JJ'),
#  ('makes', 'VBZ'),
#  ('some', 'DT'),
#  ('other', 'JJ'),
#  ('products', 'NNS'),
#  ('that', 'WDT'),
#  ('have', 'VBP'),
#  ('good', 'JJ'),
#  ('value', 'NN'),
#  ('but', 'CC'),
#  ('based', 'VBN'),
#  ('on', 'IN'),
#  ('my', 'PRP$'),
#  ('experience', 'NN'),
#  ('i', 'NN'),
#  ('dont', 'VBP'),
#  ('recommend', 'VB'),
#  ('this', 'DT'),
#  ('one', 'CD')]

# %%
_total[0][0]
# Out:
# ('is', 'VBZ')

# %%
#count = []
#for i in df1_sent_tok:
#  for j in i:
#    for k in _total:
     
#      if j == k[0]:
#        #print(k[0])
        
 #       count.append(k[2])
  
#count
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-446-7af3cf2c15d8> in <module>()
#       2 for i in df1_sent_tok:
#       3   for j in i:
# ----> 4     for k in _total:
#       5
#       6       if j == k[0]:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Finalizing

# %%
df_dataset
# Out:
#                                                  Reviews  ...  Neg_Token_Vector
# 52     it hums crackles and i think im having problem...  ...            566754
# 89     im a procheapo and i hated this thing theyre n...  ...            712708
# 223    received it in time standard blister packaging...  ...            712708
# 224    these things are terrible one wouldnt fit in m...  ...            886937
# 408    this is a cheap piece of junk that does what i...  ...            712708
# ...                                                  ...  ...               ...
# 10251  true to phosphor bronze these strings have a m...  ...            745810
# 10252  ive used elixirs for about five years now this...  ...            712708
# 10254  i really like these strings  while they are no...  ...            972789
# 10256               great just as expected  thank to all  ...            712708
# 10257  ive been thinking about trying the nanoweb str...  ...            139402
#
# [10261 rows x 4 columns]

# %%
df_dataset.loc[df_dataset['Rating'] == 1, 'Final'] = 'Neg'  
df_dataset.loc[df_dataset['Rating'] == 2, 'Final'] = 'Neg'  
df_dataset.loc[df_dataset['Rating'] == 3, 'Final'] = 'Neu'  
df_dataset.loc[df_dataset['Rating'] == 4, 'Final'] = 'Pos'  
df_dataset.loc[df_dataset['Rating'] == 5, 'Final'] = 'Pos'

# %%
df_dataset.head()
# Out:
#                                                Reviews  ...  Final
# 52   it hums crackles and i think im having problem...  ...    Neg
# 89   im a procheapo and i hated this thing theyre n...  ...    Neg
# 223  received it in time standard blister packaging...  ...    Neg
# 224  these things are terrible one wouldnt fit in m...  ...    Neg
# 408  this is a cheap piece of junk that does what i...  ...    Neg
#
# [5 rows x 5 columns]

# %%
df_dataset.drop(columns=['Rating'])
# Out:
#                                                  Reviews  ...  Final
# 52     it hums crackles and i think im having problem...  ...    Neg
# 89     im a procheapo and i hated this thing theyre n...  ...    Neg
# 223    received it in time standard blister packaging...  ...    Neg
# 224    these things are terrible one wouldnt fit in m...  ...    Neg
# 408    this is a cheap piece of junk that does what i...  ...    Neg
# ...                                                  ...  ...    ...
# 10251  true to phosphor bronze these strings have a m...  ...    Pos
# 10252  ive used elixirs for about five years now this...  ...    Pos
# 10254  i really like these strings  while they are no...  ...    Pos
# 10256               great just as expected  thank to all  ...    Pos
# 10257  ive been thinking about trying the nanoweb str...  ...    Pos
#
# [10261 rows x 4 columns]

# %%
df_dataset.to_csv('final_data.csv')
